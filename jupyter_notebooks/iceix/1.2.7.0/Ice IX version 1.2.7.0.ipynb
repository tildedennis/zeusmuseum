# %% [markdown]
# ## Initial Setup
#
# 1. Download the Ice IX version 1.2.7.0 reference sample from [MalwareBazaar](https://bazaar.abuse.ch/sample/d122c989fe69f0912e7fb2aa838d6eb83995c86b6986f7b9e20fbea287e91ed4/).
# 2. Unpack the sample with [UNPACME](https://www.unpac.me/results/cefde749-9254-40bd-9a13-363b4c7a3ebe#/).

# %%
# Install required Python modules
import sys
# !{sys.executable} -m pip install pefile

# Import required Python modules
import hashlib
import pprint
import re
import struct

import pefile
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pefile in /usr/local/lib/python3.9/site-packages (2018.8.8)
# Requirement already satisfied: future in /usr/local/lib/python3.9/site-packages (from pefile) (0.18.2)

# %%
# Load the unpacked sample
fp = open("00224a6627121433bd556bd02592b0b3a82ee49a5f257b6ec23939279a5c12f6.bin", "rb")
sample = fp.read()
fp.close()

pe = pefile.PE(data=sample)

# %% [markdown]
# ## Decrypt Strings
#
# Pseudocode:
#
#     int __usercall CryptedStrings::_getA@<eax>(unsigned __int16 id@<ax>, int buffer@<edi>)
#     {
#       STRINGINFO *s; // eax
#       int i; // ecx
#       int i2; // esi
#       char pb; // dl
#       int result; // eax
#
#       s = &dword_401CD8[2 * id];
#       for ( i = 0; i < s->size; *(i2 + buffer) = pb )
#       {
#         i2 = i;
#         pb = i ^ LOBYTE(s->key) ^ *(s->encodedString + i);
#         ++i;
#       }
#       result = s->size;
#       *(result + buffer) = 0;
#       return result;
#     }
#
# Disassembly:
#
#     .text:00410EE7                               CryptedStrings___getA proc near
#     .text:00410EE7
#     .text:00410EE7 0F B7 C0                                      movzx   eax, ax
#     .text:00410EEA 8D 04 C5 D8 1C 40 00                          lea     eax, dword_401CD8[eax*8]
#     .text:00410EF1 33 D2                                         xor     edx, edx
#     .text:00410EF3 33 C9                                         xor     ecx, ecx
#     .text:00410EF5 66 3B 50 02                                   cmp     dx, [eax+2]
#     .text:00410EF9 73 19                                         jnb     short loc_410F14
#     .text:00410EFB 56                                            push    esi
#     .text:00410EFC
#     .text:00410EFC                               loc_410EFC:
#     .text:00410EFC 8B 50 04                                      mov     edx, [eax+4]
#     .text:00410EFF 0F B7 F1                                      movzx   esi, cx
#     .text:00410F02 8A 14 32                                      mov     dl, [edx+esi]
#     .text:00410F05 32 10                                         xor     dl, [eax]
#     .text:00410F07 32 D1                                         xor     dl, cl
#     .text:00410F09 41                                            inc     ecx
#     .text:00410F0A 88 14 3E                                      mov     [esi+edi], dl
#     .text:00410F0D 66 3B 48 02                                   cmp     cx, [eax+2]
#     .text:00410F11 72 E9                                         jb      short loc_410EFC
#     .text:00410F13 5E                                            pop     esi
#     .text:00410F14
#     .text:00410F14                               loc_410F14:
#     .text:00410F14 0F B7 40 02                                   movzx   eax, word ptr [eax+2]
#     .text:00410F18 C6 04 38 00                                   mov     byte ptr [eax+edi], 0
#     .text:00410F1C C3                                            retn
#     .text:00410F1C                               CryptedStrings___getA endp

# %%
def decrypt_string(pe, id_):
    match = re.search(rb'\x8d\x04\xc5(?P<enc_strings_addr>[\s\S]{4})', 
                      pe.get_memory_mapped_image())
    enc_strings_addr = struct.unpack("I", match.group("enc_strings_addr"))[0]
    
    enc_string_addr = enc_strings_addr + 8 * id_
    enc_string_rva = enc_string_addr - pe.OPTIONAL_HEADER.ImageBase
    
    xor_key = pe.get_word_at_rva(enc_string_rva)
    encbuf_len = pe.get_word_at_rva(enc_string_rva + 2)
    encbuf_addr = pe.get_dword_at_rva(enc_string_rva + 4)
    encbuf_rva = encbuf_addr - pe.OPTIONAL_HEADER.ImageBase
    encbuf = pe.get_data(encbuf_rva, encbuf_len)
    
    plainbuf = b""
    for i in range(len(encbuf)):
        pb = (i ^ xor_key ^ encbuf[i]) & 0xff
        plainbuf += struct.pack("B", pb)
        
    return plainbuf.decode()


for i in range(237):
    plain_string = decrypt_string(pe, i)
    print(f"{i}: {plain_string}")
# Out:
# 0: %s://%s:%s@%s/
# 1: ftp
# 2: pop3
# 3: anonymous
# 4: grabbed\%S_%02u_%02u_%02u.txt
# 5: Grabbed data from: %s
#
# %S
# 6: %s%s
# Referer: %S
# User input: %s
# %sPOST data:
#
# %S
# 7: *EMPTY*
# 8: *UNKNOWN*
# 9:  *BLOCKED*
# 10: Content-Type: %s
#
# 11: ZCID: %S
#
# 12: application/x-www-form-urlencoded
# 13: HTTP authentication: username="%s", password="%s"
#
# 14: HTTP authentication (encoded): %S
#
# 15: Mozilla\Firefox
# 16: user.js
# 17: profiles.ini
# 18: Profile%u
# 19: IsRelative
# 20: Path
# 21: user_pref("network.cookie.cookieBehavior", 0);
# user_pref("privacy.clearOnShutdown.cookies", false);
# user_pref("security.warn_viewing_mixed", false);
# user_pref("security.warn_viewing_mixed.show_once", false);
# user_pref("security.warn_submit_insecure", false);
# user_pref("security.warn_submit_insecure.show_once", false);
#
# 22: user_pref("browser.startup.homepage", "%s");
# user_pref("browser.startup.page", 1);
#
# 23: Software\Microsoft\Internet Explorer\Main
# 24: Start Page
# 25: Software\Microsoft\Internet Explorer\PhishingFilter
# 26: Enabled
# 27: EnabledV8
# 28: Software\Microsoft\Internet Explorer\Privacy
# 29: CleanCookies
# 30: Software\Microsoft\Windows\CurrentVersion\Internet Settings\Zones\%u
# 31: 1406
# 32: 1609
# 33: Accept-Encoding: identity
#
# 34: TE:
#
# 35: If-Modified-Since:
#
# 36:
# Path: %s
#
# 37: %s=%s
#
# 38: *@*.txt
# 39: Low
# 40: Wininet(Internet Explorer) cookies:
# %S
# 41: Empty
# 42: Macromedia\Flash Player
# 43: flashplayer.cab
# 44: *.sol
# 45: Windows Address Book
# 46: SOFTWARE\Microsoft\WAB\DLLPath
# 47: WABOpen
# 48: Windows Contacts
# 49: A8000A
# 50: 1.0
# 51: EmailAddressCollection/EmailAddress[%u]/Address
# 52: Windows Mail Recipients
# 53: Outlook Express Recipients
# 54: Outlook Express
# 55: account{*}.oeaccount
# 56: Software\Microsoft\Windows Mail
# 57: Software\Microsoft\Windows Live Mail
# 58: Store Root
# 59: Salt
# 60: 0x%s
# 61: Windows Mail
# 62: Windows Live Mail
# 63: MessageAccount
# 64: Account_Name
# 65: SMTP_Email_Address
# 66: %sAccount name: %s
# E-mail: %s
#
# 67: %s:
# 	Server: %s:%u%s
# 	Username: %s
# 	Password: %s
#
# 68: %s_Server
# 69: %s_User_Name
# 70: %s_Password2
# 71: %s_Port
# 72: %s_Secure_Connection
# 73: SMTP
# 74: POP3
# 75: IMAP
# 76:  (SSL)
# 77: ftp://%s:%s@%s:%u
#
# 78: ftp://%s:%s@%s
#
# 79: ftp://%S:%S@%S:%u
#
# 80: yA36zA48dEhfrvghGRg57h5UlDv3
# 81: sites.dat
# 82: quick.dat
# 83: history.dat
# 84: IP
# 85: port
# 86: user
# 87: pass
# 88: SOFTWARE\FlashFXP\3
# 89: datafolder
# 90: *flashfxp*
# 91: FlashFXP
# 92: wcx_ftp.ini
# 93: connections
# 94: default
# 95: host
# 96: username
# 97: password
# 98: SOFTWARE\Ghisler\Total Commander
# 99: ftpininame
# 100: installdir
# 101: *totalcmd*
# 102: *total*commander*
# 103: *ghisler*
# 104: Total Commander
# 105: ws_ftp.ini
# 106: _config_
# 107: HOST
# 108: PORT
# 109: UID
# 110: PWD
# 111: SOFTWARE\ipswitch\ws_ftp
# 112: datadir
# 113: *ipswitch*
# 114: WS_FTP
# 115: *.xml
# 116: /*/*/Server
# 117: Host
# 118: Port
# 119: User
# 120: Pass
# 121: *filezilla*
# 122: FileZilla
# 123: SOFTWARE\Far\Plugins\ftp\hosts
# 124: SOFTWARE\Far2\Plugins\ftp\hosts
# 125: hostname
# 126: username
# 127: user
# 128: password
# 129: FAR manager
# 130: SOFTWARE\martin prikryl\winscp 2\sessions
# 131: hostname
# 132: portnumber
# 133: username
# 134: password
# 135: WinSCP
# 136: ftplist.txt
# 137: ;server=
# 138: ;port=
# 139: ;user=
# 140: ;password=
# 141: ftp*commander*
# 142: FTP Commander
# 143: SOFTWARE\ftpware\coreftp\sites
# 144: host
# 145: port
# 146: user
# 147: pw
# 148: CoreFTP
# 149: *.xml
# 150: FavoriteItem
# 151: Host
# 152: Port
# 153: User
# 154: Password
# 155: SOFTWARE\smartftp\client 2.0\settings\general\favorites
# 156: personal favorites
# 157: SOFTWARE\smartftp\client 2.0\settings\backup
# 158: folder
# 159: SmartFTP
# 160: userinit.exe
# 161: pass
# 162: certs\%s\%s_%02u_%02u_%04u.pfx
# 163: grabbed
# 164: os_shutdown
# 165: os_reboot
# 166: bot_uninstall
# 167: bot_update
# 168: bot_update_exe
# 169: bot_bc_add
# 170: bot_bc_remove
# 171: bot_httpinject_disable
# 172: bot_httpinject_enable
# 173: fs_path_get
# 174: fs_search_add
# 175: fs_search_remove
# 176: user_destroy
# 177: user_logoff
# 178: user_execute
# 179: user_cookies_get
# 180: user_cookies_remove
# 181: user_certs_get
# 182: user_certs_remove
# 183: user_url_block
# 184: user_url_unblock
# 185: user_homepage_set
# 186: user_ftpclients_get
# 187: user_emailclients_get
# 188: user_flashplayer_get
# 189: user_flashplayer_remove
# 190: Not enough memory.
# 191: Script already executed.
# 192: Failed to load local configuration.
# 193: Failed to save local configuration.
# 194: Failed to execute command at line %u.
# 195: Unknown command at line %u.
# 196: OK.
# 197: Winsta0
# 198: default
# 199: screenshots\%s\%04x_%08x.jpg
# 200: unknown
# 201: image/jpeg
# 202: Software\Microsoft\Windows\Currentversion\Run
# 203: SOFTWARE\Microsoft\Windows NT\CurrentVersion\ProfileList\%s
# 204: ProfileImagePath
# 205: unknown\unknown
# 206: :d
# rd /S /Q "%s"
# rd /S /Q "%s"
# if exist "%s" goto d
# if exist "%s" goto d
# 207: dwm.exe
# 208: taskhost.exe
# 209: taskeng.exe
# 210: wscntfy.exe
# 211: ctfmon.exe
# 212: rdpclip.exe
# 213: explorer.exe
# 214: V	%08X
# C	%08X
# PS	%08X
# 215: BOT NOT CRYPTED!
# 216: SOFTWARE\Microsoft\Windows\CurrentVersion
# 217: InstallTime
# 218: WindowsProductId
# 219: %s_%08X%08X_%d
# 220: fatal_error
# 221: unknown
# 222: SYSTEM\CurrentControlSet\Services\SharedAccess\Parameters\FirewallPolicy\StandardProfile\AuthorizedApplications\List
# 223: SYSTEM\CurrentControlSet\Services\SharedAccess\Parameters\FirewallPolicy\DomainProfile\AuthorizedApplications\List
# 224: %windir%\explorer.exe
# 225: %windir%\explorer.exe:*:Enabled:Windows Explorer
# 226: netsh advfirewall firewall add rule name="explore" dir=in action=allow program="%s"
# 227: sc config wuauserv start= disabled
# net stop wuauserv
# sc config wscsvc start= disabled
# net stop wscsvc
# 228: wtsapi32.dll
# 229: WTSEnumerateSessionsW
# 230: WTSFreeMemory
# 231: WTSQueryUserToken
# 232: userenv.dll
# 233: GetDefaultUserProfileDirectoryW
# 234: user32.dll
# 235: MessageBoxW
# 236: ntdll.dll

# %% [markdown]
# ## Extract Version
#
# Pseudocode:
#
#     ...
#     version = 0x1020700;
#     v4 = BinStorage::_addItem(binstorage, 4u, 10003, 0x20000, &version);
#     ...
#
# Disassembly:
#
#     ...
#     .text:004050CB 8D 45 F8                      lea     eax, [ebp+version]
#     .text:004050CE 50                            push    eax
#     .text:004050CF 57                            push    edi
#     .text:004050D0 68 13 27 00 00                push    2713h
#     .text:004050D5 6A 04                         push    4
#     .text:004050D7 5B                            pop     ebx
#     .text:004050D8 8B C6                         mov     eax, esi
#     .text:004050DA C7 45 F8 00 07 02 01          mov     [ebp+version], 1020700h
#     .text:004050E1 E8 77 4C 01 00                call    BinStorage___addItem
#     .text:004050E6 8A D8                         mov     bl, al
#     ...

# %%
match = re.search(rb'\x68\x13\x27\x00\x00[\s\S]{1,8}?\xc7\x45[\s\S](?P<version>[\s\S]{4})', 
                  pe.get_memory_mapped_image())
version_bytes = match.group("version")
version = ".".join([str(b) for b in version_bytes[::-1]])
print(version)
# Out:
# 1.2.7.0

# %% [markdown]
# ## Decrypt BaseConfig
#
# Pseudocode:
#
#     _BYTE *__usercall Core::getBaseConfig@<eax>(void *base_config@<eax>)
#     {
#       _BYTE *result; // eax
#       int v2; // edx
#       int v3; // esi
#       int v4; // ecx
#
#       Mem::_copy(base_config, dword_4018C8, 952u);
#       v3 = v2;
#       v4 = dword_423F88 + dword_423ADC - result;
#       do
#       {
#         *result ^= result[v4];
#         ++result;
#         --v3;
#       }
#       while ( v3 );
#       return result;
#     }
#
# Disassembly:
#
#     .text:00411A23                               Core__getBaseConfig proc near
#     .text:00411A23
#     .text:00411A23 56                                            push    esi
#     .text:00411A24 BA B8 03 00 00                                mov     edx, 3B8h
#     .text:00411A29 52                                            push    edx
#     .text:00411A2A 68 C8 18 40 00                                push    offset dword_4018C8
#     .text:00411A2F 50                                            push    eax
#     .text:00411A30 E8 05 2A 00 00                                call    Mem___copy
#     .text:00411A35 8B 0D DC 3A 42 00                             mov     ecx, dword_423ADC
#     .text:00411A3B 03 0D 88 3F 42 00                             add     ecx, dword_423F88
#     .text:00411A41 8B F2                                         mov     esi, edx
#     .text:00411A43 2B C8                                         sub     ecx, eax
#     .text:00411A45
#     .text:00411A45                               loc_411A45:
#     .text:00411A45 8A 14 01                                      mov     dl, [ecx+eax]
#     .text:00411A48 30 10                                         xor     [eax], dl
#     .text:00411A4A 40                                            inc     eax
#     .text:00411A4B 4E                                            dec     esi
#     .text:00411A4C 75 F7                                         jnz     short loc_411A45
#     .text:00411A4E 5E                                            pop     esi
#     .text:00411A4F C3                                            retn
#     .text:00411A4F                               Core__getBaseConfig endp

# %%
match = re.search(rb'\xba(?P<encbuf_len>[\s\S]{2}\x00\x00)\x52\x68(?P<encbuf_addr>[\s\S]{4})',
                   pe.get_memory_mapped_image())

encbuf_len = struct.unpack("I", match.group("encbuf_len"))[0]
encbuf_addr = struct.unpack("I", match.group("encbuf_addr"))[0]
encbuf_rva = encbuf_addr - pe.OPTIONAL_HEADER.ImageBase
encbuf = pe.get_data(encbuf_rva, encbuf_len)

# #define PESECTION_OF_BASECONFIG_KEY 2
section = pe.sections[2]
xor_key = pe.get_data(section.VirtualAddress, encbuf_len)

base_config = b""
for i, eb in enumerate(encbuf):
    pb = eb ^ xor_key[i % len(xor_key)]
    base_config += struct.pack("B", pb)
    
print(base_config)
# Out:
# b'\xb3:\xa7\x88\xdb\xac\xc9\xf6OS\x0e\xba\x8e=\x9awx\\\xe8\xc8\x0f7\xb4\x8e~\xe0\x18\x89[&\xf5&)\x0b\x94\x98!y\x8d*20\xe8\xd4\n\x00\n\x00\xc7D\xb3\xdea}.?\n`)\x9f@\x01\xbd\xbd\x92C\x8f\xbfb\x90\xb0\x82\xe9\xce\xc2/|\x8e]\x0f\r\x86\xb1\xa0\xf4Al\xe8\xf06h\xb4\xd9\\\x0c\x8dl\x1a\xc0\x85\xe0P\xb7(Or3,\x99o m\xb1C\x02~\xcb\x8c\xb6\x83\x86\t\xbb\xdf\xd8\xf4N\xd0!\x907\x05\xb3\x9at\xe8\x7f\x8f\xff\xa2\xbf\x01\x8b\xe4\xef5\x17\x1c\x94w\n\xea\x89\x15\x0f\x
xae\xd7\x9b\xc4_\xf7\xe2:[,\x0c\xa5\x9f\x0c\xa5o\xc2g\x8c\x0c2~T\xd3\xc0o\xeb\x0c_\xf4yJ(M\x8b\xfb\xa2{q=A\xaf\xe4\xf3,\x02\xed\x18Cf\x02Ta\xddq\xcd\xde\xe9\x02@YC\xd7P\xb4\xcf\x98\x1e_\xd0\xcd\x19\xdaY\x8b\x18u\x04S\xa6[\xe57\x9c\xce\xc1>\xf6\xb4|\n\xdfS\xd1\xb8\x0eYF\x08U\x1f^\xbew.\x10H;\x03x\xa0\xbe\x0f\xcdt\r\x02\x93\x85\xf3I\x11M\x10\xd5\x06\xe4+\x1f\x98$\xcai\x8d\x0c\xff\n\x00\n\x00\\\xc7\x9c\ni\x04\x01\xcf\x84\xb9\x0co\xa6\x91\x11\xfchJ"P\x0e\xae4\xa2\xc5\xc5~X)I"\x1c\nZ\x0f2ps&\t\xdc\x9d\x9c\x10\xd1\xe2\x9f\xca\x93\x05<%'

# %% [markdown]
# ## Parse BaseConfig

# %%
flags = struct.unpack("I", base_config[0x220:0x220+4])[0]
print(f"flags: 0x{flags:x}\n")

delayStats = struct.unpack("I", base_config[0x380:0x380+4])[0]
print(f"delayStats: {delayStats}\n")

defaultConfig = base_config[0x2c8:0x2c8+101].split(b"\x00")[0].decode().replace("http", "hxxp")
print(f"defaultConfig: {defaultConfig}\n")

baseKey = base_config[0x59:0x59+258]
print(f"baseKey: {baseKey}\n")
""
defaultBotnet = base_config[0x1c0:0x1c0+21].split(b"\x00\x00")[0].decode()
print(f"defaultBotnet: {defaultBotnet}\n")

delayReport = struct.unpack("I", base_config[0x2c:0x2c+4])[0]
print(f"delayReport: {delayReport}\n")

delayConfig = struct.unpack("I", base_config[0x278:0x278+4])[0]
print(f"delayConfig: {delayConfig}\n")
# Out:
# flags: 0x800
#
# delayStats: 655370
#
# defaultConfig: hxxp://mugspade.ru/orders2010.php
#
# baseKey: b'6h\xb4\xd9\\\x0c\x8dl\x1a\xc0\x85\xe0P\xb7(Or3,\x99o m\xb1C\x02~\xcb\x8c\xb6\x83\x86\t\xbb\xdf\xd8\xf4N\xd0!\x907\x05\xb3\x9at\xe8\x7f\x8f\xff\xa2\xbf\x01\x8b\xe4\xef5\x17\x1c\x94w\n\xea\x89\x15\x0f\xf0j\xe1F\x9c\x11?Jz\xcd\xda\xa04\xac\xfa\xf9\xe5\x13i\x041-TZ\xe9u`\x12\x97\xc4\xd7\xf5}b\xaf\x1d\xe3y/\xc3\xc9\xe2\x08\xadd\xee\xd2\xa9\x9b)\xf1g\xf3\x92\xed\'S;=8f\x93\xfd\xabk0\xdc\x0e\xc1\xec\xa7\x8e]\xeb*\xf8B\x16\x8a\xb2"U{\x10\xa5\xdde\xa3\xa6\xe6\xc8\xf6\x87n:s_\xde\x96\xb0[$\x81MA\x88\xcf\xbe\xd3W^Q\xbcL\x9d<aIY\xbd#\xceK\x14\xa1R\xae\xfb\xa4\xd6.V\xb8\xd4\x9f+>|\x19\xfc\x95Xv\xd1HEx\xdb&@\xc5c\x82\xc2q\rD\xaa\x1f\x07\x03\xca\x0b\xc6\xf7%\xba9\xcc\xb5\xfep\xe7\x91\xf2\x98\xd5\x1b2\x18\xa8G\x84\x80\x06\x00\x9e\x1e\xc7\xb9\x00\x00'
#
# defaultBotnet: usa
#
# delayReport: 655370
#
# delayConfig: 1966110

# %% [markdown]
# ## Download DynamicConfig
#
# A PCAP with a DynamicConfig is on [VirusTotal](https://www.virustotal.com/gui/file/db5989f7d5b60c7e22fa5ac38666831929498b3ee1690aec349a6424ba3dfba1).
#
# ![](iceix_1.2.7.0_pcap.png)
#
# Pseudocode:
#
#     char __stdcall DynamicConfig::download(char *url)
#     {
#       ...
#       Core::getPeSettings(&pe_settings);
#       bot_id = Str::unicodeToXEx(-1, 0, &pe_settings.bot_id);
#       Str::unicodeToXEx(-1, 0, &pe_settings.bot_id);
#       bot_id_len = Str::_LengthA(bot_id);
#       Mem::_copy(rc4_S, &baseConfig.baseKey, 0x102u);
#       Mem::copyEx(v4, (bot_id_len + 1));            // copies bot_id to enc_bot_id
#       Crypt::_rc4(rc4_S, enc_bot_id, bot_id_len);
#       if ( Crypt::_md5Hash(enc_bot_id_hash, enc_bot_id, bot_id_len) )
#         md5_hash_to_hex_digest(enc_bot_id_hash_hex, enc_bot_id_hash);
#       Mem::_set(post_data, 0, 256u);
#       bn1equals_len = Str::_LengthA("bn1=");
#       append_like(post_data, v8, bn1equals_len);    // appends "bn1="
#       bot_id_len2 = Str::_LengthA(bot_id);
#       append_like(post_data, bot_id, bot_id_len2);
#       sk1equals_len = Str::_LengthA("&sk1=");
#       append_like(post_data, v11, sk1equals_len);   // appends &sk1=
#       enc_bot_id_hash_hex_len = Str::_LengthA(enc_bot_id_hash_hex);
#       append_like(post_data, v13, enc_bot_id_hash_hex_len);// appends enc_bot_id_hash_hex
#       cud.post_data = post_data;
#       cud.post_data_len = Str::_LengthA(post_data);
#       ...
#
# Uses a custom RC4 PRGA function, pseudocode:
#
#     int __userpurge Crypt::_rc4@<eax>(int S@<eax>, int buf, unsigned int buf_len)
#     {
#       unsigned int index; // edi
#       char S_i; // dl
#       unsigned __int8 j; // [esp+6h] [ebp-2h]
#       unsigned __int8 i; // [esp+7h] [ebp-1h]
#
#       i = *(S + 256);
#       index = 0;
#       for ( j = *(S + 257); index < buf_len; ++index )
#       {
#         i += 3;
#         S_i = *(i + S);
#         j += S_i + 7;
#         *(i + S) = *(j + S);
#         *(j + S) = S_i;
#         *(buf + index) ^= *((*(i + S) + S_i) + S);
#       }
#       *(S + 256) = i;
#       *(S + 257) = j;
#       return S;
#     }

# %%
def rc4_keystate(S, in_buf):
    out_buf = b""

    i = S[256]
    j = S[257]
    
    for in_byte in in_buf:
        (i, j, S, K) = rc4_prga(i, j, S)
        out_byte = in_byte ^ K
        out_buf += struct.pack("B", out_byte)

    return out_buf


def rc4_prga(i, j, S): 
    # custom prga
    i = (i + 3) % 256 
    j = (j + S[i] + 7) % 256 

    S = bytearray(S)
    S[i], S[j] = S[j], S[i]
    S = bytes(S)

    K = S[(S[i] + S[j]) % 256]

    return (i, j, S, K)


bot_id = b"WIN7PRO_X86_000_74DEB1E36522DF69_26"
enc_bot_id = rc4_keystate(baseKey, bot_id)

md5 = hashlib.md5()
md5.update(enc_bot_id)
sk1 = md5.hexdigest().upper()

assert(sk1 == "C15CAF65F6280F4916AB79B669689A92")
print(f"{sk1=}")
# Out:
# sk1='C15CAF65F6280F4916AB79B669689A92'

# %% [markdown]
# ## Decrypt DynamicConfig
#
# Pseudocode:
#
#     ...
#     Mem::_copy(v7, rc4Key, 0x102u);
#     Crypt::_rc4(v4, binStorage, dataSize);
#     if ( dataSize )                             // inlined Crypt::_visualDecrypt
#     {
#       v5 = dataSize - 1;
#       if ( dataSize != 1 )
#       {
#         do
#         {
#           *(v5 + binStorage) ^= *(v5 + binStorage - 1);
#           --v5;
#         }
#         while ( v5 );
#       }
#     }

# %%
def visual_decrypt(enc_buf):
    buf = bytearray(enc_buf)

    for i in range(len(buf)-1, 0, -1):
        buf[i] ^= buf[i-1]

    plain_buf = bytes(buf)

    return plain_buf


# Load encrypted DynamicConfig from PCAP
fp = open("setusating.bin", "rb")
config_bin = fp.read()
fp.close()

round1 = rc4_keystate(baseKey, config_bin)
binstorage = visual_decrypt(round1)
print(binstorage)
# Out:
# b'\xe6\xb8\xf8\xe4W\xa1\x91\xdd+\x1b\xfeAl>!R\xb3\xdb\x07\xf0\xcbi\x00\x00\x00\x00\x00\x00/\x00\x00\x00\xb99\x8d\xf6tL^\xa4\xc3\xb2\xc2\xdc\x18\x94\xbb\x05!N\x00\x00\x00\x00\x00\x10\x04\x00\x00\x00\x04\x00\x00\x00\x00\x07\x02\x01"N\x00\x00\x00\x00\x00\x10\x19\x00\x00\x00\x19\x00\x00\x00http://datecoin.ru/us.php#N\x00\x00\x00\x00\x00\x10\x1d\x00\x00\x00\x1d\x00\x00\x00http://trapbath.ru/busted.php$N\x00\x00\x01\x00\x00\x10\xa3\x00\x00\x00\xca\x00\x00\x00\xff\xb7\xff\xffhttp://franksinat\x0842.com/tur\xb5\x0f\xf6\xffkishair.php\x00(clot\r@n\xb7\xbf,.ru/mu1ke!wk\xdb\xdf\xfe\xfeoliveOcesG.net/b\rt\xee>\xb0oJlavo(tax!ell{\xff\x81\xfdKup\x1amoodgum\x18o\xcd\xfd\x07vrd\x1a209.135\x03\xa6\x00\x18\xdb\xda62\xb8\xb3e\x1e\x00\x00\x00\x00\x00\x00\x00\x00$\xff%N\x00\x00\x00\x00\x00\x10/\x00\x00\x00/\x00\x00\x00Nhttp://*\x00S*/login.osmp.ru/*\x00S*/atl.osmp.ru/*\x00\x00\x01\x00\x00\x00\x01\x00\x00@\x82\x01\x00\x00^\x02\x00\x009\xfb\xfe\xcb\x0b\x00<TITLE>\x0c\n/\x0b\x13\xf9\xb1\xff\xbfWelcome to HSBC)titleo\x00\x9b\x05\x0b)\t\x1
\x10=~\x176\xfb\x9bHtoGMTS\xf9If\xba\xcd\x15\n\xfa\xf7\xab\x19F\t1\t\xe1\xb1\x1f!mit$}\r\n\xf00\xb4eofecko#\x19\x14\x16 \\r (\x19\x98\xadp\x18#\xfb)`fd\xe9-`\x1d\xb3;AJ\'\xc8,!\x10\xdc\x90!bx*\x94\x1c\x0b\xd7y\xe6U\\\x08\xdf\x1a_\xa1y=\'b\xf0\xac\';\r\n\xb7\xda\x80\x84Q\xea\x0fh\x14^\xe8tc\x11/\\"\xdft\x86\xc0\x1en\xdd,\'\'BeM_\xd8-\x9c9\x040.\x07r\x14No\x11\xb6\x7f\xd7\xd9VmoveChil-e\x91\r!\x18\n\xd54\x14s\xdb\xcd\xb5\xb5UT\x97NlZh1M[\x84]J\xd81]\xd5\xe8 \'\x92\x850\x00\x0b\x8e\xff\xb0!\x8c,\x8b\xcf\xb8\x1b!\x94\x0b0\xcdr\x04N\xa0\x80\xaet>\xbb\x93\x1c\x81\xedb\x9ay\xbb\'\x00>{\x93M\x19\xaa;5\x07&f\x95b\xddn\x05\x06>\x1a\x04 j&\xdd\x96\x81\x83k:nxN\x10\x19"\x0f\xee\x0b\x08\r`S\x14\xa8"\xa5\xff\xb7a2dight: 380pxq\xbbmkMzdEn-\x1bf\x1515d\xb3\xc9b\x14\x15r,\x16\x85`mi\x9ap\x14\x13]\xda\xae[\xa5ri\xaal-\x80gn\x16\n\x85\xdd\xe6\x1b\x8a>\xf2ta\x01\xb8\xb9F+4aB\xa4h6\x10\x0b\x16\xbb|0"\x0fF\x0f\xda \xb6\xb0\nr\xa6r\n\x17d}\xad\xb5\xef\x06"100%\x0c\x0b\tF\t\x9a\x81\x16\xa1G-\x06\x99\xeb\xd8\xef\xa9\x15\x1d\x16\xf8T\\Bg!\xb5n\xc3\xba"d\x1b\xfelT\nk\xd8\x0c\xad\x1a\x18/\x03f\r \x13\x85\xf6\xed\xaeoaRED\x15As as\xc6\x95\n\x05\x07\xee\x11o\xd4+\xe0\xda\xb6,y\xd6r\x ...

# %% [markdown]
# ## Parse DynamicConfig

# %%
def parse_binstorage_header(binstorage):
    header = {
        "randData": binstorage[0:20],
        "size": struct.unpack("I", binstorage[20:24])[0],
        "flags": struct.unpack("I", binstorage[24:28])[0],
        "count": struct.unpack("I", binstorage[28:32])[0],
        "md5Hash": binstorage[32:48],
    }
        
    return header


def parse_binstorage_sections(section_data, num_sections):
    CFGIDS = {
        20001: "CFGID_LAST_VERSION",
        20002: "CFGID_LAST_VERSION_URL",
        20003: "CFGID_URL_SERVER_0",
        20004: "CFGID_URL_ADV_SERVERS",
        20005: "CFGID_HTTP_FILTER",
        20006: "CFGID_HTTP_POSTDATA_FILTER",
        20007: "CFGID_HTTP_INJECTS_LIST",
        20008: "CFGID_DNS_LIST",
    }
    
    sections = []
    offset = 0
    for i in range(num_sections):
        section = {}
        
        id_ = struct.unpack("I", section_data[offset:offset+4])[0]
        if int(id_) in CFGIDS:
            section["id"] = f'{CFGIDS[int(id_)]} ({id_})'
        else:
            section["id"] = id_
            
        section["flags"] = struct.unpack("I", section_data[offset+4:offset+8])[0]
        section["size"] = struct.unpack("I", section_data[offset+8:offset+12])[0]
        section["realSize"] = struct.unpack("I", section_data[offset+12:offset+16])[0]
        # additional parsing of data is left as an exercise
        section["data"] = section_data[offset+16:offset+16+section["size"]]
        
        offset += 4 + 4 + 4 + 4 + section["size"]
        
        sections.append(section)
        
    return sections


binstorage_header = parse_binstorage_header(binstorage)
print("binstorage_header:\n")
pprint.pprint(binstorage_header)

binstorage_sections = parse_binstorage_sections(binstorage[48:], binstorage_header["count"])
print()
print("binstorage_sections:\n")
pprint.pprint(binstorage_sections)
# Out:
# binstorage_header:
#
# {'count': 47,
#  'flags': 0,
#  'md5Hash': b'\xb99\x8d\xf6tL^\xa4\xc3\xb2\xc2\xdc\x18\x94\xbb\x05',
#  'randData': b'\xe6\xb8\xf8\xe4W\xa1\x91\xdd+\x1b\xfeAl>!R\xb3\xdb\x07\xf0',
#  'size': 27083}
#
# binstorage_sections:
#
# [{'data': b'\x00\x07\x02\x01',
#   'flags': 268435456,
#   'id': 'CFGID_LAST_VERSION (20001)',
#   'realSize': 4,
#   'size': 4},
#  {'data': b'http://datecoin.ru/us.php',
#   'flags': 268435456,
#   'id': 'CFGID_LAST_VERSION_URL (20002)',
#   'realSize': 25,
#   'size': 25},
#  {'data': b'http://trapbath.ru/busted.php',
#   'flags': 268435456,
#   'id': 'CFGID_URL_SERVER_0 (20003)',
#   'realSize': 29,
#   'size': 29},
#  {'data': b'\xff\xb7\xff\xffhttp://franksinat\x0842.com/tur\xb5\x0f\xf6\xffkish'
#           b'air.php\x00(clot\r@n\xb7\xbf,.ru/mu1ke!wk\xdb\xdf\xfe\xfeoliveOces'
#           b'G.net/b\rt\xee>\xb0oJlavo(tax!ell{\xff\x81\xfdKup\x1amoodgu'
#           b'm\x18o\xcd\xfd\x07vrd\x1a209.135\x03\xa6\x00\x18\xdb\xda62\xb8\xb3e'
#           b'\x1e\x00\x00\x00\x00\x00\x00\x00\x00$\xff',
#   'flags': 268435457,
#   'id': 'CFGID_URL_ADV_SERVERS (20004)',
#   'realSize': 202,
#   'size': 163},
#  {'data': b'Nhttp://*\x00S*/login.osmp.ru/*\x00S*/atl.osmp.ru/*\x00\x00',
#   'flags': 268435456,
#   'id': 'CFGID_HTTP_FILTER (20005)',
#   'realSize': 47,
#   'size': 47},
#  {'data': b'9\xfb\xfe\xcb\x0b\x00<TITLE>\x0c\n/\x0b\x13\xf9\xb1\xff\xbfWelcom'
#           b'e to HSBC)titleo\x00\x9b\x05\x0b)\t\x1e\xff\xf6\xae\xfbbody\x04'
#           b'\x08\x19\x03 sty*="displ\xfb\x1b{\xffay:none"\x1cS/*>\xd5\x01\n\xff'
#           b'\xdb\xed\x7f\r\n<script0rc.https://a\x98\xdbn\xffjax.googCapB.k\x13'
#           b'\x1f\xec\xff\xff/libs/jquery/1.6.4\x0c.js"go\xefn\x8cyprtext\x15'
#           b'avaX"\xc2\x96\x9d\xb5>n\t>l)\xd6\xbe\xfd\x16 \tdocu\xd7nt.w\x12\x1f'
#           b"\xff\xa7\xec\xef('1'+'\xa1polycache.n\xdb\xb6\xdbru_se\x16T"
#           b'\x9dw\x00/\xaf[\xeb\xfe\xf6/flv\x0c23/hcs\x98?\x1d io\xb7o'
#           b'\x0b\x00=GMath0anem()\xfe\xd9"kU\xb2v>\');\r\n\xff\xbf\'\xc2\xc3if('
#           b"\x1cof __JSHOS\xdb\x16\xde\xfeT == 'uvefi\x87dQ{\xe6\x85#<$\x89"
#           b".\xac.vh\x98\xdb\n\x0b]ia\x0c -\rA\x18`\xb7\x15';*\xd6\x00@\xc2~''}"
#           b'\x9d\x01\x00\x00\x00\x00\x00\x00 \xff',
#   'flags': 1073741825,
#   'id': 1,
#   'realSize': 606,
#   'size': 386},
#  {'data': b'\xdf\xed\xfe\xcb\x0b\x00</head>\x04\n\xad\x05\x0escrip\xff'
#           b'\xb3\xff\xfft type="text/java\x15" langua\xff\xf6\x80\xb9g\x1a\x15'
#           b'>\r\n\x0br MyCom\xec\xff\xff\xdbpu3rHASH = \'%botname%\';"\xd8'
#           b'\xc9\xfe7\x1asubdir et\x1f\xdf\xdb\x7f\xfbtry{\x05window.o\x15rro#'
#           b'f\xb7\xed\x7f\xfbuncti\x0f(msg, url\x04l#e_\xec\xbf\r\xf6no){,c\x1d'
#           b"sole && \nl7d\x1f.log\x0e(:+';\\\xcc\x05{:'+B\x10g\x11\xfbmk\xef^)"
#           b"; r\x8c'n\xfdrue;}\x8d5\xb7\xfdm}Aatch(ek}\xa2\x01\x17\xbe\xf6"
#           b'\x87\x8d gc(a\x14\xd3b\x0b "\xd7\xeen\xb7+\x87cu\xe8nt\x8coki'
#           b'<\x19\xfd\xb1\xf6\xc8ca+"\x07\x0fd=null\xbd\x19[\x88\n@0\x07fi'
#           b'f(b\xd7Z\xfb\xad\xa1;gth>0S\x1a\r\xd7\xdd\x7f\xb7\x05yO\x17c)\x1d'
#           b'e!=-1\x18+o\x01;\xd8=c\';f$\\",e\x0e;\xd6b(\x15(f=O}'
#           b'\xb8\xc2\xc2\xd6r\xb0e\xa6a\xccc\xfd\x0b\xad5ws\xd96\x0be,f))}}\x85'
#           b'\x16\xb0\x9f\xed(d)}\xd9\x96\x1cC\xc3\x0b\xb7d\xf5ep\xde() \x92'
#           b"a\x85\x7f\xedB2\xde\xfatE[\nByI\xb8\xb7\xae\xe1d('at\x0cAJa"
#           b"')\x92\xff\x1f\xe17\xb7HTML.m7/[0-9\\,\\.\\-]\x9ek\xdf\xfe{1,}\\"
#           b'&n\x82p\\;/\xaeWX\xb56\xeb\xde/w Dm(\x11\xa3_\xf8\x1e\xa4\x8b\x0e'
#           b'\ng)+7\x1c cs]Hb<"\xa3\xdch\x93[+\xb4\xade\xe8y\xe7\xbf\x10\xf4=ak'
#           b',\xb4/\x07\x18pa\x10=~\x176\xfb\x9bHtoGMTS\xf9If\xba\xcd\x15\n'
#           b'\xe0ad\x0fT\x85\xed\xad%\xd7mtTi\x1bo\xb7\xb7\xad0\xd8("-\'\x95#\''
#           b'+cs\x0b[\xbb\xf0s({\'\xaasp\\\x0f:\xaebva\xe1\x0bGck\'}\'"\x845'
#           b'0\x00\x87\n\xc1\xb5\x08\x0b\x14al\xf0\xafm\x8dm.,h\x98\x13.sa/Ckm'
#           b'\xc1\xcc\x1f_\xb7\xd2\xcc$\x06\x84\xffF?Nuid=&h=1/\tk\xee\xe3\x9d'
#           b'\x02\xc7\xd8\x1b\x03g\x95\x8d\xc2`nlz\xce:\xfc\x01\x00\x00\x00'
#           b'l\xc7 \x00\x12\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 4,
#   'realSize': 811,
#   'size': 488},
#  {'data': b'\xff\xff\xff\xcb3\x00<script*src="js/jquery-1.\xee\xd9o\xff4.2.m'
#           b'in.\x13" ></&>\x042\xb7o?\xd9\xcc\x026 type7text9av0\xf7o\xb3a\x150'
#           b'languag\x1a\x15\x7f\xfb\xdf\x1e>\r\n\x0br MyCompu3rHASH'
#           b' \xff\x86\xfd\xff= \'%botname%\';"\x1asubdm\x1b;\xd9ir et\x1ft'
#           b'\x9d{\x05\xfd\xef\xed\xb7w\x99dow.o\x15rro#functi\xfb\xdb\xf6'
#           b'\xbf\x0f(msg, url\x04l#e_no){,\x0f\xf6\xdf\x06c\x1dsole && \n.lo='
#           b"\xb6\x1b\xb2g\x0e(:+';:'+w.\xe6\x82B\x10g\x11^); \xed\xc2\xb6"
#           b"\xb5r\x8c'n\xfdr,;}\x8d\x12\xdc\xf6\xb7}Aatch(ek}\xa2-#\x1c\x90p\r"
#           b"\n' \x8bhk\xef\xfe\xffttps://ghyclnbg\xbem/to\xc8\x11\xe1\xd6n[|"
#           b'b\x8cws\x92\x9dfo\xa0{x\xa8\xec>q>jQ\xf5(\\\xa1\xdd\xbepcu\x86nt).'
#           b'\xe0ad\x0fT\x85\xed\xad%\xd7mtTi\x1bo\xb7\xb7\xad0\xd8("-\'\x95#\''
#           b'+cs\x0b[\xbb\xf0s({\'\xaasp\\\x0f:\xaebva\xe1\x0bGck\'}\'"\x845'
#           b'0\x00\x87\n\xc1\xb5\x08\x0b\x14al\xf0\xafm\x8dm.,h\x98\x13.sa/Ckm'
#           b'\xc1\xcc\x1f_\xb7\xd2\xcc$\x06\x84\xffF?Nuid=&h=1/\tk\xee\xe3\x9d'
#           b'\x02\xc7\xd8\x1b\x03g\x95\x8d\xc2`nlz\xce:\xfc\x01\x00\x00\x00'
#           b'l\xc7 \x00\x12\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 5,
#   'realSize': 811,
#   'size': 488},
#  {'data': b'\xff\xff\xff\xcb,\x00<script*jquery.prettyPhotn\xbbg\xffo.js*'
#           b'></\x1f>\x04+\x7f\x03\x03\r\n\xec\xff\xb7\xc11 &pe="text/java'
#           b'\x156`\xee\xff" languag\x1a\x15>6\xfe\xdf\xfe\xb7\x0br MyCompu3rHA'
#           b'SH = \'%b\xfe7\xec\xdfiname%\';"\x1asubdirm\x1bk\xc9 \x93\x1ft'
#           b'\xa0{\x05\xed\x7fo\xffwindow.o\x15rro#functi\x0f\xd8\xdf\xb6\xff('
#           b'msg, url\x04l#e_no){,}\xb0\xff6c\x1dsole && \n.log\xec\xb1\xdd'
#           b"\x90\x0e(:+';:'+B\xb8s1\x17\x10g\x11^); \xb6\x0b\xdbf 'n\xfdr/"
#           b";}\x8d}Ip\xdb\xdfAatch(ek}\xa2/\xdd\x87\x10\t'\x02j1\xd4jk\x17Z"
#           b'\x84Q\x8f\x801nf\x8b\xe0\xedCem({\\ src\x10\xd6\xbe\xfd\x85h\xdfp'
#           b's://a\x19x.go\xf6\xfcx\x1bk\xf8apis"m\x13/lbs/Q8\xd8\xcf\x0e/1.'
#           b'6\n.m\x0f<([\xd2\x11"\xe1Q2\x0f\x83l\x81\x14\x141\xec\x7f\x11'
#           b'\x08\x03ghyclnbg\xfcXh\x8dF\xf1)\x11\xddb\x00\xd8\xad]\xedwso'
#           b'\xeefo\xf0\xa1\xf0\xa3lqhells\x86\xd1ml[o_ucZet?\x00'
#           b'\x04\xec\xbf\xffuid=&h=1\x7f\x00\x00\x00\x00\x00\x00\x00\x12\xff',
#   'flags': 1073741825,
#   'id': 6,
#   'realSize': 943,
#   'size': 446},
#  {'data': b'\xdf\xed\xfe\xcb\x0b\x00<HEAD*>\x04\nC\x03\x0escrip\xff'
#           b'\xb3\xff\xfft type="text/java\x15" langua\xff\xf6\x80\xb9g\x1a\x15'
#           b'>\r\n\x0br MyCom\xec\xff\xff\xdbpu3rHASH = \'%botname%\';"\xd8'
#           b'\xc9\xfe7\x1asubdir et\x1f\xdf\xdb\x7f\xfbtry{\x05window.o\x15rro#'
#           b'f\xb7\xed\x7f\xfbuncti\x0f(msg, url\x04l#e_\xec\xbf\r\xf6no){,c\x1d'
#           b"sole && \nl7d\x1f.log\x0e(:+';\\\xcc\x05{:'+B\x10g\x11\xfbmk\xef^)"
#           b"; r\x8c'n\xfdrue;}\x8dl\xb7\xfdm}Aatch(ek}\xa2</\xf1\xf6"
#           b"\x03\x12\xdc\xf0' src\x10\xda\xbb\xff\xffhttps://ghyclnbg\xbem"
#           b'/to\xc8\xbf\xb5\xdb\xd6\x11|b\x8cws\x92\x9dfo.jsWe\xc9\nYqo'
#           b'a\xec\x0b\x85o\x19x.go\t\x0fapisv\xd0\xb6\x0b_\x13/\x0bbsLq'
#           b'\xf1\xc2\xda\xc1\xbe\x80/1.6\n.m\x84\x82C{A\xd8\xf4pp\x03\x9e'
#           b'\xa3[\xd86l_\xf7c{es? \xf7T\xd9\x7fuid=&h=1~>jQ\xcd\xdd\xbe'
#           b'\xd1\xda(i\\\x88nt).bad{+$\xa3\x0fV\xd9wtTi\x1bk\x0cvco\xb9('
#           b'"-\'\x97#\xd6n\xfcm\'+css({\'\xacsp\\\x0fc\xe3\xdb\xc6:\xb0b\xaack'
#           b'\'})"\x86\x1d\x18\xb7v20\x00\x08})\x18\x18\x8d\xd6Z3FT$b\x857p'
#           b"{,c\x1dsoC\xf6\xc1\xee\xf4&& \n.log\x0e(\\\xb0\xc7v:+';:'+"
#           b"B\x10\xb5\x85\xce\xc5g\x11^)\tr\x8c\xfe\xb6\xfd\xb6'n\xfdrue;"
#           b'}\x8d}Aatch(e.l\x9b\xdbk}\xa2\x01s\x1fT8eo\xb9\xee\x0f\xdb'
#           b'\xe5(\x98 ( ) \xb9 \x00\xda\xcd}\xcd\xc3\n\xe8s\xb9\x9acu*'
#           b"\xffk\x17\x16_..tE\x84\nById('[\xa3;\x08\x98')R\t#@s\xadu\xed"
#           b'\xb3)>s.p;&N\x1d\xb3\xc0\xba\xdbo\x08moveC,ld ;\x8a_s\x14\xdc\x98'
#           b'\x05\x19\x00B<#D\xc2\x84/\x87\xbdLl\xdb\xbf1ktps://a\x19x\xb0'
#           b'o\xac\xa1q+/\xb0ap0[m\x13\xb7\xc2va/1bsLq\x17\xe2/15^8\xd8.6\n.m'
#           b'H.js\x02\xf67\x12\x81\x84\xf9yclnbg}\x85\x85\xb60t\x0co\x11Bb'
#           b'\xa7\x01do\x85w~-nfoq+\xb4m\xe1ci\xdcb8k\xf8\x0bs\xd1\x15\nm_y\xcc'
#           b'\x91x?\x02\xb6\xd4\xb4\xbdu]&\x881\x83\x00\x00\x00\x00\x00\x00'
#           b'\t\x00\xff',
#   'flags': 1073741825,
#   'id': 10,
#   'realSize': 1019,
#   'size': 619},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>u\x03\nstyle\xff\xbf\xbf\xfd '
#           b'id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!important; }@6'
#           b'o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/java\x15" ?nguag'
#           b"\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu\xec\xbf\xfd\xdf3rHASH = '%y"
#           b'tname%\';";\xd9\xf67\x1asub\x8br et\x1fw\xf7o\x1ftry{\x05wind'
#           b'ow.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg, url\x04l#\xddm\xb0\xdbe'
#           b"_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e(:\x98\x0b\xf6\xd8+';:'+B"
#           b"\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c'n\xdb\xdf\xb6\xdf\xfdrue;}"
#           b'\x8d}Aatch(ek}\xdb\x85ms\xa2\x01s\x1fT8eo\xe5(9\xd7\xfda\x98 ('
#           b' ) \xb9 \x00\xc3B\xbb\xb9\xaf\n\xe8s\xb9\x9acu*_\xe1\x7f\xed\xc2'
#           b"..tE\x84\nById('\x98\xcfnw\x07')R\tif@s)>s.\xbf\xb5\xd6\xb5p;&"
#           b'N\x1d\xb3\x08moveCp\x03\xebn,ld ;\x8a\x98a\xc2\xcf]\x0510\x00'
#           b'B</\x87\xbd\xbf\xe3\x16"urc,ttps:/q+l\xdb/a\x19x\xb0o/\xb0apva\xac'
#           b'\xa10[m\x13/1bsL8\xd8\xb7\xc2q\x17\xe2/1.6\n.m\x13\x815^H.js'
#           b'\x02\x84g\xd0\x16\xc6\xfehyclnbg}t\x0co\x11\xec\xad\xb0\xb0Bb\xa7w~'
#           b'-nfoq[\xa1=\x80b3\xf2\x05m_\x8d\xaePhs\xc6\x8br?\xb7L\x03\xf6'
#           b'\xa6uW&h=1}\x19\x7f\xee\xb6=\xde\x91rm \xe8Pw\nkF\x0e4\x1c\xdd'
#           b'\xd32"\x9c%\x03 \x83\xf0\xa3\x05\xa3-\'t\x1c]c:\xc0\xc2[at\xd8Wk2'
#           b'(\xc0"\x00\x00\x00\x00\x00\x00 \x01\xff',
#   'flags': 1073741825,
#   'id': 11,
#   'realSize': 966,
#   'size': 592},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>u\x03\nstyle\xff\xbf\xbf\xfd '
#           b'id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!important; }@6'
#           b'o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/java\x15" ?nguag'
#           b"\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu\xec\xbf\xfd\xdf3rHASH = '%y"
#           b'tname%\';";\xd9\xf67\x1asub\x8br et\x1fw\xf7o\x1ftry{\x05wind'
#           b'ow.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg, url\x04l#\xddm\xb0\xdbe'
#           b"_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e(:\x98\x0b\xf6\xd8+';:'+B"
#           b"\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c'n\xdb\xdf\xb6\xdf\xfdrue;}"
#           b'\x8d}Aatch(ek}\xdb\x85ms\xa2\x01s\x1fT8eo\xe5(9\xd7\xfda\x98 ('
#           b' ) \xb9 \x00\xc3B\xbb\xb9\xaf\n\xe8s\xb9\x9acu*_\xe1\x7f\xed\xc2'
#           b"..tE\x84\nById('\x98\xcfnw\x07')R\tif@s)>s.\xbf\xb5\xd6\xb5p;&"
#           b'N\x1d\xb3\x08moveCp\x03\xebn,ld ;\x8a\x98a\xc2\xcf]\x0510\x00'
#           b'B</\x87\xbd\xbf\xe3\x16"urc,ttps:/q+l\xdb/a\x19x\xb0o/\xb0apva\xac'
#           b'\xa10[m\x13/1bsL8\xd8\xb7\xc2q\x17\xe2/1.6\n.m\x13\x815^H.js'
#           b'\x02\x84g\xd0\x16\xc6\xfehyclnbg}t\x0co\x11\xec\xad\xb0\xb0Bb\xa7w~'
#           b'-nfoq[\xa1=\x80b3\xf2\x05m_\x8d\xaePhs\xc6\x8br?\xb7\x00\x02\xf6'
#           b'\xa6uW&h=1}\x00\x00\x00\x00\x00\x00\x00\t\xff',
#   'flags': 1073741825,
#   'id': 12,
#   'realSize': 900,
#   'size': 541},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>|\x03\nstyle\xff\xbf\xbf\xfd '
#           b'id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!important; }@6'
#           b'o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/java\x15" ?nguag'
#           b"\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu\xec\xbf\xfd\xdf3rHASH = '%y"
#           b'tname%\';";\xd9\xf67\x1asub\x8br et\x1fw\xf7o\x1ftry{\x05wind'
#           b'ow.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg, url\x04l#\xddm\xb0\xdbe'
#           b"_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e(:\x98\x0b\xf6\xd8+';:'+B"
#           b"\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c'n\xdb\xdf\xb6\xdf\xfdrue;}"
#           b'\x8d}Aatch(ek}\xdb\x85ms\xa2\x01s\x1fT8eo\xe5(9\xd7\xfda\x98 ('
#           b' ) \xb9 \x00\xc3B\xbb\xb9\xaf\n\xe8s\xb9\x9acu*_\xe1\x7f\xed\xc2'
#           b"..tE\x84\nById('\x98\xcfnw\x07')R\tif@s)>s.\xbf\xb5\xd6\xb5p;&"
#           b'N\x1d\xb3\x08moveCp\x03\xebn,ld ;\x8a\x98a\xc2\xcf]\x0510\x00'
#           b'B</\x87\xbd\xbf\xe3\x16"urc,ttps:/q+l\xdb/a\x19x\xb0o/\xb0apva\xac'
#           b'\xa10[m\x13/1bsL8\xd8\xb7\xc2q\x17\xe2/1.6\n.m\x13\x815^H.js'
#           b'\x02\x84g\xd0\x16\xc6\xfehyclnbg}t\x0co\x11\xec\xad\xb0\xb0Bb\xa7w~'
#           b'-nfoq\x15\x16>\x80bal\xddk\xc0Ph\x9b\xa3\xf4<t_z\xcd\xf6\xa6\x8d'
#           b'\xae\x92y?\xbeu^&h=1\x84\x00\x00\x00\x02\x00\t\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 13,
#   'realSize': 907,
#   'size': 545},
#  {'data': b'\xba\xff\xff\xcb\x15\x00function doSubmit\x04\x14\x08\xf7\xdf'
#           b'}\xef\x03_old\x0b\x0b\x03</head>y\x03\n\xfd\xfe\xf6\x7fstyle id'
#           b'="h\x04body">\x05 {\xff\xb7\xf6\xbfAisplay: nN!!important\xfb'
#           b'\xdbc\xed; }@6>\r\n?cript \x0e\xed\xd9\xffvpeBtext/java\x15" ?\x9b'
#           b"\x0b\x98\xfbnguag\x1a\x156\x0br\xdb\xffm\xfb MyCoSu3rHASH = '%y"
#           b't\xad}\xc3\xfename%\';"\x1as\xc8\x8b\xde>v\xb2r et\x1ftry{\x05w'
#           b'in\x0f\xe1\xdd\xdd\xe9w.\xa1rro#\x00(m\xecv\xdb\xfesg, url\x04l#e'
#           b"_\xc4){,\x0fvw\x1bc\x1dso\xf4&& \n.lo=\xb6\x1b\xb2g\x0e(:+';:'+t"
#           b".\xe6\x82B\x10g\x11^)\xdf\n\xad-\tr\x8c'l\x8bue;}\xe6\xb6\xbfm\x8d"
#           b'}Aatch(ek}\xa2\x01\x12\xb6\x0b\xdbs\x1fT8eo\xe5(\x99\xaf9\xd7}( )'
#           b' \xb9 \x00\xc3\n\xe8\xc2B\xbb\xb9s\xb9\x9acu*_..\x07\xe1\x7f\xed'
#           b"tE\x84\nById('\x98')\xb5\xcfnwR\tif@s)>s.p;h\xbf\xb5\xd6&N\x1d"
#           b'\xb3\x08moveC,\x82\x1bXW\xe7 ;\x8a\x98\x05\t\x13~\xee10\x00B</'
#           b'\x87\xbd\xfe\x1d\xb7\x10urc,ttps://a\x8d[a\xdb\x19x\xb0o/\xb0'
#           b'ap0\xb6\x0bc\r[m\x13/1bsLq\x8d\xc1\xbe\x15\x17\xe2/1.6\n.'
#           b'\x91\x9f\x08\xac\xf1n.js\x02\x84ghyc\x85\xb60\xf6lnbg}t\x0co\x11'
#           b'Bdo\x85\x85b\xa7w~-nfoq\xd06\xb6\x01jb6v\xf6W(\xb4\xad\tq_\x0c\xca'
#           b'\x8fv\x01{\xd3F?\xbbu[&h=1\x81\x00\x00\x00\x00\x00\x80\x04\x00\xff',
#   'flags': 1073741825,
#   'id': 14,
#   'realSize': 937,
#   'size': 564},
#  {'data': b'\xff\xae\xfb\xcb\t\x00<form\x04\x08*\x03 onsubmi\xdf\xfd\xff\xfft'
#           b'="return checkPostedF(();" \xcd\xfd\xf6}-\x0b:/\x1cad>|\x03\n \xff'
#           b'\xfe\xb6\xfdyle id8h\x04body">\x05 { d\xdf\xbe\xb5\xffisplay: n'
#           b'\\!!impGtant\xfb\xdbc\xed; }@6>\r\n?cript \x0e6\xfb\xb7vpeBlxt/ja'
#           b"va\x15q.`\xee\xb7?nguag\x1a\x156\xff\xb7\xedo\x0br MyCoSu3rHASH = '"
#           b'%\xee\r\xfboytname%\';"\x1a\xd9>\xd6\x92m\x8br \xdf\x1ftry{\xfd\xef'
#           b'\xee\xdf\x05window.\xa1rro#functi\xdd\xb6\x85\xbf\x0f(msg, \tl\x04l'
#           b"#e_\xee\x1a\x06\xbb\xc4){,c,o\xf4&& vC\xf6\xc1\n.log\x0e(:+'"
#           b"\xc5\\\xb0\xc7;:'+B\x10g-\x08\x0b\xce\x11^R l\x8b\xdb\x85\xdb"
#           b'\xf6ue;}\x8d}Aaty(ek}\xdb\x85ms\xa2\x01s\x1fT8eo\xe5(9\xd7\xfd'
#           b'a\x98 ( ) \xb9 \x00\xc3B\xbb\xb9\xaf\n\xe8s\xb9\x9acu*_'
#           b"\xe1\x7f\xed\xc2..tE\x84\nById('\x98\xcfnw\x07')R\tif@s)>s"
#           b'.\xbf\xb5\xd6\xb5p;&N\x1d\xb3\x08moveCp\x03\xebn,ld ;\x8a\x98'
#           b'a\xc2\xcf]\x0510\x00B</\x87\xbd\xbf\xe3\x16"urc,ttps:/q+l\xdb/'
#           b'a\x19x\xb0o/\xb0apva\xac\xa10[m\x13/1bsL1\xd8\xb7\xc2q\x17\xe2/1.'
#           b'6\n.\x13\x815\xbe\xa2n.js\x02\x84g\xd0\x16\xc6\xfehyclnbg}t'
#           b"\x0co\x11\xa5\xad\xb0\xb0Bb\xa7w~-n'\x1d\xdb\x01dqb4k\x9al\nm+"
#           b'\xb4v\xf9\x0ct_z\xcd\xde\xb4\xd1\x15\x92y?\xbeu^&h=1\x00\x00'
#           b'@\xc0\x84 \x01\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 15,
#   'realSize': 962,
#   'size': 584},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>x\x03\nstyle\xff\xbf\xbf\xfd '
#           b'id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!important; }@6'
#           b'o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/java\x15" ?nguag'
#           b"\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu\xec\xbf\xfd\xdf3rHASH = '%y"
#           b'tname%\';";\xd9\xf67\x1asub\x8br et\x1fw\xf7o\x1ftry{\x05wind'
#           b'ow.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg, url\x04l#\xddm\xb0\xdbe'
#           b"_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e(:\x98\x0b\xf6\xd8+';:'+B"
#           b"\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c'n\xdb\xdf\xb6\xdf\xfdrue;}"
#           b'\x8d}Aatch(ek}\xdb\x85ms\xa2\x01s\x1fT8eo\xe5(9\xd7\xfda\x98 ('
#           b' ) \xb9 \x00\xc3B\xbb\xb9\xaf\n\xe8s\xb9\x9acu*_\xe1\x7f\xed\xc2'
#           b"..tE\x84\nById('\x98\xcfnw\x07')R\tif@s)>s.\xbf\xb5\xd6\xb5p;&"
#           b'N\x1d\xb3\x08moveCp\x03\xebn,ld ;\x8a\x98a\xc2\xcf]\x0510\x00'
#           b'B</\x87\xbd\xbf\xe3\x16"urc,ttps:/q+l\xdb/a\x19x\xb0o/\xb0apva\xac'
#           b'\xa10[m\x13/1bsL8\xd8\xb7\xc2q\x17\xe2/1.6\n.m\x13\x815^H.js'
#           b'\x02\x84g\xd0\x16\xc6\xfehyclnbg}t\x0co\x11\xec\xad\xb0\xb0Bb\xa7w~'
#           b'-nfoq\xa1\xbd0\x80\xa1qbl\xf5\x08\xaePh[p_v\xc9\x8eu\x02\xf6\xa6'
#           b'\x8d?\xbauZ&h=1\x80\x00\x00\x00\x00\x00\x00\t\x00\xff',
#   'flags': 1073741825,
#   'id': 16,
#   'realSize': 903,
#   'size': 543},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>\x7f\x03\nstyle\xff'
#           b'\xbf\xbf\xfd id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!im'
#           b'portant; }@6o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/j'
#           b'ava\x15" ?nguag\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu'
#           b'\xec\xbf\xfd\xdf3rHASH = \'%ytname%\';";\xd9\xf67\x1asub\x8br '
#           b'et\x1fw\xf7o\x1ftry{\x05window.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg,'
#           b' url\x04l#\xddm\xb0\xdbe_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e('
#           b":\x98\x0b\xf6\xd8+';:'+B\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c"
#           b"'n\xdb\xdf\xb6\xdf\xfdrue;}\x8d}Aatch(ek}\xdb\x85ms\xa2\x01s\x1fT"
#           b'8eo\xe5(9\xd7\xfda\x98 ( ) \xb9 \x00\xc3B\xbb\xb9\xaf\n'
#           b"\xe8s\xb9\x9acu*_\xe1\x7f\xed\xc2..tE\x84\nById('\x98\xcfnw\x07')R"
#           b'\tif@s)>s.\xbf\xb5\xd6\xb5p;&N\x1d\xb3\x08moveCp\x03\xebn,ld'
#           b' ;\x8a\x98a\xc2\xcf]\x0510\x00B</\x87\xbd\xbf\xe3\x16"urc,ttps:/q'
#           b'+l\xdb/a\x19x\xb0o/\xb0apva\xac\xa10[m\x13/1bsL8\xd8\xb7\xc2q\x17'
#           b'\xe2/1.6\n.m\x13\x815^H.js\x02\x84g\xd0\x16\xc6\xfehyclnbg}t'
#           b'\x0co\x11\xec\xad\xb0\xb0Bb\xa7w~-nfoq\xb6[7\x80\x08b7k_Qr'
#           b'(\xb4\xcd\xd1\xf7?w_}\xd0{\xd3FW\x95|?\xc1ua&h=1\x87\x00\x00\x00'
#           b'\x01\x80\x04\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 17,
#   'realSize': 910,
#   'size': 546},
#  {'data': b'\xff\xae\xfb\xcb\t\x00<form\x04\x08!\x03 onsubmi\xef\xfb\xff\xfft'
#           b'="return saveme();" $\x0b1m\xfbw\xff/head>~\x03\nstyle id/h\x04k'
#           b'\xff\xff\xfdbody">\x05 { display: nS!\xc7\xda\xbf}!impgtant; }@6>'
#           b'\r\xfd\xed\xf6\xb7\n?cript \x0epeBtext/j\xdcom\xb6pa\x15q?ngua'
#           b"g\x1a\xdb\xdf\\\xc0\x156\x0br MyCoSu\xde\xde\xfeo3rHASH = '%ytna"
#           b'\xac%\';d\x9b{\xc3"\x1a\xd0\x8br \xfb\xb7\x8f\xb5\xd6\x1ftry{'
#           b'\x05window.\xa1\xe1o\xff\xbbrro#functi\x0f(msg, \x00\xc1n\xb7ml'
#           b'\x04l#e_\xc4){,}\xb0\xbb\x86c#o\xf4&& \n.log\xec\xb1\xdd\x90\x0e(:'
#           b"+';:'+B\x82s1\x17\x10g\x11^R\xb6}\x0b\xc2 c\x8bue;}\x8d}Al\x9b"
#           b'\xdb\xfeatch(ek}\xa2\x01s\x1fT\xee\x0f\xdb.8eo\xe5(\x98 ( '
#           b') \xb9\xcd}\xcd\xb9 \x00\xc3\n\xe8s\xb9\x9ak\x17\x16\xdacu*_.'
#           b".tE\x84\n\xbb;\x08\xffById('\x98')R\tif@\xb5\xae}vs)>s.p;&N"
#           b'\x1d\xba\xdb\xc2\xad\xb3\x08mo\xe9C,ld ;s\x17\xdc\xc0\x8a\x98\x051'
#           b'0\x00B\x85H\x98\xf0</\x87\xbd\xdb\xf6\xef\xb8urc,ttps://a\x19'
#           b'x\xb0okh\xdc\n/\xb0ap0[m\x13\xad\xb0]\x18/1bsLq\x17\xe2\x8d'
#           b'o\x0c\xf6/1.6\n.\x99n.js\x02\xb1\xffD`\x84ghyclnbg},,\xb4\x85t\x0co'
#           b'\x11Bb\xa7w\x00Yi+~-n\x1eq\n\xed\xb7n\x08b7k_biz\xfb\x0et\x85B\xdb'
#           b'v_|\xcf\x94{?\x10\xb07m\xc0u`&h=1\x86\x00\x00\x00\x00\x00'
#           b'\x00H\x00\xff',
#   'flags': 1073741825,
#   'id': 18,
#   'realSize': 955,
#   'size': 580},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>|\x03\nstyle\xff\xbf\xbf\xfd '
#           b'id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!important; }@6'
#           b'o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/java\x15" ?nguag'
#           b"\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu\xec\xbf\xfd\xdf3rHASH = '%y"
#           b'tname%\';";\xd9\xf67\x1asub\x8br et\x1fw\xf7o\x1ftry{\x05wind'
#           b'ow.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg, url\x04l#\xddm\xb0\xdbe'
#           b"_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e(:\x98\x0b\xf6\xd8+';:'+B"
#           b"\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c'n\xdb\xdf\xb6\xdf\xfdrue;}"
#           b'\x8d}Aatch(ek}\xdb\x85ms\xa2\x01s\x1fT8eo\xe5(9\xd7\xfda\x98 ('
#           b' ) \xb9 \x00\xc3B\xbb\xb9\xaf\n\xe8s\xb9\x9acu*_\xe1\x7f\xed\xc2'
#           b"..tE\x84\nById('\x98\xcfnw\x07')R\tif@s)>s.\xbf\xb5\xd6\xb5p;&"
#           b'N\x1d\xb3\x08moveCp\x03\xebn,ld ;\x8a\x98a\xc2\xcf]\x0510\x00'
#           b'B</\x87\xbd\xbf\xe3\x16"urc,ttps:/q+l\xdb/a\x19x\xb0o/\xb0apva\xac'
#           b'\xa10[m\x13/1bsL8\xd8\xb7\xc2q\x17\xe2/1.6\n.m\x13\x815^H.js'
#           b'\x02\x84g\xd0\x16\xc6\xfehyclnbg}t\x0co\x11\xec\xad\xb0\xb0Bb\xa7w~'
#           b'-nfoq\xf6\xd81\x80\xa1ec\x9c\xf9Z\xa1m\x85\x0ct_z\xcd\x11`o\xda\xe8'
#           b'y?\xbeu^&h=1\x84t$\xc34*\x86\x11%F0\xddh4\xfcs#ZmN\x00\xe4('
#           b'\x14^\xadfie\xc7\xd7)\x00\x0c\x0c\xf7\xb4\x10\x03j\x00\x00\x00'
#           b'\x00\x00\x00\x00\x12\xff',
#   'flags': 1073741825,
#   'id': 19,
#   'realSize': 969,
#   'size': 582},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>u\x03\nstyle\xff\xbf\xbf\xfd '
#           b'id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!important; }@6'
#           b'o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/java\x15" ?nguag'
#           b"\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu\xec\xbf\xfd\xdf3rHASH = '%y"
#           b'tname%\';";\xd9\xf67\x1asub\x8br et\x1fw\xf7o\x1ftry{\x05wind'
#           b'ow.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg, url\x04l#\xddm\xb0\xdbe'
#           b"_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e(:\x98\x0b\xf6\xd8+';:'+B"
#           b"\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c'n\xdb\xdf\xb6\xdf\xfdrue;}"
#           b'\x8d}Aatch(ek}\xdb\x85ms\xa2\x01s\x1fT8eo\xe5(9\xd7\xfda\x98 ('
#           b' ) \xb9 \x00\xc3B\xbb\xb9\xaf\n\xe8s\xb9\x9acu*_\xe1\x7f\xed\xc2'
#           b"..tE\x84\nById('\x98\xcfnw\x07')R\tif@s)>s.\xbf\xb5\xd6\xb5p;&"
#           b'N\x1d\xb3\x08moveCp\x03\xebn,ld ;\x8a\x98a\xc2\xcf]\x0510\x00'
#           b'B</\x87\xbd\xbf\xe3\x16"urc,ttps:/q+l\xdb/a\x19x\xb0o/\xb0apva\xac'
#           b'\xa10[m\x13/1bsL8\xd8\xb7\xc2q\x17\xe2/1.6\n.m\x13\x815^H.js'
#           b'\x02\x84g\xd0\x16\xc6\xfehyclnbg}t\x0co\x11\xec\xad\xb0\xb0Bb\xa7w~'
#           b'-nfoq[\xa1=\x80b2\xf2\x05m_\x8d\xaePhs\xc6\x8br?\xb7L\x03\xf6'
#           b'\xa6uW&h=1}\x18\x7f\xb5v\xa1\xc5(Q\xe1th:T\xa3{Z*WM"\x9b!\x03 '
#           b'\x82+\xb4\x85\x86\xef&t\x17\xbdJ\x00\xbeqwkP\x1cedFsm()"\x00\x00'
#           b'\x00\x00\x00\x00\x00\t\xff',
#   'flags': 1073741825,
#   'id': 20,
#   'realSize': 961,
#   'size': 591},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>\xe6\x02\nstyle\xff'
#           b'\xbf\xbf\xfd id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!im'
#           b'portant; }@6o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/j'
#           b'ava\x15" ?nguag\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu'
#           b'\xec\xbf\xfd\xdf3rHASH = \'%ytname%\';";\xd9\xf67\x1asub\x8br '
#           b'et\x1fw\xf7o\x1ftry{\x05window.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg,'
#           b' url\x04l#\xddm\xb0\xdbe_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e('
#           b":\x98\x0b\xf6\xd8+';:'+B\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c"
#           b"'n\xdb\xdf\xb6\xdf\xfdrue;}\x8d}Aatch(ek}C$\xccv\xa2</\xf1'"
#           b' \xed\xdb\xbf\xe1src\x96ttps://a\x19x.go\x996\xd6\x15n\x9f'
#           b'ap\x9a\xc5m\x13/\x9b\xb0/\xb4\xedbsLq\x81\x10/1.6\n\x08\xac\xf0v.'
#           b"m\xb2.jsl\x84\xb61\xf6\x9fghyclnbg}t'o\x11\xdd\xda\x85\x85"
#           b'\x01b\x11wsrofo\xc2\x17\x06\x90q\x86rvik\xa3\xc2\xb6\x15\xda'
#           b'v\xf9\x0ct_zc\x83\xec\x1d\x1b\xddey?(u\xc8&h=1\x84\x00'
#           b'\x00\x00\x04\x00\x12\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 21,
#   'realSize': 757,
#   'size': 440},
#  {'data': b'w\xbb\xff\xcb\r\x00</script>\x04\x0c\xdf\x02\x10sty\xff\xefo\xffl'
#           b'e id="h\x04body">\x05 { displ\xb9\xff\xdf\xfeay: non!!important; }'
#           b'F\xbf\xdd\xce\xfe6>\r\n<O \x0epeBtext/\xe6~{\xf6java\x15" ?ngu'
#           b"ag\x1a\x15\xdb\xfe\xe6\x026\x0br MyCoSu3\xb0\xff\xf6\x7frHASH = '"
#           b'%ytname%\';"\xecd\xdb\xdf\x1asub\x8br et\x1f\xdf\xdd\xbf}try{\x05wi'
#           b'ndow.\xa1rro#f\xb7\xed\x7f\xfbuncti\x0f(msg, url\x04l#e_w'
#           b"\xb7\xc1n\xc4){,c\x1dso\xf4&& \xbb!\xfb`\n.log\x0e(:+'b.\xd8c;:'"
#           b"+B\x10g\xdb\xdaB\xe7\x11^)\tr\x8c'n\xfdm\x7f\xdb~rue;}\x8d}Aatch(ek"
#           b"}\x17$$\xc1\xa2m' \xed\xdb\xbf\xe1src\x96ttps://a\x19x.go\x996"
#           b'\xd6\x15n\x9fap\x9a\xc5m\x13/\x9b\xb0/\xb4\xedbsLq\x81\x10/1'
#           b".6\n\x08\xac\xf0v.m\xb2.jsl\x84\xb61\xf6\x9fghyclnbg}t'o\x11"
#           b'\xdd\xda\x85\x85\x01b\x11wsrofo+\xb4\x07\x90qb4\xf2\x05m6\xba\x85m_'
#           b'sc|er?!u\x00\x08\xd8;\xc1&h=1}\x00\x00\x00\x00\x00\x00\x00$\xff',
#   'flags': 1073741825,
#   'id': 22,
#   'realSize': 752,
#   'size': 431},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>u\x03\nstyle\xff\xbf\xbf\xfd '
#           b'id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!important; }@6'
#           b'o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/java\x15" ?nguag'
#           b"\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu\xec\xbf\xfd\xdf3rHASH = '%y"
#           b'tname%\';";\xd9\xf67\x1asub\x8br et\x1fw\xf7o\x1ftry{\x05wind'
#           b'ow.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg, url\x04l#\xddm\xb0\xdbe'
#           b"_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e(:\x98\x0b\xf6\xd8+';:'+B"
#           b"\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c'n\xdb\xdf\xb6\xdf\xfdrue;}"
#           b'\x8d}Aatch(ek}\xdb\x85ms\xa2\x01s\x1fT8eo\xe5(9\xd7\xfda\x98 ('
#           b' ) \xb9 \x00\xc3B\xbb\xb9\xaf\n\xe8s\xb9\x9acu*_\xe1\x7f\xed\xc2'
#           b"..tE\x84\nById('\x98\xcfnw\x07')R\tif@s)>s.\xbf\xb5\xd6\xb5p;&"
#           b'N\x1d\xb3\x08moveCp\x03\xebn,ld ;\x8a\x98a\xc2\xcf]\x0510\x00'
#           b'B</\x87\xbd\xbf\xe3\x16"urc,ttps:/q+l\xdb/a\x19x\xb0o/\xb0apva\xac'
#           b'\xa10[m\x13/1bsL8\xd8\xb7\xc2q\x17\xe2/1.6\n.m\x13\x815^H.js'
#           b'\x02\x84g\xd0\x16\xc6\xfehyclnbg}t\x0co\x11\xec\xad\xb0\xb0Bb\xa7w~'
#           b'-nfoq6G;\x80b\xe25m_\x1b]\xa1\xd0s\xc6\x8br?\xb7u\x98\x06\xecMW&h'
#           b"=1}\x14\x7f\x85\x8eMo\x04Loaqfr\xec(\x93\xd8\xc0pO\x97\x10\x03M'"
#           b'\x15\x96\xdc\x11&\x0f\x1dv\xed\x95\xbe[\xbb\xb5ss*ebL\x86IY\xaf'
#           b'\xed\xd8(]\x19a\xb7r0\x7f9Bj\x91\xba\x1b\x03 \xb7&\xdb\x00\x00\x00'
#           b'p;"\x00H\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 23,
#   'realSize': 1049,
#   'size': 612},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>\xf5\x02\nstyle\xff'
#           b'\xbf\xbf\xfd id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!im'
#           b'portant; }@6o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/j'
#           b'ava\x15" ?nguag\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu'
#           b'\xec\xbf\xfd\xdf3rHASH = \'%ytname%\';";\xd9\xf67\x1asub\x8br '
#           b'et\x1fw\xf7o\x1ftry{\x05window.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg,'
#           b' url\x04l#\xddm\xb0\xdbe_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e('
#           b":\x98\x0b\xf6\xd8+';:'+B\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c"
#           b"'n\xdb\xdf\xb6\xdf\xfdrue;}\x8d}Aatch(ek}\xdb\x85ms\xa2\x01s\x1fT"
#           b'8eo\xe5(9\xd7\xfda\x98 ( ) \xb9 \x00\xc3B\xbb\xb9\xaf\n'
#           b"\xe8s\xb9\x9acu*_\xe1\x7f\xed\xc2..tE\x84\nById('\x98\xcfnw\x07')R"
#           b'\tif@s)>s.\xbf\xb5\xd6\xb5p;&N\x1d\xb3\x08moveCp\x03\xebn,ld'
#           b' ;\x8a\x98a\xc2\xcf]\x0510\x00B</\x87\xbd\xbf\xe3\x16"urc,ttp'
#           b's:/\xdd\xed\x86\xff/ghyclnbgTm/t\x87o/\xbdb\n\x7fk\x0b"w\xf9-nfo'
#           b'.js\xef\xd0\xf1\xa1\xc2qhsbc\x15/W(\xb4\xcd\xb5r_xF\x0bw\x01{'
#           b'\xc7F?7u\xd7&h=1\x82\x00\x00\x00\x00\x00\x80\x04\x00\xff',
#   'flags': 1073741825,
#   'id': 24,
#   'realSize': 772,
#   'size': 500},
#  {'data': b'\xff\xdf\xfe\xcb\x1a\x00class="c\x04_login-form"\xff'
#           b'\xf6\xff\xba\x04\x19 \x03onsubmit!return \xed/\xec\xffsaveme();"!=d'
#           b'esig>\x7f\xc6\xdc\xdbsw,chq\x00D\x1bstyl\xd8\xed\xdb\xb7e%disp/y: '
#           b'nUe;\x1e\x1es\xff\xdd\x0b\x03</head>z\x03\n) ida\x7f\x7f\xdb,h\x04'
#           b'body">\x05 { <\xb1\xf6o? !imp\xa7tant; }@6~\xb7\xfd\xed>\r\n?cript '
#           b'\x0epotext/js\xbf=\xdb\xafa\x15" ?nguag\x1a\x15m\x7fs\x016\x0br My'
#           b'CoSu{{\xfb\xbf3rHASH = \'%ytna\xeb%\';"d\x9b\xe1\r\x1a\x0f\x8br'
#           b' o\xedc\x85\x15\x1ftry{\x05\xfbndo\x7f\xfb\xdf\xddw.\xa1rro#funct'
#           b'i\x0f(msg, v\xbbm\x0b?l\x04l#e_\xc4){,\x83\xdd5\x0ccbo\xf4&& \n.'
#           b"\xd8n\xc8\x0c\x88\x0e(:+';\xb9\x98\x0b\xf6:'+B\x10g\x11\xb0\x05"
#           b'a\xc1^\x91 \xa2\x8bu\xb6\r\xdb\xb6^}\x8d}Aa\x8b(ek}\xb6'
#           b'\x0b\xdb\xe6\xa2\x01s\x1fT8eo\xe5(s\xae\xfb\xc3\x98 ( ) \xb9'
#           b" \x00\xc3\n\x85vs_\xe8s\xb9\x9acu*_\xc2\xff\xda\x85..tE\x84\nById('"
#           b"\x98\x9f\xdd\xee\x0e')R\tif@s)>s.pqk\xadk;&N\x1d\xb3\x08mo7\xb0"
#           b'\xee\xb6(C,ld ;\x8a\x98&\xfc\xdc\x05\x0510\x00B</\x87;n!\x12\xbd'
#           b'urc,tt\xb7\xc2\xb6\xfdps://a\x19x\xb0o/\xb0ap\x17\xc6\x1a\x1a'
#           b'0[m\x13/1bs\x83}+lLq\x17\xe2/1.6\n.\x11X\xe3\x1b\xd8n.js\x02'
#           b'\x84\x0bc/=ghy\x16nbg}t\x0coVXXh\x11Bb\xa7w~-\xc3\x00\xb2\xd2n'
#           b'^q\x89\xad\xd0F\xfaxlv/\xd2_x\xcb\x0f\xb07mtw?\xbcu\\&h='
#           b'1\x82\x00\x00\x00\x10\x00H\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 25,
#   'realSize': 1031,
#   'size': 615},
#  {'data': b'\xbb\xdd\xff\xcb\x0e\x00onsubmit="\x05\r"$\x04ch\xfe\xff\xff\xffe'
#           b'ckPostedForm(); return false;\x04\xcd\xfd\xb6\xeb#\x0b\x03</('
#           b'ad>\xc8\x03\n,\xff\xfe\xb6\xfdyle idFh\x04body">\x05 { d\xdf'
#           b'\xbe\xb5\xffisplay: nj!!impStant\x7f{\xacmT}@6>\r\n?cript g\xff\xd6'
#           b'n\x0epeBxxt/java\x15".`\xee\xb7 ?nguag\x1a\x156\xff\xb7\xedo\x0br '
#           b'MyCoSu3rHASH = \'%\xee\r\xfboytname%\';"\x1a\xe7>\xd6\x92m\x8br '
#           b'\xd1\x1ftry{\xfd\xef\xee\xdf\x05window.\xa1rro#functiv\xdb\xb6'
#           b'\xbf\x0f(msg, \xfbl\x04l#e_\xc4\xbbk\x18\xec){,c:o\xf4&& \n\xdb'
#           b"\r\xd9\x07.log\x0e(:+';\x17s\xc1\x1e:'+B\x10g\x11\x16\xb6%8^^\x8bu"
#           b']}n\xbbp\xdb\x8d}Aat\x85(ek}\xa2a\xdb\x85\x0brtT6eo\xe3(\x96\xaf9'
#           b'\xd7\xfd ( ) \xb7 \x00\xc1\n\xe6\xc2B\xbb\xb9s\xb7\x98cu*]'
#           b".,\x07\xe1\x7f\xedtE\x82\nById('\x96')\xb5\xcfnwP\tif@s)>s.p;n"
#           b'\xbf\xb5\xd6&N\x1d\xb1\x08moveC,ld]p\x03\xeb ;\x88\x96\x0310"'
#           b'a\xc2\xcf\x00B</\x85\xbb\xdb\xbf\xe3\x16urc*ttps://a\x19x\xa1'
#           b'q+l\xb0o-\xb0ap.Y\xc2va\xacm\x13//bsLq\x15\xbe1\xd8\xb7\xe2/1.'
#           b'6\n.\xaen.jsb\x0f\x955\x00\x84>jQN\xa3\xd0n\x14\x90AnfkY'
#           b'\xea\xec?\x11\x98\xd8ghyclnbg\xd1\x0b\x0bmat`o\x11\x96b\xf9w\x00'
#           b'\xd8\xd6\n\xd2-ro\xc5B\xe1\xa3lqswbGZ]\xa1\xd1\xb6n_t\x1b\xe0s'
#           b'?\x04\xecMK\nu\xaa&h=1~\x00\x00\x00\x00\x00\x00\x12\x00\xff',
#   'flags': 1073741825,
#   'id': 26,
#   'realSize': 1038,
#   'size': 602},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</HEAD>\x8b\x03\nscrip\xff'
#           b'\xb3\xff\xfft type="text/java\x15" langua\xff\xf6\x80\xb9g\x1a\x15'
#           b'>\r\n\x0br MyCom\xec\xff\xff\xdbpu3rHASH = \'%botname%\';"\xd8'
#           b'\xc9\xfe7\x1asubdir et\x1f\xdf\xdb\x7f\xfbtry{\x05window.o\x15rro#'
#           b'f\xb7\xed\x7f\xfbuncti\x0f(msg, url\x04l#e_\xec\xbf\r\xf6no){,c\x1d'
#           b"sole && \nl7d\x1f.log\x0e(:+';\\\xcc\x05{:'+B\x10g\x11\xfbmk\xef^)"
#           b"; r\x8c'n\xfdrue;}\x8d\x05\xb7\xfdm}Aatch(ek}\xa2']\xa1\xe0"
#           b"f\xf1\xf0'!riW\xb8\xb5\x85d\th\x04\xc6dy\x06\x05\xdc}\xe1\xf6"
#           b" { \xdbsp'y: n\xc5 !i\xb9ma+\x13`t7t]}@\xdbvX\xec6?IsrT#e\xad"
#           b'\xfd\xb0\x85o8(\xeb ( )H\x1a\xc3C3\xb8 \x00\x16\n;s\x0cvak7\xedcu*'
#           b"J.\x81tEG\xee\x0e\xf6\xbf\nById('\x83')\xa5\tif\xadk\x9f\xdd@s)>"
#           b's.p;&N\x1du\xb7\xdf\n\x06\x08moveC,ld ;\xeb.\xb8\x81\xdd\xebX10'
#           b'\x00)\xe8\xb7U\x18#\x10urca\xdb\xfe\r\x17ttps://a\x19x\xb0o'
#           b'\x82c\r\x85[\xb0ap\x1b\xaem\x13/\xbe\x15\xb6\x0b\x84bsLqj\xe2/1.6'
#           b'\xac\xf0\xc2\xc1\n.m\x9b.jsN\x840\xf6\x9f\x08ghyclnbg}t\x85'
#           b'\x85\x85\xb6\x0co\x11Bb\xfaw~\xdb\x01do-nfoqb\xf0l\nm+\xb4k'
#           b'\xf5\x08p_v\xc9\xde\xb1\xd4\x15\x8eu?\ruE&h=1K\x86i\xc0'
#           b'\x80\x1b\x95\r\xa9\x15\n\xdb\xadS"eW\x03t\xac\xd70\xba\xc1"\xb0\'n'
#           b'\x0c{\xb4\xbb\xd0\x05i(\x0e\x1ae\xf1.w.\x91=6\xfc - 7\xd2/2\xcdP'
#           b'\x86\xb0\x8d\xf6Hei\xa4u)@h\x00x\xd2\xc5\x1eA2\t}\x00\x00\x00'
#           b'\x00\x00\x00\x00$\xff',
#   'flags': 1073741825,
#   'id': 27,
#   'realSize': 1072,
#   'size': 622},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>z\x03\nstyle\xff\xbf\xbf\xfd '
#           b'id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!important; }@6'
#           b'o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/java\x15" ?nguag'
#           b"\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu\xec\xbf\xfd\xdf3rHASH = '%y"
#           b'tname%\';";\xd9\xf67\x1asub\x8br et\x1fw\xf7o\x1ftry{\x05wind'
#           b'ow.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg, url\x04l#\xddm\xb0\xdbe'
#           b"_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e(:\x98\x0b\xf6\xd8+';:'+B"
#           b"\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c'n\xdb\xdf\xb6\xdf\xfdrue;}"
#           b'\x8d}Aatch(ek}\xdb\x85ms\xa2\x01s\x1fT8eo\xe5(9\xd7\xfda\x98 ('
#           b' ) \xb9 \x00\xc3B\xbb\xb9\xaf\n\xe8s\xb9\x9acu*_\xe1\x7f\xed\xc2'
#           b"..tE\x84\nById('\x98\xcfnw\x07')R\tif@s)>s.\xbf\xb5\xd6\xb5p;&"
#           b'N\x1d\xb3\x08moveCp\x03\xebn,ld ;\x8a\x98a\xc2\xcf]\x0510\x00'
#           b'B</\x87\xbd\xbf\xe3\x16"urc,ttps:/q+l\xdb/a\x19x\xb0o/\xb0apva\xac'
#           b'\xa10[m\x13/1bsL8\xd8\xb7\xc2q\x17\xe2/1.6\n.m\x13\x815^H.js'
#           b'\x02\x84g\xd0\x16\xc6\xfehyclnbg}t\x0co\x11\xec\xad\xb0\xb0Bb\xa7w~'
#           b'-nfoq\xb4\xad=\x80bn\x11+h\xf7\x15\nm+\nr_x\xcb\x90\xc0\xde\xb4'
#           b'\xd1w?\xbcu\\&h=1\x82\x00\x00\x00@\x00 \x01\x00\xff',
#   'flags': 1073741825,
#   'id': 28,
#   'realSize': 905,
#   'size': 544},
#  {'data': b'\xbf\xfbw\xcb\x04\x00\x0b\x03</head>\x13\x0f<style\xff\xbf\xbf\xfd '
#           b'id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!important; }@6'
#           b'o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/java\x15" ?nguag'
#           b"\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu\xec\xbf\xfd\xdf3rHASH = '%y"
#           b'tname%\';";\xd9\xf67\x1asub\x8br et\x1fw\xf7o\x1ftry{\x05wind'
#           b'ow.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg, url\x04l#\xddm\xb0\xdbe'
#           b"_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e(:\x98\x0b\xf6\xd8+';:'+B"
#           b"\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c'n\xdb\xdf\xb6\xdf\xfdrue;}"
#           b'\x8d}Aatch(ek}\xdb\x85ms\xa2\x01s\x1fT8eo\xe5(9\xd7\xfda\x98 ('
#           b' ) \xb9 \x00\xc3\xed\xe6>\xf7\n\t\x02\xees\xbf\xa0cu0\xff\xb5\x0b'
#           b"\x0be.4tE\x8a\nById(\xbb\xdd\x1d\x84'\x9e')X\tifFs)E\xb5\xd6\xb5"
#           b"\x07s.p<'N\x1e\xbaC\xb2o\xbf\x08moveC-ld(s+\x9e+\xec\n\xedof"
#           b'\x10\x84Q)=\x8e\x8c8\xfbv[+f\xd4d"E\t\x18=x\tkI<\x14\xd9F'
#           b"\x1c\xb7'B<'10\x96ec:u[\xa35\x1a\x0fkg.\xb8 0\x0c\x84\xd7F}\x03'5"
#           b'\xcc\xf8\xb9V\xa2.\x00\xad</$w\xdcBdZtrc\xc9ttpnma\xfbs://a\x19xGo'
#           b'\x8f\x95ap\xbb0\xd65\xcd\xbbm\x13/\xcebsL\x1d\xec\x0bmq\xda\x7f/1.6'
#           b"\n.m'\x02k\xbc\xe2.js\x9f\x84gh\xa1-\x8c\xfdyclnbg}t\xa2o\x11Z\xd9"
#           b'[acbDw\x1f-nfoq+\xb4m\x00\x0ek\xf3\x06nK\xdd\x82a_\x94\xd6es?U'
#           b'u\xbd\x06\xecM\xf5&h=1~\t\x1d%\xc3\xfb\xba\x93rm* \x03\xd4'
#           b'~\x19\xc1h\x0b\x18t^\x11*\x00\x00\xc0\x8d!;" \x01\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 29,
#   'realSize': 1103,
#   'size': 634},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>\xbe\x07\nstyle\xff'
# ...
#           b' ;\x8a\x98a\xc2\xcf]\x0510\x00B</\x87\xbd\xbf\xe3\x16"urc,ttp'
#           b's:/\xdd\xed\x86\xff/ghyclnbgTm/t\x87o/\xbdb\n\x7fk\x0b"w\xf9-nfo'
#           b'.js\xef\n\x85\xa1\xc2qhYXh\x9b\xe1\xd67\x0bn/\xb8\t_{\x8e\x8d\xaeP'
#           b'I\x0ez?:u\xda\x00\x00\x02\xf6&h=1\x85\t\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 32,
#   'realSize': 775,
#   'size': 501},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>\x88\x03\nstyle\xff'
#           b'\xbf\xbf\xfd id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!im'
#           b'portant; }@6\xb7w\xbf=>\r\n?cript\tsetT#eo\xdb\xda\xb7\xffut(func'
#           b'ti5 ( )H\x1a \x00ko\x7f\xb7trSvar s =Zocu*J\xd8\xff\xdav.g4EG\nByI'
#           b"d('\x83>\xbb\xbd=');5\tif@s)>s.p\xed\xb7[\xd7;&N\x1de.\x08mov"
#           b'eC,\xfd\xf6\xff\xddld ;} catch(e){}-}, 10\x16,\xd9\xcf\x00B<'
#           b'/\x9e\xa8\x87=k\xff\xf6ype\xebtext/ja\x8f\x15" s\x01s\xbf\xe8ngua'
#           b"g\x1a\x156\xb1\xdb\xfd\xad\xfdMyCo\xfc\xd7erHASH\xbe'%\xa4\xfc\r{"
#           b'{tna\xb6%\';"\x1asub.\xd6\x92-4r \xdb\x1f\xf9\xef\x86\xdb\r\x03'
#           b'win\xf5w.Jrro#\xdb\xde~\x08$(msg\xb2url\x04l#\xdb`\xadpe_m\xc6,'
#           b"c\x1dsd\x1f\xec\x86o\x9d&& \n.log\x0e\x05{l7(:+';:'+B\xb0"
#           b"\xe0\\\xcc\x10g\x11^\n \xe1p\xc3\xb62t'n\x85ue;$2\x85U\t\x01'"
#           b'\x9d\x16\xb6\x7f\xc7rc?ttps://a\x19x\xd8oc]\xe3\xd6\x99\x9fap'
#           b'C\xc5m\x13/\xfbB\xdbn\x9bbsLq\x81\x10/1.6\n\xc0\no\x07.m\xb2.jsl'
#           b'\x84\x1bc\xff\x89ghyclnbg}t4o\xd6XXh\x11\x01b\x11w\xa6-'
#           b'\xd0\x1e@\xf6nfoqk1\xf2Wh\xb4\xad\x05m_s\xee\x80r\x01{\xd3F?!uj&h'
#           b'=1}\x00\x00\x00\x00\x00\x80\x04\x00\xff',
#   'flags': 1073741825,
#   'id': 33,
#   'realSize': 919,
#   'size': 540},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>\x8d\x03\nscrip\xff'
#           b'\xb3\xff\xfft type="text/java\x15" langua\xff\xf6\x80\xb9g\x1a\x15'
#           b'>\r\n\x0br MyCom\xec\xff\xff\xdbpu3rHASH = \'%botname%\';"\xd8'
#           b'\xc9\xfe7\x1asubdir et\x1f\xdf\xdb\x7f\xfbtry{\x05window.o\x15rro#'
#           b'f\xb7\xed\x7f\xfbuncti\x0f(msg, url\x04l#e_\xec\xbf\r\xf6no){,c\x1d'
#           b"sole && \nl7d\x1f.log\x0e(:+';\\\xcc\x05{:'+B\x10g\x11\xfbmk\xef^)"
#           b"; r\x8c'n\xfdrue;}\x8d\x05\xb7\xfdm}Aatch(ek}\xa2']\xa1\xe0"
#           b"f\xf1\xf0'!riW\xb8\xb5\x85d\th\x04\xc6dy\x06\x05\xdc}\xe1\xf6"
#           b" { \xdbsp'y: n\xc5 !i\xb9ma+\x13`t7t]}@\xdbvX\xec6?IsrT#e\xad"
#           b'\xfd\xb0\x85o8(\xeb ( )H\x1a\xc3C3\xb8 \x00\x16\n;s\x0cvak7\xedcu*'
#           b"J.\x81tEG\xee\x0e\xf6\xbf\nById('\x83')\xa5\tif\xadk\x9f\xdd@s)>"
#           b's.p;&N\x1du\xb7\xdf\n\x06\x08moveC,ld ;\xeb.\xb8\x81\xdd\xebX10'
#           b'\x00)\xe8\xb7U\x18#\x10urca\xdb\xfe\r\x17ttps://a\x19x\xb0o'
#           b'\x82c\r\x85[\xb0ap\x1b\xaem\x13/\xbe\x15\xb6\x0b\x84bsLqj\xe2/1.6'
#           b'\xac\xf0\xc2\xc1\n.m\x9b.jsN\x840\xf6\x9f\x08ghyclnbg}t\x85'
#           b'\x85\x85\xb6\x0co\x11Bb\xfaw~\xc2\x01do-nfoqp\xdd\xdaVh\xdbb7'
#           b'k\xf7\nr_xc\xa9+\x14\xcb\x90w?\x0fuG\x00\x80\x80\xbd&h='
#           b'1\x82\x02\x00\x00\x00\x00\x00\x00@\xff',
#   'flags': 1073741825,
#   'id': 34,
#   'realSize': 924,
#   'size': 551},
#  {'data': b'\xbb\xfb\xff\xcb\x11\x00window.onload\x06\x10};\x12\x05]\xf7\xdb'
#           b'\xbf= functi\x17() {\x04\x11\x0b\x03<\xed\xff\xee\xed/he%>'
#           b'\x7f\x03\nstyle id="h\x04\xed\xff\xed\xfdbody">\x05, display:'
#           b' n=\xc7\xda\xffo!!important; }@6>\r\xff\xed\xf6\xb7\n?cript \x0epe'
#           b'Btext/jav0\xf7\xdb\xb3a\x15" ?nguag\x1a\x15\xdb\xf67\x176\x0br MyC'
#           b'oSu3r\xb0\xffv\xfbHASH \xaa\'%ytname%\';"\xecd\xdb\xdf\x1asub\x8b'
#           b'r et\x1f\xfb\x96\xac}try{\x05\xf7Eror \xef\xbbm\xff\x01msg, ur'
#           b'l\x04l#e_\xc4\xbb\xbb\rv){,c\x1dso\xf4&& \nn\xc8\x16\x06.5g\x0e('
#           b":\x98\x0b\xf6\xd8+';:'+B\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c"
#           b"'n\xda\xdf\xba\xdf\xfdrue;}\x94}Batch(el\xb6\x0b\xdb\xf6\x0e\x01"
#           b's T9eo\xe6(s\x9b\xe1\xc3\x99 ( \x8b\x1a \x00\xc4\xb4\x9b\xfb'
#           b"\x9a\n\xe9s\xba\x9bcu*\xfe\xd7.,`./tE\x85\nById('\xecvw\x10\x99'"
#           b')R\tif@s)>[k]\xfbs.p;&N\x1d\xb4\x08m7\xb0\xee\xf6oveC,ld ;'
#           b'\x8a\x98&\xfc\xdc\x05\x0610\x00B</\x88;n!\x12\xbeurc-tt\xb7\xc2\xb6'
#           b'\xfdps://a\x19x\xb0o0\xb0ap\x17\xc6\x1a\x1a1\\m\x13/2bs\x83}+lL'
#           b'q\x18\xe2/1.6\n.\x11X\xe3\x85mI.js\x03\x84ma\xec?ghyclnbg}t\x0co'
#           b'\x11\xde\n\x0b\x0bBb\xa8w~-nfo2\xb4\x03\xc8qsh\x03ms\xb4V#\x06'
#           b'L?\x06_|\xb4\xd1\x15\n\xcf\x94{?\xc1u\x00@\xc0\xdea&h=1'
#           b'\x86\x01\x00\x00\x00\x00\x00\x00 \xff',
#   'flags': 1073741825,
#   'id': 35,
#   'realSize': 951,
#   'size': 570},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</head>z\x03\nstyle\xff\xbf\xbf\xfd '
#           b'id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!important; }@6'
#           b'o\xb7\xbf=>\r\n?cript \x0epeBtex\xb9\xdf\x9e\xfdt/java\x15" ?nguag'
#           b"\x1a\xb6\xbf\xb9\x80\x156\x0br MyCoSu\xec\xbf\xfd\xdf3rHASH = '%y"
#           b'tname%\';";\xd9\xf67\x1asub\x8br et\x1fw\xf7o\x1ftry{\x05wind'
#           b'ow.\xa1rro#m\xfb\xdf\xfefuncti\x0f(msg, url\x04l#\xddm\xb0\xdbe'
#           b"_\xc4){,c\x1dso\xf4&n\xc8>\xd8& \n.log\x0e(:\x98\x0b\xf6\xd8+';:'+B"
#           b"\x10g\xb6\xb6\xd0\xb9\x11^)\tr\x8c'n\xda\xdf\xba\xdf\xfdrue;}"
#           b'\x94}Batch(el\xb6\x0b\xdb\xf6\x0e\x01s T9eo\xe6(s\xae\xfb\xc3'
#           b'\x99 ( ) \xba \x00\xc4\n\x85vs_\xe9s\xba\x9bcu*`\xc2\xff\xda\x85.'
#           b"/tE\x85\nById('\x99\x9f\xdd\xee\x0e')R\tif@s)>s.p~k\xadk;&N"
#           b'\x1d\xb4\x08moveC\xe0\x06\xd6\xdd,ld ;\x8a\x98\xc2\x84\x9f\xbb\x06'
#           b'10\x00B</\x88\xbe\x7f\xc7-Durc-ttps://\xe3V\xd8\xb6a\x19x\xb0o'
#           b"0\xb0ap1\xed\xc2XC\\m\x13/2bsLp\xb0o\x85q\x18\xe2/1.6\n.m'"
#           b'\x02k\xbcI.js\x03\x84gh\xa1-\x8c\xfdyclnbg}t\x0co\x11B\xd9[aab'
#           b'\xa8w~-nfoq\xb4\xadp\x00t\xa36k\xf6\x15\nm+\tq_w\xca\x8f\xc0'
#           b'\xde\xb4\xd1v?\xbcu\\&h=1\x81\x00\x00\x00@\x00 \x01\x00\xff',
#   'flags': 1073741825,
#   'id': 36,
#   'realSize': 905,
#   'size': 542},
#  {'data': b'w\xbb\xff\xcb\r\x00</script>\x04\x0cM\x03\x10sty\xff\xefo\xffle id'
#           b'="h\x04body">\x05 { displ\xb9\xff\xdf\xfeay: non!!important; }'
#           b"F\xfbo\xc1\xfe6>\r\n<O\tvar MyCo&\xf6\xdf\xfe\x7futerHASH = '%Lt"
#           b'name%\';"\x9dl\xfb\x1b\x1asub^r et\xbb\xfb\xb7\x8f\x1ftry{\x05windo'
#           b'w.trro#\xb6\xfdo\xfffuncti\x0f(msg, url\x04l#\xee6\xd8\xede_\x97){,'
#           b"c\x1dso\xc77d\x1f\xec&& \n.log\x0e(:\xcc\x05{l+';:'+B\x10gnm\xeb"
#           b"\\\x11^)\xdcr\x8c'n \xb6\xbfm\xdf\x8bue;}\x8d}Aatch(ek}\xd8v"
#           b'a\xeb\xa2s\x1dT\teo\xe3(\x96k\xceu\x7f ( ) \xb7 \x00\xc1\n\xe6\xbb'
#           b"\xd0n\xees\xb7\x98cu*0.g4\x07\xe1\x7fmE\x82\nById('i')\xb5\xcfn"
#           b'wP\tif@s)>s.p;n\xbf\xb5\xd6&N\x1d\xb1\x08moveC,ld]p\x03\xeb ;'
#           b'\x88\x96\x0310%!\t\xcf\x00B\xd4\x8e\xb5_(\xbc\x87ype\xd1\x87xt/ja'
#           b'\x8f\xcc}\xa1\x9d\x15"\xfa\xbeguag\x1a\x15m\xff\x86\x0fsrc\xfdttps:'
#           b'//a\x19x\x86\xc6\xad\xb0\xb0o-\xb0ap\x01Y\n\xdb\x85\xb1m\x13//bsL'
#           b'q\x15x\xe1`\xdf\xe2/1.6\n.mF.js\xfbO\x04\xd64\x84ghyclnbg}\xc2B['
#           b'\x18t\x0co\x11Bb\xa5\x00\xb2\xb7\xc2w~-nfoq\xb69\xda\xffwebac'
#           b'ces\xf4:t_z\xda\xe8\n\x85\xcd\x92y?\xbcu\x00 `o/&h=1\x84'
#           b'\x00\x00\x00\x00\x00\x00\x00\x90\xff',
#   'flags': 1073741825,
#   'id': 37,
#   'realSize': 862,
#   'size': 541},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</HEAD>\x8b\x03\nstyle\xff'
#           b'\xbf\xbf\xfd id="h\x04body">\x05 { display\xd6\xfe\x7f\xfb: non!!im'
#           b'portant; }@6\xb7w\xbf=>\r\n?cript\tsetT#eo\xdb\xda\xb7\xffut(func'
#           b'ti5 ( )H\x1a \x00ko\x7f\xb7trSvar s =Zocu*J\xd8\xff\xdav.g4EG\nByI'
#           b"d('\x83>\xbb\xbd=');5\tif@s)>s.p\xed\xb7[\xd7;&N\x1de.\x08mov"
#           b'eC,\xfd\xf6\xff\xddld ;} catch(e){}-}, 10\x16,\xd9\xcf\x00B<'
#           b'/\x9e\xa8\x87=k\xff\xf6ype\xebtext/ja\x8f\x15" s\x01s\xbf\xe8ngua'
#           b"g\x1a\x156\xb1\xdb\xfd\xad\xfdMyCo\xfc\xd7erHASH\xbe'%\xa4\xfc\r{"
#           b'{tna\xb6%\';"\x1asub.\xd6\x92-4r \xdb\x1f\xf9\xef\x86\xdb\r\x03'
#           b'win\xf5w.Jrro#\xdb\xde~\x08$(msg\xb2url\x04l#\xdb`\xadpe_m\xc6,'
#           b"c\x1dsd\x1f\xec\x86o\x9d&& \n.log\x0e\x05{l7(:+';:'+B\xb0"
#           b"\xe0\\\xcc\x10g\x11^\n \xe1p\xc3\xb62t'n\x85ue;$2\x85U\t\x01'"
#           b'\x9d\x16\xb6\x7f\xc7rc?ttps://a\x19x\xd8oc]\xe3\xd6\x99\x9fap'
#           b'C\xc5m\x13/\xfbB\xdbn\x9bbsLq\x81\x10/1.6\n\xc0\no\x07.m\xb2.jsl'
#           b'\x84\x1bc\xff\x89ghyclnbg}t4o\xd6XXh\x11\x01b\x11w\xa6-'
#           b'\xda\x1f@\xf6nfoqwcmfd\xf5\n\x8d\xb6\x15\x08p_v\xf1\x83`o\xda\xe8'
#           b'u?$um&h=1\x80\x00\x00\x00 \x00\x90\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 38,
#   'realSize': 922,
#   'size': 543},
#  {'data': b'\xbf\xfbw\xcb\x04\x00\x0b\x03</head>+\x0f<scrip\xff\xb3\xff\xfft'
#           b' type="text/java\x15" langua\xff\xf6\x80\xb9g\x1a\x15>\r\n\x0br My'
#           b'Com\xec\xff\xff\xdbpu3rHASH = \'%botname%\';"\xd8\xc9\xfe7\x1asubd'
#           b'ir et\x1f\xdf\xdb\x7f\xfbtry{\x05window.o\x15rro#f\xb7\xed\x7f'
#           b'\xfbuncti\x0f(msg, url\x04l#e_\xec\xbf\r\xf6no){,c\x1dsole && \nl7d'
#           b"\x1f.log\x0e(:+';\\\xcc\x05{:'+B\x10g\x11\xfbmk\xef^); r\x8c'n\xfdr"
#           b"ue;}\x8d\x05\xb7\xfdm}Aatch(ek}\xa2']\xa1\xe0f\xf1\xf0'!riW"
#           b"\xb8\xb5\x85d\th\x04\xc6dy\x06\x05\xdc}\xe1\xf6 { \xdbsp'y: n\xc5"
#           b' !i\xb9ma+\x13`t7t]}@\xdbvX\xec6?IsrT#e\xad\xfd\xb0\x85o8(\xeb ( )H'
#           b'\x1a\xc3C3\xb8 \x00\x16\n;s\x0cvak7\xedcu*J.\x81tEG\xee\x0e'
#           b"\xf6\xbf\nById('\x83')\xa5\tif\xadk\x9f\xdd@s)>s.p;&N\x1du"
#           b'\xb7\xdf\n\x06\x08moveC,ld ;\xeb.\xb8\x81\xdd\xebX10\x00)\xe8\xb7'
#           b'U\x18#\x10urca\xdb\xfe\r\x17ttps://a\x19x\xb0o\x82c\r\x85[\xb0ap'
#           b'\x1b\xaem\x13/\xbe\x15\xb6\x0b\x84bsLqj\xe2/1.6\xac\xf0\xc2\xc1'
#           b'\n.m\x9b.jsN\x840\xf6\x9f\x08ghyclnbg}t\x85\x85\x85\xb6\x0co\x11Bb'
#           b'\xfaw~\xf7\x01`o-nfoq>jQ\xc0X2\x1c\xc2(\xa5)pVy\r\x08\x85I\xd6('
#           b'g\xec"\xe3\xb7\t\x83-\'\xb8\x98ss({\'<|\xa35\x06\'=\x17\xb5ck\''
#           b'}\xe0",,\x8f"\x995\x98\x0b\n\x85C\x85\x14b1\x95\xa85\xb4\xd6\x16'
#           b'\x10_\xa8\xc3\xbd\x15?\x04\x84w,\xadu\xe5&h=1 \x00\x00\x00\x00\x00'
#           b'\x00\x12\x00\xff',
#   'flags': 1073741825,
#   'id': 39,
#   'realSize': 1082,
#   'size': 608},
#  {'data': b'\xdf\xfdw\xcb\x04\x00\x0b\x03</body>\xb7\x02\nscrip\xff'
#           b'\xb3\xff\xfft type="text/java\x15" langua\xff\xff\x80\xb9g\x1a\x15'
#           b'>\r\njQuery(docum\xdb\xffo\xffent).reaQ(function() {$s\xef'
#           b"\x02\xf6\xf6etTi\x1eout\x18\x17if (\xff\xed\xff\x7foof(WEWORK)!=='"
#           b"!defined'~\xfb\x0b\xf6 && \x18Flog\x16Submi\xf6\xb7\x80\xdd\xa6= I"
#           b"sturn s\x997\xe6\xde\xdaee\x0f;};s'L2{\xd8*\xfbForm0\xc2.f.o"
#           b"\xdb\x0f\xbbs.l9.att\xedb\xbbes[ \xeb\x9e\xb5'=W']P{6#3\\\x18.<l"
#           b'uE\x81\xc2\xb6M\xc2";K\'@p6[\x88\x97\xb0\xffl7"]\')[0]S\x1f\xc2\xb6'
#           b"n\xb2O'\x14te'Edo\xbf\xa53clickH={}<ld\xc3V\x85\xd5\x8f["
#           b'\x1b\x10\x0e#\xbeL\x085)\x1b\xd9dcK(E,>!\x17kw]>}\x02,2'
#           b'0\x00\x0c\x04\\\xc6\x19\x8d\xb4~>\xc5h\xdbo1vt>\xf0\xc5\xb3le'
#           b' id\xb6h\x0b\xaf\xf1h\x04\xdc\xa4\x05\xab \xc6\xd6\xbe\xf1disp\xc5'
#           b'y: np!!\x8f\x9e\xfb\xc6\xc2p\xa5t\xd5t; }Q60B$9\xce\x05\xe0scl'
#           b'\x04\xd9 \xb4 \x00\xe5\x0cG\xdb\\\x80/r\xd950+\xfc\xfb\x96FtEle\nB'
#           b'yId\x07\xb0\xcc>\x8d\x05\xf5\t\x1as)>\x9b\xb6\xaemUp;&N\x1de_m'
#           b'o\xb8\xe1n\x0b\x1eC,ld \xb9 c\xe1\x11\x1a_Ech(e\xd4) 10'
#           b"+\x86\xf6\xaf\x05\x01qMyCo\xe9\xae\xf6\xf6\xb6\xfbrHASH~'%dtnav%'"
#           b'R\xf7\x06\x93\x1d\x0c\x96td@c }\x1bA\x18\x15\nb\x13e\xba\x10\xc2'
#           b'eE3G)-\xd2\xd60\x04G\x16c.-\xc9\xb0\xb0@\xe0n/,\x16w!\x0c\xdb'
#           b'.\xcbfd\x1dLV \xec=n_rbw\x80ld\x8d\x94\x0c\xa1\x11\xcaz/*/'
#           b'\t\xf2\xfc\x16c\x81R\x19*u\xc5-t\r!\\/\xa6A)e\xa5\x86\xd60\xd80\x03'
#           b'Az%\x00\x00\x00p\xba\x00$\x00\x00\xff',
#   'flags': 268435457,
#   'id': 'CFGID_HTTP_INJECTS_LIST (20007)',
#   'realSize': 2051,
#   'size': 849}]

# %% [markdown]
# ## Commands
#
# Pseudocode:
#
#     ...
#     ci = 0;
#     while ( 1 )
#     {
#       CryptedStrings::_getW(word_4017F8[4 * ci], commandNameBuffer);
#       if ( !lstrcmpiW(*args, commandNameBuffer) )
#         break;
#       if ( ++ci >= 26 )
#         goto LABEL_33;
#     ...
#
# Disassembly:
#
#     .text:00414144 33 FF                                         xor     edi, edi
#     .text:00414146
#     .text:00414146                               loc_414146:
#     .text:00414146 66 8B 04 FD F8 17 40 00                       mov     ax, ds:word_4017F8[edi*8]
#     .text:0041414E 8D B5 54 FD FF FF                             lea     esi, [ebp+commandNameBuffer]
#     .text:00414154 E8 C4 CD FF FF                                call    CryptedStrings___getW
#     .text:00414159 8B C6                                         mov     eax, esi
#     .text:0041415B 50                                            push    eax
#     .text:0041415C FF 33                                         push    dword ptr [ebx]
#     .text:0041415E FF 15 88 12 40 00                             call    ds:lstrcmpiW
#     .text:00414164 85 C0                                         test    eax, eax
#     .text:00414166 74 08                                         jz      short loc_414170
#     .text:00414168 47                                            inc     edi
#     .text:00414169 83 FF 1A                                      cmp     edi, 1Ah
#     .text:0041416C 72 D8                                         jb      short loc_414146
#     .text:0041416E EB 1F                                         jmp     short loc_41418F

# %%
match = re.search(rb'\x66\x8b\x04\xfd(?P<indexes_addr>[\s\S]{4})', pe.get_memory_mapped_image())
indexes_addr = struct.unpack("I", match.group("indexes_addr"))[0]

for i in range(26):
    index_addr = indexes_addr + i * 8
    index_rva = index_addr - pe.OPTIONAL_HEADER.ImageBase
    enc_string_index = pe.get_word_at_rva(index_rva)
    
    plain_string = decrypt_string(pe, enc_string_index)
    print(f"{enc_string_index}: {plain_string}")
# Out:
# 164: os_shutdown
# 165: os_reboot
# 166: bot_uninstall
# 167: bot_update
# 168: bot_update_exe
# 169: bot_bc_add
# 170: bot_bc_remove
# 171: bot_httpinject_disable
# 172: bot_httpinject_enable
# 173: fs_path_get
# 174: fs_search_add
# 175: fs_search_remove
# 176: user_destroy
# 177: user_logoff
# 178: user_execute
# 179: user_cookies_get
# 180: user_cookies_remove
# 181: user_certs_get
# 182: user_certs_remove
# 183: user_url_block
# 184: user_url_unblock
# 185: user_homepage_set
# 186: user_ftpclients_get
# 187: user_emailclients_get
# 188: user_flashplayer_get
# 189: user_flashplayer_remove
