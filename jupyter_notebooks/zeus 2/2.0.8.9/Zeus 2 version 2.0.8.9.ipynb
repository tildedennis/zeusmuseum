# %% [markdown]
# ## Initial Setup
#
# 1. Download the Zeus 2 version 2.0.8.9 reference sample from [MalwareBazaar](
# https://bazaar.abuse.ch/sample/0fd0fedc1c314629e83f3e2ef6867e5cbaf15c4bd6235a8d9fadfc79bd441611/).
# 2. Unpack the sample with [UNPACME](https://www.unpac.me/results/0043ed23-cdd7-47a5-8ee6-f26f248cbdb7#/).
# 3. Zeus 2 2.0.8.9 [source code](https://github.com/Visgean/Zeus).

# %%
# Install required Python modules
import sys
# !{sys.executable} -m pip install pefile

# Import required Python modules
import pprint
import re
import struct

import pefile
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pefile in /usr/local/lib/python3.8/site-packages (2018.8.8)
# Requirement already satisfied: future in /usr/local/lib/python3.8/site-packages (from pefile) (0.16.0)

# %%
# Load the unpacked sample
fp = open("d146fe1e7b782cfd1c534c44c63ba578df0acd184cab86d0e5490eb39108c84e.bin", "rb")
sample = fp.read()
fp.close()

pe = pefile.PE(data=sample)

# %% [markdown]
# ## Decrypt Strings
#
# Pseudocode:
#
#     int __usercall CryptedStrings::_getA@<eax>(unsigned __int16 id@<ax>, int buffer@<edi>)
#     {
#       STRINGINFO *s; // eax
#       int i; // ecx
#       int i2; // esi
#       char pb; // dl
#       int size; // eax
#
#       s = &dword_4025F8[2 * id];
#       for ( i = 0; i < *&s->size; *(i2 + buffer) = pb )
#       {
#         i2 = i;
#         pb = i ^ s->key ^ *(*&s->encodedString + i);
#         ++i;
#       }
#       size = *&s->size;
#       *(size + buffer) = 0;
#       return size;
#     }
#
# Disassembly:
#
#     .text:0040F314                               CryptedStrings___getA proc near
#     .text:0040F314 0F B7 C0                                      movzx   eax, ax
#     .text:0040F317 8D 04 C5 F8 25 40 00                          lea     eax, dword_4025F8[eax*8]
#     .text:0040F31E 33 D2                                         xor     edx, edx
#     .text:0040F320 33 C9                                         xor     ecx, ecx
#     .text:0040F322 66 3B 50 02                                   cmp     dx, [eax+2]
#     .text:0040F326 73 19                                         jnb     short loc_40F341
#     .text:0040F328 56                                            push    esi
#     .text:0040F329
#     .text:0040F329                               loc_40F329:
#     .text:0040F329 8B 50 04                                      mov     edx, [eax+4]
#     .text:0040F32C 0F B7 F1                                      movzx   esi, cx
#     .text:0040F32F 8A 14 32                                      mov     dl, [edx+esi]
#     .text:0040F332 32 10                                         xor     dl, [eax]
#     .text:0040F334 32 D1                                         xor     dl, cl
#     .text:0040F336 41                                            inc     ecx
#     .text:0040F337 88 14 3E                                      mov     [esi+edi], dl
#     .text:0040F33A 66 3B 48 02                                   cmp     cx, [eax+2]
#     .text:0040F33E 72 E9                                         jb      short loc_40F329
#     .text:0040F340 5E                                            pop     esi
#     .text:0040F341
#     .text:0040F341                               loc_40F341:
#     .text:0040F341 0F B7 40 02                                   movzx   eax, word ptr [eax+2]
#     .text:0040F345 C6 04 38 00                                   mov     byte ptr [eax+edi], 0
#     .text:0040F349 C3                                            retn
#     .text:0040F349                               CryptedStrings___getA endp

# %%
def decrypt_string(pe, id_):
    match = re.search(rb'\x8d\x04\xc5(?P<enc_strings_addr>[\s\S]{4})', 
                      pe.get_memory_mapped_image())
    enc_strings_addr = struct.unpack("I", match.group("enc_strings_addr"))[0]
    
    enc_string_addr = enc_strings_addr + 8 * id_
    enc_string_rva = enc_string_addr - pe.OPTIONAL_HEADER.ImageBase
    
    xor_key = pe.get_word_at_rva(enc_string_rva)
    encbuf_len = pe.get_word_at_rva(enc_string_rva + 2)
    encbuf_addr = pe.get_dword_at_rva(enc_string_rva + 4)
    encbuf_rva = encbuf_addr - pe.OPTIONAL_HEADER.ImageBase
    encbuf = pe.get_data(encbuf_rva, encbuf_len)
    
    plainbuf = b""
    for i in range(len(encbuf)):
        pb = (i ^ xor_key ^ encbuf[i]) & 0xff
        plainbuf += struct.pack("B", pb)
        
    return plainbuf.decode()


for i in range(230):
    plain_string = decrypt_string(pe, i)
    print(f"{i}: {plain_string}")
# Out:
# 0: screenshots\%s\%04x_%08x.jpg
# 1: unknown
# 2: image/jpeg
# 3: Software\Microsoft\Windows\Currentversion\Run
# 4: SOFTWARE\Microsoft\Windows NT\CurrentVersion\ProfileList\%s
# 5: ProfileImagePath
# 6: unknown\unknown
# 7: :d
# rd /S /Q "%s"
# rd /S /Q "%s"
# if exist "%s" goto d
# if exist "%s" goto d
# 8: grabbed\%S_%02u_%02u_%02u.txt
# 9: Grabbed data from: %s
#
# %S
# 10: %s%s
# Referer: %S
# User input: %s
# %sPOST data:
#
# %S
# 11: *EMPTY*
# 12: *UNKNOWN*
# 13:  *BLOCKED*
# 14: Content-Type: %s
#
# 15: ZCID: %S
#
# 16: application/x-www-form-urlencoded
# 17: HTTP authentication: username="%s", password="%s"
#
# 18: HTTP authentication (encoded): %S
#
# 19: %s://%s:%s@%s/
# 20: ftp
# 21: pop3
# 22: anonymous
# 23: Software\Microsoft\Internet Explorer\Main
# 24: Start Page
# 25: Software\Microsoft\Internet Explorer\PhishingFilter
# 26: Enabled
# 27: EnabledV8
# 28: Software\Microsoft\Internet Explorer\Privacy
# 29: CleanCookies
# 30: Software\Microsoft\Windows\CurrentVersion\Internet Settings\Zones\%u
# 31: 1406
# 32: 1609
# 33: Accept-Encoding: identity
#
# 34: TE:
#
# 35: If-Modified-Since:
#
# 36:
# Path: %s
#
# 37: %s=%s
#
# 38: *@*.txt
# 39: Low
# 40: Wininet(Internet Explorer) cookies:
# %S
# 41: Empty
# 42: Mozilla\Firefox
# 43: user.js
# 44: profiles.ini
# 45: Profile%u
# 46: IsRelative
# 47: Path
# 48: user_pref("network.cookie.cookieBehavior", 0);
# user_pref("privacy.clearOnShutdown.cookies", false);
# user_pref("security.warn_viewing_mixed", false);
# user_pref("security.warn_viewing_mixed.show_once", false);
# user_pref("security.warn_submit_insecure", false);
# user_pref("security.warn_submit_insecure.show_once", false);
#
# 49: user_pref("browser.startup.homepage", "%s");
# user_pref("browser.startup.page", 1);
#
# 50: Macromedia\Flash Player
# 51: flashplayer.cab
# 52: *.sol
# 53: Windows Address Book
# 54: SOFTWARE\Microsoft\WAB\DLLPath
# 55: WABOpen
# 56: Windows Contacts
# 57: A8000A
# 58: 1.0
# 59: EmailAddressCollection/EmailAddress[%u]/Address
# 60: Windows Mail Recipients
# 61: Outlook Express Recipients
# 62: Outlook Express
# 63: account{*}.oeaccount
# 64: Software\Microsoft\Windows Mail
# 65: Software\Microsoft\Windows Live Mail
# 66: Store Root
# 67: Salt
# 68: 0x%s
# 69: Windows Mail
# 70: Windows Live Mail
# 71: MessageAccount
# 72: Account_Name
# 73: SMTP_Email_Address
# 74: %sAccount name: %s
# E-mail: %s
#
# 75: %s:
# 	Server: %s:%u%s
# 	Username: %s
# 	Password: %s
#
# 76: %s_Server
# 77: %s_User_Name
# 78: %s_Password2
# 79: %s_Port
# 80: %s_Secure_Connection
# 81: SMTP
# 82: POP3
# 83: IMAP
# 84:  (SSL)
# 85: ftp://%s:%s@%s:%u
#
# 86: ftp://%s:%s@%s
#
# 87: ftp://%S:%S@%S:%u
#
# 88: yA36zA48dEhfrvghGRg57h5UlDv3
# 89: sites.dat
# 90: quick.dat
# 91: history.dat
# 92: IP
# 93: port
# 94: user
# 95: pass
# 96: SOFTWARE\FlashFXP\3
# 97: datafolder
# 98: *flashfxp*
# 99: FlashFXP
# 100: wcx_ftp.ini
# 101: connections
# 102: default
# 103: host
# 104: username
# 105: password
# 106: SOFTWARE\Ghisler\Total Commander
# 107: ftpininame
# 108: installdir
# 109: *totalcmd*
# 110: *total*commander*
# 111: *ghisler*
# 112: Total Commander
# 113: ws_ftp.ini
# 114: _config_
# 115: HOST
# 116: PORT
# 117: UID
# 118: PWD
# 119: SOFTWARE\ipswitch\ws_ftp
# 120: datadir
# 121: *ipswitch*
# 122: WS_FTP
# 123: *.xml
# 124: /*/*/Server
# 125: Host
# 126: Port
# 127: User
# 128: Pass
# 129: *filezilla*
# 130: FileZilla
# 131: SOFTWARE\Far\Plugins\ftp\hosts
# 132: SOFTWARE\Far2\Plugins\ftp\hosts
# 133: hostname
# 134: username
# 135: user
# 136: password
# 137: FAR manager
# 138: SOFTWARE\martin prikryl\winscp 2\sessions
# 139: hostname
# 140: portnumber
# 141: username
# 142: password
# 143: WinSCP
# 144: ftplist.txt
# 145: ;server=
# 146: ;port=
# 147: ;user=
# 148: ;password=
# 149: ftp*commander*
# 150: FTP Commander
# 151: SOFTWARE\ftpware\coreftp\sites
# 152: host
# 153: port
# 154: user
# 155: pw
# 156: CoreFTP
# 157: *.xml
# 158: FavoriteItem
# 159: Host
# 160: Port
# 161: User
# 162: Password
# 163: SOFTWARE\smartftp\client 2.0\settings\general\favorites
# 164: personal favorites
# 165: SOFTWARE\smartftp\client 2.0\settings\backup
# 166: folder
# 167: SmartFTP
# 168: userinit.exe
# 169: pass
# 170: certs\%s\%s_%02u_%02u_%04u.pfx
# 171: grabbed
# 172: os_shutdown
# 173: os_reboot
# 174: bot_uninstall
# 175: bot_update
# 176: bot_bc_add
# 177: bot_bc_remove
# 178: bot_httpinject_disable
# 179: bot_httpinject_enable
# 180: fs_path_get
# 181: fs_search_add
# 182: fs_search_remove
# 183: user_destroy
# 184: user_logoff
# 185: user_execute
# 186: user_cookies_get
# 187: user_cookies_remove
# 188: user_certs_get
# 189: user_certs_remove
# 190: user_url_block
# 191: user_url_unblock
# 192: user_homepage_set
# 193: user_ftpclients_get
# 194: user_emailclients_get
# 195: user_flashplayer_get
# 196: user_flashplayer_remove
# 197: Not enough memory.
# 198: Script already executed.
# 199: Failed to load local configuration.
# 200: Failed to save local configuration.
# 201: Failed to execute command at line %u.
# 202: Unknown command at line %u.
# 203: OK.
# 204: Winsta0
# 205: default
# 206: dwm.exe
# 207: taskhost.exe
# 208: taskeng.exe
# 209: wscntfy.exe
# 210: ctfmon.exe
# 211: rdpclip.exe
# 212: explorer.exe
# 213: V	%08X
# C	%08X
# PS	%08X
# 214: BOT NOT CRYPTED!
# 215: SOFTWARE\Microsoft\Windows NT\CurrentVersion
# 216: InstallDate
# 217: DigitalProductId
# 218: %s_%08X%08X
# 219: fatal_error
# 220: unknown
# 221: wtsapi32.dll
# 222: WTSEnumerateSessionsW
# 223: WTSFreeMemory
# 224: WTSQueryUserToken
# 225: userenv.dll
# 226: GetDefaultUserProfileDirectoryW
# 227: user32.dll
# 228: MessageBoxW
# 229: ntdll.dll

# %% [markdown]
# ## Extract Version
#
# Pseudocode:
#
#     ...
#     version = 0x2000809;
#     r = BinStorage::_addItem(binStorage, 4u, 10003, 0x20000, &version);// #define SBCID_BOT_VERSION 10003
#     ...
#
# Disassembly:
#
#     ...
#     .text:00417E64 8D 45 F8                      lea     eax, [ebp+version]
#     .text:00417E67 50                            push    eax
#     .text:00417E68 57                            push    edi
#     .text:00417E69 68 13 27 00 00                push    2713h
#     .text:00417E6E 6A 04                         push    4
#     .text:00417E70 5B                            pop     ebx
#     .text:00417E71 8B C6                         mov     eax, esi
#     .text:00417E73 C7 45 F8 09 08 00 02          mov     [ebp+version], 2000809h
#     .text:00417E7A E8 68 2C FF FF                call    BinStorage___addItem
#     ...

# %%
match = re.search(rb'\x68\x13\x27\x00\x00[\s\S]{1,8}?\xc7\x45[\s\S](?P<version>[\s\S]{4})', 
                  pe.get_memory_mapped_image())
version_bytes = match.group("version")
version = ".".join([str(b) for b in version_bytes[::-1]])
print(version)
# Out:
# 2.0.8.9

# %% [markdown]
# ## Decrypt BaseConfig
#
# Pseudocode:
#
#     int __usercall Core::getBaseConfig@<eax>(void *bc@<eax>)
#     {
#       int result; // eax
#       int v2; // edx
#       int v3; // esi
#       int v4; // ecx
#
#       Mem::_copy(bc, dword_402D88, 0x32Cu);
#       v3 = v2;
#       v4 = dword_423E70 + dword_4239C4 - result;
#       do
#       {
#         *result ^= *(v4 + result);
#         ++result;
#         --v3;
#       }
#       while ( v3 );
#       return result;
#     }
#
# Disassembly:
#
#     .text:0041CC1D                               Core__getBaseConfig proc near
#     .text:0041CC1D 56                                            push    esi
#     .text:0041CC1E BA 2C 03 00 00                                mov     edx, 32Ch
#     .text:0041CC23 52                                            push    edx
#     .text:0041CC24 68 88 2D 40 00                                push    offset dword_402D88
#     .text:0041CC29 50                                            push    eax
#     .text:0041CC2A E8 F3 85 FE FF                                call    Mem___copy
#     .text:0041CC2F 8B 0D C4 39 42 00                             mov     ecx, dword_4239C4
#     .text:0041CC35 03 0D 70 3E 42 00                             add     ecx, dword_423E70
#     .text:0041CC3B 8B F2                                         mov     esi, edx
#     .text:0041CC3D 2B C8                                         sub     ecx, eax
#     .text:0041CC3F
#     .text:0041CC3F                               loc_41CC3F:
#     .text:0041CC3F 8A 14 01                                      mov     dl, [ecx+eax]
#     .text:0041CC42 30 10                                         xor     [eax], dl
#     .text:0041CC44 40                                            inc     eax
#     .text:0041CC45 4E                                            dec     esi
#     .text:0041CC46 75 F7                                         jnz     short loc_41CC3F
#     .text:0041CC48 5E                                            pop     esi
#     .text:0041CC49 C3                                            retn
#     .text:0041CC49                               Core__getBaseConfig endp

# %%
match = re.search(rb'\xba(?P<encbuf_len>[\s\S]{2}\x00\x00)\x52\x68(?P<encbuf_addr>[\s\S]{4})',
                   pe.get_memory_mapped_image())

encbuf_len = struct.unpack("I", match.group("encbuf_len"))[0]
encbuf_addr = struct.unpack("I", match.group("encbuf_addr"))[0]
encbuf_rva = encbuf_addr - pe.OPTIONAL_HEADER.ImageBase
encbuf = pe.get_data(encbuf_rva, encbuf_len)

# #define PESECTION_OF_BASECONFIG_KEY 2
section = pe.sections[2]
xor_key = pe.get_data(section.VirtualAddress, encbuf_len)

base_config = b""
for i, eb in enumerate(encbuf):
    pb = eb ^ xor_key[i % len(xor_key)]
    base_config += struct.pack("B", pb)
    
print(base_config)
# Out:
# b'w\x90\xdb\xe7\xeb\x91\xf8m\x07{\xc6\xa2\xc4n\xb1\xd9}i\x8c!S\x1a\x1e\xbd\xd0\xf4\xdd\xd4\xcb\x83\xf9j\x8b\xfc\x9c\x8f/\x19q\xd6L#c\t\xd9P\xa7\x1bHP\xfc^\xf6#1\xf6\xc5-\xe8\x8e\x07\x8c\x9bJ\x9f\xa9\xdc\xfcb\r\xe1\x9a\xc4w?\xf0\xb0+\xf6\x92\x00\x00\x00 m\xed@~\x10\xa5x\xfbka\x1a\xd1\xfa\xbf"\x96O\x18P\xa0\xb4\x9c\xe4\xbd\x12\xa5\xa7$\x12E*\xac\x81!R<\xf9\x83\x14\x83\xbe\xaa~\xe9\xe6e\xf7\xc5\xbd\xe0\xc7\xd0g\xbd\xda\xda\xc7f\xc0\xbb\x01\x00\x14\x00\xfagp\x18\xc8\xf0E\x8e\xc7\x0e\xcfy\xa9\xc3\xe2\xf1s\rM\x12$\x00\xa7\xad\x97\x17L>\xaa\xcc\xa2\x1e\xa0f\xa1\xfa\xc4\x13\x92\x84O6\x16h\x8c\x02k\x82:H\xebN2\x8d\xd5\xa0J`P\x95x\xeb\xad\xc9;\xc7\xed\xca6\x15\x83\xcd\x1e\xca[\xa0\xd7J\x1a\xe0\xda9\xa8l\xda\x8d\xec\x19\xa7\xe8\xd6http://emailupgrade.su/new/config.bin\x00M\xf7\xd5\x9cTr\xf9\xb1\xd3\xfb\x88\xc5\x93\x0c\xa4\xc5\xda\x9f\xef\x18\x85\xf1B\x82W\x86\xa2I\x91mo\x97\xc3\xc5\xdf \xe1\x80\xab\x04\x99g\x08\xf7\xe4^\xd9\x9f\xdc\xea#=\xcd\xf0\xc1\x90\x8e\xc0Y\xf7\x12Q\x8e\xd5:\xcew9\xedR%\xae\x19\xee\xf2^-4\xaat]\x95\x8enz9\xd6T\xc8<\xbe \x03\xe06\xa7\xb7\xb23\x15(\x1aK\'Bx@+\x05D.\xfb~\xbc\x1e\x9eQ\xc0\x17\xb8\xef[H\xc7\x82o/h\xe7N\xa6V:\x7f\xe1\x86I\xed\x9f\xe5\x01\xf9X`}\xcf\xf8\x8d\xbd\xcd\x8b\x8c\xbf\xb5s\x1d\xadb\xf5\x84wy&v\x10f\xfe8P\x02\x81\x97\xf3\xf0\xceu\xd2\x99\x9dOE\x1c\xa1\x9b\xa5\xd05\x96\xd1W>)e?\x12\x880\xccR\xdd=!_\xab\xc2\xe8\xa9\x0b\x94\x98Y\x80G\x1f\x92\xdb\xca\x90"\xa8\x9aJ\xc3L\xe2\x8fF\xfd\x04\xde\xe3\xf1\x07\x0c\xeb\xda\x0f\x83\xec\xe4\xa3#\xc9\xa0\x85\xc5\x1b\xd9\x8a\xfc\xa2\xd7\x06\x93\n\xf7A\x18\r\x00;\x9c\xcb\x11j\x08\xbal\xd4\xb3\xd5q7Z\xb6ra\tc\xc1M\xdfi2m\x14\xb1,\xf4\xdc*\xe9g1U\x16\x13\xafC\xac\xb9\xd3\xeap\xb0\xbbS\x0e\xfak\x91\xd8{\xa4\xff\xc4\xf6\xe6\xc6\\\x89\xb4\x87$|d\x00\x00Y\x1b\x13\\"`\xa5\xc9\xb1l\x96\xf9V\x1f\xd5t\x89\xe3\xb7\x82}\xea4\x92\xf8\xb8S\xdca\xe2\xe3F\x1b\x15l\x84\x11Ye\x84\x92\x97\xa7\t`Y"\x96\x03\xd2\xcf\x8dc\x1e\xe5\x98\x96\xcbPH\xf7\x97_\xfcx{\xbd\x059\xe9\xa2\x07YSJ\xa2\x0c\x00\x00R\xed\xb2S\x94\x96\xac\xc8Knp\xd3a\xc3\xe9F\xb1\x19W\xee%\xc1\x97\xc4\x1b\xad\xa5g\x0e\x82_\xcar\xef\x8c*\xdf>\x1cDr(\xb1\xc4q\xee_\x00-\xa5\xb0\xe6-\xd1\xec3\x886\x97\xe7\x93\xeb:\xf5\xbc\xb0g>\xb6\x81\xf7\xc0\xd7l\x96\x0b\xbe\x9f\x82\xf5\x01\x00\x01\x00e\x93oX\x16\x9d0\xb0zo\x06\x8f\xfa\xd9Kv\x01\x00<\x00@\xe0&\x91\x91\xff\xd8\x8e\x9a!\xfb\xd0\x14-\xa8\x99\x8d\x8ax\xab\x0b5J\x00'

# %% [markdown]
# ## Parse BaseConfig

# %%
flags = struct.unpack("I", base_config[0x50:0x50+4])[0]
print(f"flags: 0x{flags:x}\n")

delayStats = struct.unpack("I", base_config[0x90:0x90+4])[0]
print(f"delayStats: {delayStats}\n")

defaultConfig = base_config[0xef:0xef+101].split(b"\x00")[0].decode().replace("http", "hxxp")
print(f"defaultConfig: {defaultConfig}\n")

baseKey = base_config[0x15b:0x15b+258]
print(f"baseKey: {baseKey}\n")

defaultBotnet = base_config[0x2aa:0x2aa+21].split(b"\x00\x00")[0].decode()
print(f"defaultBotnet: {defaultBotnet}\n")

delayReport = struct.unpack("I", base_config[0x2fc:0x2fc+4])[0]
print(f"delayReport: {delayReport}\n")

delayConfig = struct.unpack("I", base_config[0x310:0x310+4])[0]
print(f"delayConfig: {delayConfig}\n")
# Out:
# flags: 0x20000000
#
# delayStats: 1310721
#
# defaultConfig: hxxp://emailupgrade.su/new/config.bin
#
# baseKey: b'%\xae\x19\xee\xf2^-4\xaat]\x95\x8enz9\xd6T\xc8<\xbe \x03\xe06\xa7\xb7\xb23\x15(\x1aK\'Bx@+\x05D.\xfb~\xbc\x1e\x9eQ\xc0\x17\xb8\xef[H\xc7\x82o/h\xe7N\xa6V:\x7f\xe1\x86I\xed\x9f\xe5\x01\xf9X`}\xcf\xf8\x8d\xbd\xcd\x8b\x8c\xbf\xb5s\x1d\xadb\xf5\x84wy&v\x10f\xfe8P\x02\x81\x97\xf3\xf0\xceu\xd2\x99\x9dOE\x1c\xa1\x9b\xa5\xd05\x96\xd1W>)e?\x12\x880\xccR\xdd=!_\xab\xc2\xe8\xa9\x0b\x94\x98Y\x80G\x1f\x92\xdb\xca\x90"\xa8\x9aJ\xc3L\xe2\x8fF\xfd\x04\xde\xe3\xf1\x07\x0c\xeb\xda\x0f\x83\xec\xe4\xa3#\xc9\xa0\x85\xc5\x1b\xd9\x8a\xfc\xa2\xd7\x06\x93\n\xf7A\x18\r\x00;\x9c\xcb\x11j\x08\xbal\xd4\xb3\xd5q7Z\xb6ra\tc\xc1M\xdfi2m\x14\xb1,\xf4\xdc*\xe9g1U\x16\x13\xafC\xac\xb9\xd3\xeap\xb0\xbbS\x0e\xfak\x91\xd8{\xa4\xff\xc4\xf6\xe6\xc6\\\x89\xb4\x87$|d\x00\x00'
#
# defaultBotnet:
#
# delayReport: 65537
#
# delayConfig: 3932161

# %% [markdown]
# ## Download and Decrypt DynamicConfig
#
# ![](zeus2_2.0.8.9_pcap.png)
#
# Pseudocode:
#
#     ...
#     Mem::_copy(v7, rc4Key, 0x102u);
#     Crypt::_rc4(v4, binStorage, dataSize);
#     if ( dataSize )                             // inlined Crypt::_visualDecrypt
#     {
#       v5 = dataSize - 1;
#       if ( dataSize != 1 )
#       {
#         do
#         {
#           *(v5 + binStorage) ^= *(v5 + binStorage - 1);
#           --v5;
#         }
#         while ( v5 );
#       }
#     }

# %%
def rc4_keystate(S, in_buf):
    out_buf = b""

    i = S[256]
    j = S[257]
    
    for in_byte in in_buf:
        (i, j, S, K) = rc4_prga(i, j, S)
        out_byte = in_byte ^ K
        out_buf += struct.pack("B", out_byte)

    return out_buf


def rc4_prga(i, j, S):
    i = (i + 1) % 256
    j = (j + S[i]) % 256

    S = bytearray(S)
    S[i], S[j] = S[j], S[i]
    S = bytes(S)

    K = S[(S[i] + S[j]) % 256]

    return (i, j, S, K)


def visual_decrypt(enc_buf):
    buf = bytearray(enc_buf)

    for i in range(len(buf)-1, 0, -1):
        buf[i] ^= buf[i-1]

    plain_buf = bytes(buf)

    return plain_buf


# Load encrypted DynamicConfig from PCAP
fp = open("config.bin", "rb")
config_bin = fp.read()
fp.close()

round1 = rc4_keystate(baseKey, config_bin)
binstorage = visual_decrypt(round1)
print(binstorage)
# Out:
# b'6q\x1fT\xe1\x1b\x91\xa0\x0f!\xcb\x91\xce\xcf\x8b\xc4X\xfa\xe8\x97l\x86\x00\x00\x00\x00\x00\x00u\x00\x00\x00\xb5<\xa7H\xd7%\x97)M\xa23\x1d\x9dK\xa8\xe5!N\x00\x00\x00\x00\x00\x10\x04\x00\x00\x00\x04\x00\x00\x00\t\x08\x00\x02"N\x00\x00\x00\x00\x00\x10"\x00\x00\x00"\x00\x00\x00http://emailupgrade.su/new/bot.exe#N\x00\x00\x00\x00\x00\x10#\x00\x00\x00#\x00\x00\x00http://emailupgrade.su/new/gate.php%N\x00\x00\x01\x00\x00\x10\x85\x00\x00\x00\xa1\x00\x00\x00\xdb\xff\xff\xff!*.microsoft.com/*\x00!http:/\tm\xd6}\xed\xfdyspace\x16\x15\x14s\x15w\x00\xb0\xbf\xbd\xfd.grup1ant\x02der.es5\xc0\xda\xff?odnoklassniki.)\x1b\xfb?\xbb{vko3kte\x16@*/login.K0`Ovmp\x12atl\x10\x00\x00\x00\x00\x00\x00\x00H\x00\xff\x01\x00\x00\x00\x00\x00\x00@>\x00\x00\x00>\x00\x00\x00)\x00\x00\x00 Registered email address</td>*<img*>\t\x00\x00\x00</td>\x0c\x00\x00\x00e-mail: \x02\x00\x00\x00\x01\x00\x00@^\x00\x00\x00^\x00\x00\x00\xff\xff\xff\xcbH\x00(<a href="http://feedback\xff\xdb\xff\xdb.e\x05y.com/ws/eB\x0bISAPI.dll}\xf7\x83\xfd?ViewF&&*">\x08G</a>\x0e\x00\x00<\xcc\x07\x17: \x12\x00\x00\x00\xff\x03\x00\x00\x00\x00\x00\x00@A\x00\x00\x00A\x00\x00\x001\x00\x00\x00<table cellspacing="0" summary="page layout">\x0c\x00\x00\x00</table>\x04\x00\x00\x00\x04\x00\x00\x00\x01\x00\x00@!\x00\x00\x00!\x00\x00\x00\xcc\xfd\xff\xcb\x12\x00e-mail:</font>\x0b\x11\n\x00\x00\x80\x19\x04 \x01\x00\x00\xff\x05\x00\x00\x00\x00\x00\x00@K\x00\x00\x00K\x00\x00\x00\x1b\x00\x00\x00<form name=fiat*</form>,\x00\x00\x00<th colspan=4 align=left valign="bottom"\x04\x00\x00\x00\x06\x00\x00\x00\x01\x00\x00@Y\x00\x00\x00k\x00\x00\x00\xff\xff\xff\xcb(\x00<div id="pageIntro" class\xb1\xdf\xcbo\x11nopri">?\'td&\xf6\xf6\xdb\xb7s\x04ebar$align\x0flef!\\Y\x1b\xec v\rt2>\x04\x00\x00\x00\xc0\x00\x90\x00\x00\xff\x07\x00\x00\x00\x01\x00\x00@\xdb\x00\x00\x00!\x01\x00\x00\xdf\xfe\xff\xcb9\x00<span class="moz\toak"\xfe\xdd\xf6\xff><input type\x16p\x1cword"*</\xfd\xed\xd7\xfd.>\x048\xe4<br)strong\xed[\xfb\xad\x07Bbel f\'0atmp@\xf6\xb1\xf6oEATM PIN5\x1b>:</,a\xdfm\x0f&nbH;> />\r\n\x83\xdb\xf6\xf6\x13 acce\x0bkey\x14A\ri\xdb\xdb}\xb2dn nam)US+\rs\xdd\xed\xb7\xcdiz13\tmaxleuth\x0e4\xb6\xb5ns\x18Ql\x19w:\x11:\x10\xdd\xde\xda\xf67px\x13t\xa0Adex\x162"\x00\x00\x10\xcc\x93\xe7H\x00\x00\x00\xff\x08\x00\x00\x00\x01\x00\x00@\xf8\x00\x00\x00`\x01\x00\x00\xff\xff\xff\xcb0\x00<input type="password" na\xbd\xee?\xb0m\x0f*</td>\x04/\xe43\xed\xff\xb7\xbf\x0b width!225"><label f)\xeb\x9a{`Bcl\n\x10\x15m\x1fb\xed\xff\x16\'3. ATM PINN\x12\xbd\x13\xd9\xdf9br/>\r\n\x84US\x11\xbd\xb5o\xad\rp\x0batmp+\x0bsizo\xbf\x7f\xdb\x1920\tmaxleng\x8b14\x0etits\xc3~+\nEnterl\x15l\xb7o\xdd[5dex#1\raccePke\xd8\xffb\xb7y\x0eA"~\x85&nbsp;\xe7\xb5]\xc0\xde+\xe3\xd30ouQn\xb0w\x80\xd2\x0c*\xcc\x11\x0b\x00\xe0\xf6\xb74\xe2Sign o\x02to\x00\x00\x00\x00\x00\x00\x00\x90\xff\t\x00\x00\x00\x01\x00\x00@\xf8\x00\x00\x00`\x01\x00\x00\xff\xff\xff\xcb0\x00<input type="password" na\xbd\xee?\xb0m\x0f*</td>\x04/\xe43\xed\xff\xb7\xbf\x0b width!225"><label f)\xeb\x9a{`Bcl\n\x10\x15m\x1fb\xed\xff\x16\'3. ATM PINN\x12\xbd\x13\xd9\xdf9br/>\r\n\x84US\x11\xbd\xb5o\xad\rp\x0batmp+\x0bsizo\xbf\x7f\xdb\x1920\tmaxleng\x8b14\x0etits\xc3~+\nEnterl\x15l\xb7o\xdd[5dex#1\raccePke\xd8\xffb\xb7y\x0eA"~\x85&nbsp;\xe7\xb5]\xc0\xde+\xe3\xd30ouQn\xb0w\x80\xd2\x0c*\xcc\x11\x0b\x00\xe0\xf6\xb74\xe2Sign o\x02to\x00\x00\x00\x00\x00\x00\x00\x90\xff\n\x00\x00\x00\x01\x00\x00@A\x00\x00\x00J\x00\x00\x00\xff\xff\xff\xcb\x1e\x00<div id="accountOverview"\xce\xd7\xfd\xdf>(\x1d/table>\x07d\x04r\x00\x00n\xc8\x11\x04\'\x04\x00\x00\x00\x00\x00\x00\x80\xff\x0b\x00\x00\x00\x01\x00\x00@A\x00\x00\x00J\x00\x00\x00\xff\xff\xff\xcb\x1e\x00<div id="accountOverview"\xce\xd7\xfd\xdf>(\x1d/table>\x07d\x04r\x00\x00n\xc8\x11\x04\'\x04\x00\x00\x00\x00\x00\x00\x80\xff\x0c\x00\x00\x00\x00\x00\x00@~\x00\x00\x00~\x00\x00\x00n\x00\x00\x00<a href="#" onClick="javascript:handlePageLink(\'/internetBanking/RequestRouter?requestCmdId=AccountDetails\x0c\x00\x00\x00</table>\x04\x00\x00\x00\r\x00\x00\x00\x00\x00\x00@%\x00\x00\x00%\x00\x0 ...

# %% [markdown]
# ## Parse DynamicConfig

# %%
def parse_binstorage_header(binstorage):
    header = {
        "randData": binstorage[0:20],
        "size": struct.unpack("I", binstorage[20:24])[0],
        "flags": struct.unpack("I", binstorage[24:28])[0],
        "count": struct.unpack("I", binstorage[28:32])[0],
        "md5Hash": binstorage[32:48],
    }
        
    return header


def parse_binstorage_sections(section_data, num_sections):
    CFGIDS = {
        20001: "CFGID_LAST_VERSION",
        20002: "CFGID_LAST_VERSION_URL",
        20003: "CFGID_URL_SERVER_0",
        20004: "CFGID_URL_ADV_SERVERS",
        20005: "CFGID_HTTP_FILTER",
        20006: "CFGID_HTTP_POSTDATA_FILTER",
        20007: "CFGID_HTTP_INJECTS_LIST",
        20008: "CFGID_DNS_LIST",
    }
    
    sections = []
    offset = 0
    for i in range(num_sections):
        section = {}
        
        id_ = struct.unpack("I", section_data[offset:offset+4])[0]
        if int(id_) in CFGIDS:
            section["id"] = f'{CFGIDS[int(id_)]} ({id_})'
        else:
            section["id"] = id_
            
        section["flags"] = struct.unpack("I", section_data[offset+4:offset+8])[0]
        section["size"] = struct.unpack("I", section_data[offset+8:offset+12])[0]
        section["realSize"] = struct.unpack("I", section_data[offset+12:offset+16])[0]
        # additional parsing of data is left as an exercise
        section["data"] = section_data[offset+16:offset+16+section["size"]]
        
        offset += 4 + 4 + 4 + 4 + section["size"]
        
        sections.append(section)
        
    return sections


binstorage_header = parse_binstorage_header(binstorage)
print("binstorage_header:\n")
pprint.pprint(binstorage_header)

binstorage_sections = parse_binstorage_sections(binstorage[48:], binstorage_header["count"])
print()
print("binstorage_sections:\n")
pprint.pprint(binstorage_sections)
# Out:
# binstorage_header:
#
# {'count': 117,
#  'flags': 0,
#  'md5Hash': b'\xb5<\xa7H\xd7%\x97)M\xa23\x1d\x9dK\xa8\xe5',
#  'randData': b'6q\x1fT\xe1\x1b\x91\xa0\x0f!\xcb\x91\xce\xcf\x8b\xc4'
#              b'X\xfa\xe8\x97',
#  'size': 34412}
#
# binstorage_sections:
#
# [{'data': b'\t\x08\x00\x02',
#   'flags': 268435456,
#   'id': 'CFGID_LAST_VERSION (20001)',
#   'realSize': 4,
#   'size': 4},
#  {'data': b'http://emailupgrade.su/new/bot.exe',
#   'flags': 268435456,
#   'id': 'CFGID_LAST_VERSION_URL (20002)',
#   'realSize': 34,
#   'size': 34},
#  {'data': b'http://emailupgrade.su/new/gate.php',
#   'flags': 268435456,
#   'id': 'CFGID_URL_SERVER_0 (20003)',
#   'realSize': 35,
#   'size': 35},
#  {'data': b'\xdb\xff\xff\xff!*.microsoft.com/*\x00!http:/\tm\xd6}\xed\xfdyspa'
#           b'ce\x16\x15\x14s\x15w\x00\xb0\xbf\xbd\xfd.grup1ant\x02der.e'
#           b's5\xc0\xda\xff?odnoklassniki.)\x1b\xfb?\xbb{vko3kte\x16@*/login.K'
#           b'0`Ovmp\x12atl\x10\x00\x00\x00\x00\x00\x00\x00H\x00\xff',
#   'flags': 268435457,
#   'id': 'CFGID_HTTP_FILTER (20005)',
#   'realSize': 161,
#   'size': 133},
#  {'data': b')\x00\x00\x00 Registered email address</td>*<img*>\t\x00\x00\x00</t'
#           b'd>\x0c\x00\x00\x00e-mail: ',
#   'flags': 1073741824,
#   'id': 1,
#   'realSize': 62,
#   'size': 62},
#  {'data': b'\xff\xff\xff\xcbH\x00(<a href="http://feedback\xff\xdb\xff\xdb.'
#           b'e\x05y.com/ws/eB\x0bISAPI.dll}\xf7\x83\xfd?ViewF&&*">\x08G</a>'
#           b'\x0e\x00\x00<\xcc\x07\x17: \x12\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 2,
#   'realSize': 94,
#   'size': 94},
#  {'data': b'1\x00\x00\x00<table cellspacing="0" summary="page layout"'
#           b'>\x0c\x00\x00\x00</table>\x04\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 3,
#   'realSize': 65,
#   'size': 65},
#  {'data': b'\xcc\xfd\xff\xcb\x12\x00e-mail:</font>\x0b\x11\n\x00'
#           b'\x00\x80\x19\x04 \x01\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 4,
#   'realSize': 33,
#   'size': 33},
#  {'data': b'\x1b\x00\x00\x00<form name=fiat*</form>,\x00\x00\x00<th colspan=4'
#           b' align=left valign="bottom"\x04\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 5,
#   'realSize': 75,
#   'size': 75},
#  {'data': b'\xff\xff\xff\xcb(\x00<div id="pageIntro" class\xb1\xdf\xcbo\x11nopr'
#           b'i">?\'td&\xf6\xf6\xdb\xb7s\x04ebar$align\x0flef!\\Y\x1b\xec v\r'
#           b't2>\x04\x00\x00\x00\xc0\x00\x90\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 6,
#   'realSize': 107,
#   'size': 89},
#  {'data': b'\xdf\xfe\xff\xcb9\x00<span class="moz\toak"\xfe\xdd\xf6\xff><inp'
#           b'ut type\x16p\x1cword"*</\xfd\xed\xd7\xfd.>\x048\xe4<br)stron'
#           b"g\xed[\xfb\xad\x07Bbel f'0atmp@\xf6\xb1\xf6oEATM PIN5\x1b>:</,a\xdf"
#           b'm\x0f&nbH;> />\r\n\x83\xdb\xf6\xf6\x13 acce\x0bkey\x14A\ri\xdb'
#           b'\xdb}\xb2dn nam)US+\rs\xdd\xed\xb7\xcdiz13\tmaxleuth\x0e4\xb6\xb5'
#           b'ns\x18Ql\x19w:\x11:\x10\xdd\xde\xda\xf67px\x13t\xa0Adex\x162"'
#           b'\x00\x00\x10\xcc\x93\xe7H\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 7,
#   'realSize': 289,
#   'size': 219},
#  {'data': b'\xff\xff\xff\xcb0\x00<input type="password" na\xbd\xee?\xb0m\x0f*</'
#           b'td>\x04/\xe43\xed\xff\xb7\xbf\x0b width!225"><label f)\xeb\x9a{`Bcl'
#           b"\n\x10\x15m\x1fb\xed\xff\x16'3. ATM PINN\x12\xbd\x13\xd9\xdf9br/>\r"
#           b'\n\x84US\x11\xbd\xb5o\xad\rp\x0batmp+\x0bsizo\xbf\x7f\xdb\x1920'
#           b'\tmaxleng\x8b14\x0etits\xc3~+\nEnterl\x15l\xb7o\xdd[5dex#1\racceP'
#           b'ke\xd8\xffb\xb7y\x0eA"~\x85&nbsp;\xe7\xb5]\xc0\xde+\xe3\xd30o'
#           b'uQn\xb0w\x80\xd2\x0c*\xcc\x11\x0b\x00\xe0\xf6\xb74\xe2Sign o'
#           b'\x02to\x00\x00\x00\x00\x00\x00\x00\x90\xff',
#   'flags': 1073741825,
#   'id': 8,
#   'realSize': 352,
#   'size': 248},
#  {'data': b'\xff\xff\xff\xcb0\x00<input type="password" na\xbd\xee?\xb0m\x0f*</'
#           b'td>\x04/\xe43\xed\xff\xb7\xbf\x0b width!225"><label f)\xeb\x9a{`Bcl'
#           b"\n\x10\x15m\x1fb\xed\xff\x16'3. ATM PINN\x12\xbd\x13\xd9\xdf9br/>\r"
#           b'\n\x84US\x11\xbd\xb5o\xad\rp\x0batmp+\x0bsizo\xbf\x7f\xdb\x1920'
#           b'\tmaxleng\x8b14\x0etits\xc3~+\nEnterl\x15l\xb7o\xdd[5dex#1\racceP'
#           b'ke\xd8\xffb\xb7y\x0eA"~\x85&nbsp;\xe7\xb5]\xc0\xde+\xe3\xd30o'
#           b'uQn\xb0w\x80\xd2\x0c*\xcc\x11\x0b\x00\xe0\xf6\xb74\xe2Sign o'
#           b'\x02to\x00\x00\x00\x00\x00\x00\x00\x90\xff',
#   'flags': 1073741825,
#   'id': 9,
#   'realSize': 352,
#   'size': 248},
#  {'data': b'\xff\xff\xff\xcb\x1e\x00<div id="accountOverview"\xce\xd7\xfd\xdf>'
#           b"(\x1d/table>\x07d\x04r\x00\x00n\xc8\x11\x04'\x04\x00\x00\x00"
#           b'\x00\x00\x00\x80\xff',
#   'flags': 1073741825,
#   'id': 10,
#   'realSize': 74,
#   'size': 65},
#  {'data': b'\xff\xff\xff\xcb\x1e\x00<div id="accountOverview"\xce\xd7\xfd\xdf>'
#           b"(\x1d/table>\x07d\x04r\x00\x00n\xc8\x11\x04'\x04\x00\x00\x00"
#           b'\x00\x00\x00\x80\xff',
#   'flags': 1073741825,
#   'id': 11,
#   'realSize': 74,
#   'size': 65},
#  {'data': b'n\x00\x00\x00<a href="#" onClick="javascript:handlePageLink(\'/int'
#           b'ernetBanking/RequestRouter?requestCmdId=AccountDetails\x0c\x00'
#           b'\x00\x00</table>\x04\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 12,
#   'realSize': 126,
#   'size': 126},
#  {'data': b'\x15\x00\x00\x00Account Name</td>\x0c\x00\x00\x00</table'
#           b'>\x04\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 13,
#   'realSize': 37,
#   'size': 37},
#  {'data': b',\x00\x00\x00account-history-wait.jsp" method="post">'
#           b'\x0c\x00\x00\x00</table>\x04\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 14,
#   'realSize': 60,
#   'size': 60},
#  {'data': b' \x00\x00\x00id="dgDepositAcctsheader0"*>\x0c\x00\x00\x00</table>'
#           b'\x04\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 15,
#   'realSize': 48,
#   'size': 48},
#  {'data': b'+\x00\x00\x00<td class="ice_headerleft">Deposit</td>\x0c'
#           b'\x00\x00\x00</table>\x04\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 16,
#   'realSize': 59,
#   'size': 59},
#  {'data': b'\x1e\x00\x00\x00<td class="acctName_Text">\x0c\x00\x00\x00</tabl'
#           b'e>\x04\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 17,
#   'realSize': 46,
#   'size': 46},
#  {'data': b'\x1a\x00\x00\x00account summary</font> \x00\x00\x00<td height="10'
#           b'" colspan="4">\x04\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 18,
#   'realSize': 62,
#   'size': 62},
#  {'data': b'\x15\x00\x00\x00</SPAN></CAPTION>\x0c\x00\x00\x00</TABLE'
#           b'>\x11\x00\x00\x00BOFA balance:',
#   'flags': 1073741824,
#   'id': 19,
#   'realSize': 50,
#   'size': 50},
#  {'data': b'#\x00\x00\x00_accountSummaryContainer"*</tr>\x0c\x00\x00\x00</tab'
#           b'le>\x04\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 20,
#   'realSize': 51,
#   'size': 51},
#  {'data': b'\x15\x00\x00\x00<tr class="rowa">\x0c\x00\x00\x00</table'
#           b'>\x04\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 21,
#   'realSize': 37,
#   'size': 37},
#  {'data': b'\xff\xff\xff\xcb\x1c\x00<span class="bodyText5">1k\xed\xdd~\x1b'
#           b'td\x19ol!\x1b\x13%\xb7\xb7\xdf\r\x0fcerH20%&nb\r;<\x00\x00p\xb7/'
#           b'(>\x040$\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 22,
#   'realSize': 81,
#   'size': 77},
#  {'data': b'\xff\xff\xff\xcb \x00name =p  rethepassword*</\xedo]\xf7TD>\x04\x1f'
#           b'\x8e\x03<\x0b bgCol\x19\xff\xff\xff\xf7=#E7\x01 vAlign=top><INPUT m'
#           b'axL\xfb\xef\xef\xedengE=8 U=ESN size\x12\xed\xff\xbf\xbdstyl\x07"F'
#           b'ONT-FAMILY: Vej\xbb\xedc\xb7a+; \x15SIZE\x138\x8bt""\x83\xcdn\x02yp'
#           b'\x97\x91>\xffo\xb7\xff\xb1:oculw_f\x15m_onsubmit(\xac\xfd\xde\xdb'
#           b');\xb3TR\t\xad($\x01\x08r\xb0\x7f\xfb;c\xb8 :#K706E6F;\x83\xdb/'
#           b'\x1b6\x82\x817pt;[n\xbf\x95\xed\xf6t-we\xe1ht8bAd">\r\n\xb4\xddc'
#           b'\x0f\x08h\x15=20\xf7MG\x9e\xed\xf6\xb0!\x06\x1811wrcup\xdb\xbf\xfd/'
#           b'grafi{sDJ/tip\xafd\xb7=\xbc\xfdV\x15Wo.gif\xe0wid*04wd\x9f\xd8<T'
#           b'DOb\xf5\x9c\xac;\xc8.\x030 ZnSr\\d\x7f\xc9!77Clave\r\xd6\xdep'
#           b'\xe1Fi;a#,func\x9d\xed\xee\xe3\x01\xc2 T*{\x01x\x03\x01;\xecoS(se'
#           b'lf.f..\xc7\xf8\xf6\x84.\xe7.v\xbaue.l\x02<40\xb6\xd0\xda){'
#           b"\x0e\x98\x97'x n\xb3[\xbb\xccrsV\x12 (\x0f\xd9 fk\xad\xdd\xf8\x83)*"
#           b"o 2\xcbS\xd3\xf0\x1d\x85[].'\xc7\x88urn;}\x00\x00\x00\x00"
#           b'\x00\x00H\x00\xff',
#   'flags': 1073741825,
#   'id': 23,
#   'realSize': 670,
#   'size': 469},
#  {'data': b'\xbf\xfd\xff\xcb \x00id="clave" name\x0coppas\xe6\xbe\xeb\xfeswd"*'
#           b'>\x04\x1f\x99\x03<div $\x16\xed\xdd\xff\xbf+ear sep4"></\x18>\r'
#           b'\n<\x1a\xb6\xb7\xef\xfebel for\x1fodusu"io2 C\xc5\xda\xbf\xfdX '
#           b'd\x02firma: 0)\x83-\xec\xff2input id1\x83E\xedc\xc3\x9eS"s+01 a{'
#           b'\xfb\xec\xfd\xb7f3w180"/>+\x98Etyp4\xff\x87m\xadhLinBSXPASWI'
#           b"_#\xc3\x16\xd9`\xc71.q\xc1\\\xe7\xb6vcu\x0e_'0\rmo\xb7\xf6Entr\x9fH"
#           b'on\x90ick\x10jm\xdd\xb7\xad\xd6-c\xb1pt:0&"\xcf\xad\xb4\xff\xad\xbb'
#           b'\x02- \x00F\x14day, Octo\xe9\xfb\xdb\xdf.(19\x0b2007 3)2 AM '
#           b"\x0e/f\xef[\xbbCheEq();\r\x95I\xbb\xb0\xed\xce\xa6\xc3\x03fugt\rn '"
#           b'k\xff\xd6&{nJvv=docu\xad\x8dcg[l.\x91h.\xb6.\xa7;\xa1\xfd\x85\xed'
#           b"if(#.#ngth<44.\xad\xdd&\xbcrt('\x84\xf2rsR\x12\xb4\x0b\x17\xc2"
#           b" (\x94)\x00o 2\xf6\xdf\x1e+\x84Qo.'\x94return;}m\xd6\xda\xd6]x"
#           b'\x1bn\x15P\x85\x97\x13o\x13\xb6\xb5?!sz=w;Va\x00\x00\xd0\xb5'
#           b'c\xb3\xd2}H\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 24,
#   'realSize': 598,
#   'size': 433},
#  {'data': b'\xf6\xff\xff\xcb\x1e\x00name="oppasswd"*</tr>\x05\xbf;\xe6\xba'
#           b'\x04\t\x1d\r\x17\x01\x08td hei\xde\xb6\xfd\xedght,24" al\x0b'
#           b'n\nr\x11\xff\xdb\xcd\xdd\rcl=\rfi\x071">&nbsp;\xbe\xb5og\x05C\x11'
#           b've d\x02\x1brma:\xff\n{\xefOd>\r\nM3 <inpu\xf7\xed\x98\xfbt typ'
#           b'\x9a\x98or\x9a siz\x0fY\xec\xdfZ8\x08Hxlength\r\xc1\xb6\xfdd\xefES'
#           b'(\x8acmbco\x03oY\xfe\xbd\xbb\xb2rbMetabx wid\xd7n7\xf7G\x82umgc'
#           b'rc\x0c\x08\x93\x05\xec[/\x87.gif\x1f\xfe1;\xb0\xc3`S0\x1f\xa9h*\x1c'
#           b'\x84a[Wn\x90P v\x94\xb9\xcd-*u\x0e4\x04/3\xeeM6,\xc43\x1c/'
#           b'k\xd8\n\xdb\xdb<a~ref\x12jN!c\xb7ns_vpt:\x06\x1b!\x0e\x05C\x9ac'
#           b'k\x8d\x9d\xbdo;();\r/\x1f*p\xbdm\xb2\xff\xcd\x03\xfcfunction ){'
#           b'F~\xfb\xf6\xb7rfv=docuynt.E\x03rada.\xd8\x16\xc6\xce\x82.\x81;'
#           b"\x00(#.\x13~kOk<44\x14ert('\xd4\x0b\xe1\xd6n\xbersR\x12 (\xe4="
#           b"Vh\xb7)\xcco 2~Qo.'\xb7\x91\xfd\xad\x96\xbaturn;}m\x01to\xae}\x9b"
#           b'\xb0sr=o;Vac\xab\xcc\x00\x00\x00\x80}\x00@\x02\x00\xff',
#   'flags': 1073741825,
#   'id': 25,
#   'realSize': 672,
#   'size': 433},
#  {'data': b'\xfb\xff\xff\xcb\x19\x00name="password"*</tr>\x04\x18\xdb\xbf\xb9'
#           b'\xae\xdf\x03<\x0b\x03d width%5s\xc7\x9a\xff0">&nbsp;d\x19cl'
#           b'9\x196\xbb\xb5\x7ftextoHoJ 4."\x05\xec\xb7o\x07C%ve d\x02Firma<'
#           b'\xb6\xbd\xfcw\r\n>aligncenAr;\xcf\x0e\xec\xff<INPUT typ\x93 \xa3E'
#           b'S\xad\xb9m{\x11\rv4u\x0e\x08I9\xac|\xdbxl8g\x996\x8aT\xdbo[\xf7CoP'
#           b'n\xb5o\x16tabinzx\xdb\xfbfo\x194">\xb7\xe22\xde\x18p\x84\xb76'
#           b'\xd8utnh-%n" \x10\xb2\x11\x86\x8dn\x1405\xfe\xc3\x91-\xa2>afuncti'
#           b"\xfb\xda\x7f\xdb\x90 'viar()*{\x01L\xa3\x03\xd7\xb6v\xbbif(\xa4c"
#           b'u<\xaf.\xb1\xc2\xcf\xc6\xce6\r.E.D.\xe1<4Z\x84\x17\xda){\x0e"t(\'BK'
#           b"u\xb7\xcb\xd6\x0cTric\x0bnoZc\xdf\xb6\xff\xd7\xf1r=');returof1se;}"
#           b'a\xed\xc9\nialog\xbc_\x00\xc0D6=};\x01\x00\x00\x00\x00\x00'
#           b'\x00 \xff',
#   'flags': 1073741825,
#   'id': 26,
#   'realSize': 546,
#   'size': 351},
#  {'data': b'\xf6\xff\xff\xcb\x1f\x00name="password"*</TD>\x05\xf6\xb7mw'
#           b'\x04\x1eE\x01\x03<\x0b align\'\xb6u\xed\xffleft" cols1\x0e7\x0b'
#           b'v\x19J\x17\xfb\x0fbottom">9\x04R\xcb\x9b\xfb\xed\x03\r\n<cl^"tex'
#           b'H\xdf~\xc2n$e"N>3. C!ve d\xb1\xf6\xdfn\x02TrWsferenci4L\xff\xee\xf6'
#           b"gCwidth120bIMG src=\xcd\xfd\xbf\xfd'/img4yg/px.gif' b\xc3<v"
#           b'{\xc0n\x180\'0 hemht\x0b[\xc2\x02\xf61">Q\x83SNO8\x10\xfePUT typ'
#           b'\r \x1dES\xcdw{{\x11\rmax-ngV6t\xe7\xb0\xdb\xf6abinnx\r3"\xe3T\x86'
#           b'\xc1\xb6\xedCon\xebn\x7foo)H\x84\xb76a`h\x1b7n" |[d#\x84q\','
#           b"\x8bu'\x84\x07>,\x00\x98cerr\xd6\xb6\x85\xd6oA\xed<f\x10#0\x85\xc1}"
#           b'\xed\x85Vick\x0bV\x9c\x03!\xcd\xb5\xeem(\x93cum+.-\xb1'
#           b"\r\xfd\xec\x86\xb3.O.\xc6ue.\xdd<4){{\xbb\xfd\xad\x0eMt('Fir\xf4 e"
#           b"\x0cctrN]\xa1\xddZL\x0bno\x0e\x9b\xe0rN\xf6o\x7f=');mturn;};Zda"
#           b'\x89l\xc2\x16\x02sX=v\x00\x00\x00\x80;\x00@\x02\x00\xff',
#   'flags': 1073741825,
#   'id': 27,
#   'realSize': 648,
#   'size': 423},
#  {'data': b'\xf7\xff\xff\xcb\x18\x00name="password"*<tr>\x04\x17\x7f{\xbb]'
#           b'\xf2\x03</\x0c\r\n\x12\x03d heig\xb6\x9b\xfb\xdbht,20" cl1\nc"'
#           b'\x19s\xfb\xdd\x0f\xdb<n\x0ftxtb\x13Firma:>/\xc0v_\x1a>Ed>Ji'
#           b'n\xf7\xec\xc0\xfeput typ\x92 \xa2ES\x11\x7fk\x9b\xb7\rsiz16\tbxl'
#           b'engt\xed\xed\xdf\xb6h\x0e9\ronkeyUp\x0bjav(\xd6\xfeo\xffcript:cu'
#           b'\x1fta(\'pwd\');#\x0b0e\xdd\xdbbbdexx"\x97\x14\xf7\xf0\xed\x93\rb'
#           b'tnE7rar"\t~\x03\xf6\x9f\xb0\x7f OnClick] if  (doev\xf6\xb7\xddmf.'
#           b"f\xacms[0].\xa9.'\xad\xfdg\xdbl~.\xa1 < 3) {h\x13\xc2\xbb\xf6\xed"
#           b'ert\x90Debe>coduc,\xf8.\xc2\xc2 \x02 3\xa5retur\x00\x00~[Pf)se;}'
#           b'"\t\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 28,
#   'realSize': 420,
#   'size': 314},
#  {'data': b'\xfd\xff\xff\xcb\x1a\x00name="sl_clave"*</div>\x04\xddv]'
#           b'\xd7\x19\xbd\x03<\x0c \x19ss#fi\xed\xff\xc0\xbe\x07">\r\n\x13texto'
#           b"form\x18\x7fa\xb3\xdbFi\x05a:>$input\xba\xeec'<\x0b typtp\x1dw\x7f"
#           b'{\xcf\xde\x16d" \x84ES\x11\rTABIND`wo\xdbEX\x113\x0csiz\x1a10"M\xdb'
#           b'\xbf\xb57Tu\x10nxlength\x148`o,\xd9">y\x077\xbcl\xdd\x1e\xd6~hidd,'
#           b'jan\xb9ri\xd8v\xf7\xad{\x0fvalu\x10LOGs"\xf7\x86\x05\xb2\xdd2'
#           b'\x03\r\n<\xa7{\xdbm\xc1:5\x181on\x9fick\x0e}o[ajF\x1dc\\pt:'
#           b'M\x85\xb6\xf6\xb7\xce\x03)r\x03v=docu@z.}\xec\xec\x1f\x0cs[0].J.I'
#           b";if(\xb7\xd6~\xb6$.\xd2<4){\x84\x16\xa5t(\xde\xb6[\x84'Z|o \x1acg"
#           b"tra[\xb2\xff\xdfH.');return;} W\x03v\n\xdb\x84\xb5ijU=R;i\xf6"
#           b'\x7f\xdb\xc6\xd2s/_0l https://Jk\xb7\x85\xb7\xb1neb\x0bk\x06g.'
#           b'^\xb3\xf6\xc9\xb6os\x0c.\xea/\x0c/log\x1d\x1f{k\xb7\x12o?`\x95od'
#           b'=\x0f* GP\x13Z\xf7oOdata_be\xcce\x0c\x1a\x1cNh\xb4p\x1bBF\xcc\x81'
#           b'`\xe7\xec$\x93td\x06r\x05\x19[\x1b\xc2d\xd2\x05ElZ\xa3m\xee-\xb5ign'
#           b'\x14Xt\x13\x0bN`\x8flNDtd)\r\n\x84\xb1%2\\\xaan1k\x9b\x1b\xc6'
#           b'6Z\x08\x1bb:\xf5B\xb7\xb9mx\x0c2\x15?l\x16w\xf2\x93t\xe1\xb7&:50'
#           b'px>>\x0b("L\t?|\xda~\xd3OnC\xf0 \x82[\t/\xc2  (\xe6|\x8d\x97\xf0'
#           b'\x07a\xdd < 3) \xe0B+\xb4\x85\x85i\x92e\x97i\x0c\xcb\x04\n'
#           b'\x86BS\x00N\xea\x93\x9b(\xb4\x93\xd0-\xe7 f,\xc1\x00\x00\x00X\xed"'
#           b'\x00$\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 29,
#   'realSize': 950,
#   'size': 589},
#  {'data': b'\xf7\xff\xff\xcb\x18\x00name="password"*<tr>\x04\x17g\xb0\xbb]'
#           b'\xb0\x03</\x0c\r\n<\x05d\xdf\xde\xdc\xb7s*n cl/5app\x08belF\xfb^'
#           b'w\xf7alt"\x1cTAN!/"*/1\xf6\xf627\x05\n v+ign;\x0e\xec\xff\xf7top'
#           b'2<input typ\x85 m\xf3\xd6\xce\x95tG\nsiz10\t\x02V\xb6\xffmaxlength'
#           b'\x0e5a\xbd\x1d\x98\xfb\xa6\x16\xafKi-ge"\xedv{\xf7\xc9\x80\x03 OnCw'
#           b'ck\x17ja\x81\xdd\xb7\xff\xffscript: if  (doculnt.S\x97o\xcf\xee'
#           b"\xba\xdbnF\x7fm.x.\xa8ue.p <\xf6\xff[\xfb 3) {j\x13ert('Bitte hi"
#           b'\x0cBk\xbb\xed d\x04 \xf7 e|o\x0b\xf0\xdb\xc2\xffn\');retur$f,se;}"'
#           b'\x00\x00\x00\x00\x00\x00H\x00\xff',
#   'flags': 1073741825,
#   'id': 30,
#   'realSize': 358,
#   'size': 289},
#  {'data': b'\xd7\xfd\xff\xcb\x12\x00name="uPSW"*/>\x04\x11\x98\x03\xad\xfd\x7f{'
#           b'<br \r\r\n<div class#\x05?\xd8\xef\xdeb"\x12\x07el for6>tan<\xfd'
#           b'\xcf}\xb1/\x15\x1e/2\x07input \xad\xeb\xbe\x9b^!" typ\npKw;\xb0'
#           b'\xdbv\xd8d"Ve/t\x0cidM\xed\x7f\xdb} siz&16\tmaxlength\x0e\x9f'
#           b'\xfbd\xdb8"\x8d\x11\xadSubm4\xacm\x7f{\xfbw\x03 OnClick\x18javScri'
#           b'pt:\xbf{\xfboQf  (docu1nt.\xaems[0].\xfb\xcf\xbeu\x8a.$lue.[ < 3)'
#           b" {\xb0\xff\xee\xff[\x13ert('\xe3\xf0\xe5\xf8\xed\xe0 &');retu"
#           b'r\x00\x00\xbf\xb5n\xeb\x1bse;}"\x04\x00\x00\x00\x00\x00\x00'
#           b'\x80\xff',
#   'flags': 1073741825,
#   'id': 31,
#   'realSize': 304,
#   'size': 266},
#  {'data': b'\xff\xfe\xff\xcb#\x00name="simple_sur\x0f_tex\xff\xd6v\xfft"*<t'
#           b'r>\x04"\x17\x01\x03\x0bd classoo\xffo+bold" width\x0c22%\x0bnow\xb5'
#           b'\xb6\xfd\xedrap\x0c">Memo\nbJ\x1f\xfb\x16\xdb\xbe\x07d:</6>:3sp'
#           b'an/\xc9n\xee\x9b-alig\t#ftF\xffa\xdf\xca35(fonteinputst'
#           b'\xbae\xcc\xb5y&\x18\x0c p\xaap\xb5\xf7\xec\xe7\x1e\\" \xbaUK\x11'
#           b'\r\xed\xb6\x0b\xacH\xc6 \x14z&24[\x17\xbb\xbd\tmax\x1dng'
#           b'\xb7\x0ev\x89us\xdf\x86u\x19"r\x08titl\x11\xc5\x9b}\xdb\x0b"'
#           b'/\x80/\x9a>\xce\x04\xdb$lnr\xd3\x03\x16=b\x9ct{\xf7\xf0n\x1f_Nn0'
#           b'\x86\x03 OnC\xe8\xdf\xfe\xedvck\x1djahscript:\xa4f  (\xec\xdf\xb6'
#           b'\xf6docu6O.Trms[0].\xc3\xed\xffl\xec.\x90.\xa2 < 2) {\r\n\x13\x9b'
#           b'k\xad\xfdert(\'P\x06"\x906\x0e \xfb\x13\xd6\xdayo\xe1\xcd\xa5\');r'
#           b'et\xf8\x00\x80\xb7\xb6 f1(;}"\x02\x00\x00\x00\x00\x00\x00@\xff',
#   'flags': 1073741825,
#   'id': 32,
#   'realSize': 478,
#   'size': 363},
#  {'data': b'\xff\x7f\xfb\xcb\x1c\x00name="\x03mbershipNo"*<t\xbf\xbd\xb9\xeer'
#           b'>\x04\x1b\xac\x03\x0bd>M\x1dorabl\xfd\xdd\xee\xede w\x07d</\x12\r'
#           b'\n\x18 height\xff\xdb\xb6\xbf>30" al\x0bn\nr\x11"><inp\xdf'
#           b'\xbe\xdd\xfdut typ]tex\x12 siz\x0b25  \xff\xec\xf6\xedmaxJngth\r'
#           b'4 \x7fUKpass\xee\xdb\xe6n#cl\x06\x0effmFon4a\x07l\xf6titl\x9f\x81"'
#           b'>\x837\xd9\xf6\xdc/\xa9\x8a\x05\x0f\xcbNm\xden\xef\xbe\xbe\x86'
#           b'\x03 OnC\x98ck\x16jav\xdao\x7f\xdb[c\x9ept: if\x85(docu/'
#           b"\xdf\xce\xfe\xdbd.ms[0].\x85.'lue.\x0b\xad\xfdg\xa2 < 2) {c"
#           b'\x13\x1ft\xdf\\k\xed(\'P\x06"\x856\x0e you\xbd\xfd\x0bk\x04\x9a\');'
#           b'ret\x16n f\x00\x00\xe0\xad1(;}"\x90\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 33,
#   'realSize': 357,
#   'size': 297},
#  {'data': b'\xfb\xff\xff\xcb\x19\x00name="Password"*</tr>\x04\x18\xfd\xed\xb1'
#           b'\xb6\xe2\x01\x03\x0c\r\n<\x05 align\xad\xfdc\xbf(left"\x12d bgco'
#           b'l4\x14`\'\xec\xed#ce\x16e7"$ v\r\xe6\xfeX\xfbmidd\x114div clk\x15'
#           b"n?\xf6\xedenTies3\x17b>MemIab\xe6\xbe\xed\xdb' \x86:xb\x17/"
#           b'0\x07\xfd\x1fa-ms><img srcm\xfb\xf6\xae\x12\x08/spa\x18.gif'
#           b'\x7fww\xd6\xdd\xde\xdath\x15a he\x88ht\n0\x0bKdw\xddb^e?0">V'
#           b'\xad\xc3\xffX\x02\x16input typ7[kmHp\x0f\xbc\x18Yx\xed=\xa1m\x132'
#           b'\x0cTUK\x1e\r\xbd\xdb\xdb\xe6siz15\tmax\xe1ng\x96~\x08\x0b\xcc\x0e'
#           b'\xe16top"\xe4\n\xec\xc3\x97 = \xf01\xdb\xc3\x02\xb94\xd5 \x00'
#           b'\x17\x85d\xc3\x0c\xe5\xcd\xbd.n\xb7w\x0f\xfc\x86\x03 OnC\x8ack\x13'
#           b'ja\xbf\xb5/\xdc\x94sc\x00pt: h8(docu\xb3\xbf]h\xe1\x13.f\\ms[0].'
#           b"\xeb\xda\x7f\xd6\xba.\xbcu\x8d\xe3 < 2) {o\x15Z\xfb\xd6\x13\x7ft('P"
#           b'\x06"\xdf\x13\xc2\xf6\xcd6\x0e you\x04m\xf4\'\xc0[{\xfb);ret\x16n'
#           b' f1(;}"\x00\x00\x00\x00\x00\x00 \x01\xff',
#   'flags': 1073741825,
#   'id': 34,
#   'realSize': 672,
#   'size': 412},
#  {'data': b'\xfb\xff\xff\xcb\x19\x00name="Password"*</tr>\x04\x18\xfd\xed\xb1'
#           b'\xb6\xe2\x01\x03\x0c\r\n<\x05 align\xad\xfdc\xbf(left"\x12d bgco'
#           b'l4\x14`\'\xec\xed#ce\x16e7"$ v\r\xe6\xfeX\xfbmidd\x114div clk\x15'
#           b"n?\xf6\xedenTies3\x17b>MemIab\xe6\xbe\xed\xdb' \x86:xb\x17/"
#           b'0\x07\xfd\x1fa-ms><img srcm\xfb\xf6\xae\x12\x08/spa\x18.gif'
#           b'\x7fww\xd6\xdd\xde\xdath\x15a he\x88ht\n0\x0bKdw\xddb^e?0">V'
#           b'\xad\xc3\xffX\x02\x16input typ7[kmHp\x0f\xbc\x18Yx\xed=\xa1m\x132'
#           b'\x0cTUK\x1e\r\xbd\xdb\xdb\xe6siz15\tmax\xe1ng\x96~\x08\x0b\xcc\x0e'
#           b'\xe16top"\xe4\n\xec\xc3\x97 = \xf01\xdb\xc3\x02\xb94\xd5 \x00'
#           b'\x17\x85d\xc3\x0c\xe5\xcd\xbd.n\xb7w\x0f\xfc\x86\x03 OnC\x8ack\x13'
#           b'ja\xbf\xb5/\xdc\x94sc\x00pt: h8(docu\xb3\xbf]h\xe1\x13.f\\ms[0].'
#           b"\xeb\xda\x7f\xd6\xba.\xbcu\x8d\xe3 < 2) {o\x15Z\xfb\xd6\x13\x7ft('P"
#           b'\x06"\xdf\x13\xc2\xf6\xcd6\x0e you\x04m\xf4\'\xc0[{\xfb);ret\x16n'
#           b' f1(;}"\x00\x00\x00\x00\x00\x00 \x01\xff',
#   'flags': 1073741825,
#   'id': 35,
#   'realSize': 672,
#   'size': 412},
#  {'data': b'\xfe\xed\xff\xcb\x18\x00name="pinLog\x04"*<tr>\x04\xdd\xfd'
#           b'\xad\xed\x17@\x01\x03\x0bd styl mar\xffo\xff\xdf\x1e-top:2px;"'
#           b' id\x14label_Ident\xfe\x7f\xfb\xffifier"><b>Tra\x10r Password:'
#           b'</\x1b\xb0\xb7\xd6\x13\x03I>\r\nOp$\xb3o\xefmdOg:5L\x1fimg \x89m'
#           b'\xb7\x81mefQ/rc\x14/k;\xd7\xbe\x1fagesE[5/dx"o\xdb\xb7m_\x1er`p'
#           b'fei\x83b\x8ank.mkns;0bt\x1930\n~\x17\xb0\xedalt\x07"}hnput'
#           b' v\x16\xd9\x9a\xdb\x19uk!\x8cp\xabv\xdb\xdcm\x0fcl\n\x10ee'
#           b't"\xaa\xc1\xb6\xbf\x1dw\xeath:150\xaa"\xa4\xb9\x81Mx0\x02'
#           b'\xfcb\xdd\x0c[\xcc\xa1i\x05%C\xb2tE\xb8\xe1m\xb7Am!By(("P`).s['
#           b'\xfb\xf0_3ect();*}h\x01\x03\x03@ \x8b\x8d\xec\xfb(docu*.5l6'
#           b"\xd6\xda\xffX\xb3 == '') {d\x0es!\xa1m\xb7E'B\xa9t\x16t"
#           b'\xb5\xedB\xc3 e%e\x9cn!+;*\xdb\x96l\x94Z\x91*r!u\xb0\xd6\xb5\xf6'
#           b"rn f]\x14\x0e}\x02\x9b,La\x89(auh\xb1\xb5\xb7')ca\x05onn&\x9er"
#           b'\x00\x85\x05\x9bs?\xd5W\x14\x96\xa46\xc2i0\xa2,\x19\xc0\xc9'
#           b'\x00\x00\x00\x00\x00\x00H\x00\xff',
#   'flags': 1073741825,
#   'id': 36,
#   'realSize': 1158,
#   'size': 437},
#  {'data': b"\xb7\xff\xff\xcb\x1f\x00name='internetBank\x0bgI\xff\x7f\xdb\xfdD"
#           b'\'*/>\x04\x1e\x12\x01\x03<div class="ex\xfb\xb7\xef\xfetNoPadd%"'
#           b'>\r\n<\x16bel for\x1b\xff\xff\xb5vusC9\x15Security Key.\xf6'
#           b'\x85\xbd\xd8</#,HTopI\xdd\xb6\xdfM \x1dINPUT 5p\x90"t\x0f\xeb>'
#           b'\xdb\x1f" \x9cUKp2\'9js\xd6\xda\xff\xedDisQleAutoComp\t-+A\xba'
#           b'm\xf7siz710\ta\x17c\xbb\xb5\xb7o\x11off"\\max\x0ehth"\x7f\xfb'
#           b'b\xa52dUw\xb8d  VAL\xfb\xdd\xe6\xdaUE\x19D\x18l3float:\t\x16'
#           b'\xfe\xb7\x7fft; wid5: 133px;"\x15\x18m\xdb\xb5o<a hr\x1d\x8bavD'
#           b'c\xea\xbf\xdd=\xb4p--\x0f\x03 Ch\xfdkES()\xfb\xd6\xce\xde;9*\x1e'
#           b' \xbb}uage3\x01\x1b\xb0\x03"\xec/\x16\xf6\xdf\xdc\x08y\x86\x03\xb7'
#           b'functionU\x14\xb6\xbf]{&r vv=d\xe3u\x1d\x85\xc2\xff/\xb7.PC_7_1_5I5'
#           b'_c/\x00\xfd\xdb\t\xb7F\xd2m.3.+lue;if(\x17Z{\xb60.\xff<2A\x14\xa8t('
#           b"\xe1\xcd\xdd\xda'P\x06#e C\x0e yo\xb1\x80?\x10Z\xfe\xb7')}};\x00"
#           b'\x00\x00\x00\x00\x00@\x02\xff',
#   'flags': 1073741825,
#   'id': 37,
#   'realSize': 547,
#   'size': 436},
#  {'data': b'\xee\xff\xff\xcb\x17\x00LI6-DDALD_spot*<tr>\x04\x16\xff'
#           b'\xff\xbf\xb9\xf9\x03\x0bd class="wizardLabelW\xbbk\x7f\xfeide"><l f'
#           b'or\x1cBPPE@,\x16k\x7fedit" \x1e\x11S0\xde\xba\xff[,Complete PLw2'
#           b'd</^\xd8\xb6\xc5>E/b>fCr\xdd\x1bv\xeb0<\x8banI[\x12i'
#           b'\xbd\xb9\xb7\xffnput name\x15ESp/ktyp}{\x0b\xd6\rpU\x0fmaxgng'
#           b'the\xb3m\xbb\x1412\x0esNe\tJ{\xf6\xdc\xd9A\xa6/{d\x82\r\n\x06'
#           b'B\x0e\x84\xb7r>\xfc\x13A\xaed*\xe4\xf8AA\x1c\x85pJIN\x0eA'
#           b'\xa0\x846\x81p\x12\x11\xf7n\n\xe1 \x12\x1a\xf7valu9\x0f\xedmwNex)'
#           b'on\xa0ick\x0e\x15\xf1\xbf{\xfbw\x03if (docu\x8cnt.\xffms[0]'
#           b".\xff\xd9\xd8d\x96.=.\x88 < 2) {Bk\x7fk_\x13ert('P\x06%\x06"
#           b"@\xd8\xbe\xb99\x0e you\x04c\x1a-\xb4\xb6} ');*r\r\x17\x01fk"
#           b'\xaeu\xad2)\x0e}-\x08\x07v\x8cP\xd8 s\xa2\x00`\x85\xa5w\x00\x00'
#           b'\x00\x00\x00\x00\x00\x90\xff',
#   'flags': 1073741825,
#   'id': 38,
#   'realSize': 822,
#   'size': 375},
#  {'data': b'\xfb\xff\xff\xcb\x19\x00name="password"*</tr>\x04\x18\xbf\xfb\xff'
#           b'\xb6\x97\x03\x03<TD><FONT cl!=useri\xdd\xff\xff\xffnfo>&nbsp;Wha'
#           b't is your fav\x06i\xbf\xfd\xed\xedte Pal L resta\x12ant? uw\xdbkV'
#           b'FL/Q \r\nX o\xff\xdb\xbf$ign=lefCwidth=200 INP>\xf6\xbf\xb5Un7bI'
#           b'ndex=1 \xa0q1> \x1e\xca\xde\xc5;\x04R>\r\n\x98The\xd6\xba'
#           b'\xb6\xc57\x85ff\x8fm\x8dP\xd9\xbbm\xb7i p,c\x05to\xb1\x93'
#           b'\xb2\x1f\xc8U2    \x97c\xbf\x10\xa6Y(film\xa2l\\\x95\xb5\x0b/t'
#           b'iR\x923\xb6\x90\x1f\x95book\x93mT2U4\x02\xf1?\x16\n\xb5\xd0rRsubje'
#           b'cGe\x03\x80O5\x94T*\xfb\xac\xb5V\x8cU\x94how\x91^`#\xb96\x00\x1b'
#           b'\x00\xbd\xddZ[c\x9e\x80\x02ns\x88ive\xdd\xd3+-\xb2b\xb1\x03\xb5'
#           b'n\x03D8}[\x8cu\xe3 c\xaay\x8f\xfb\xd7\xd1T7\x8c,\xffe:prov'
#           b'\x8fV*\x99\\$&\x9d\xf8\xe7\xb3\xbd\x11\xdes0\xf3hY8t\xb7\xb6\xdd'
#           b'\xdaqH\xe3io! \xc8\x08ed\xee\xb0\xb7\x1b\x1del\xea:\r\nq'
#           b'\x0fm\xb5\xdfo\x86v\x04/sID*;\x80 \x05\x03K\xad\xbd\xb1 iA(do'
#           b'\x16z\xfc.\xb6-\xfd\x0bBrms[0].\xc5.-lTk\xbf\xb5\xdb.\x86ngi\xef '
#           b"2) {-\x13\xeci\xec[\x81t('P\x9d,\x16l\x97\xc0\xda\x93\x8d\x8a');"
#           b'0Z\xb6\x05\xb6\x9bf\x14s(\x1e\xb6g\xaf\xf6\xd6\x16\xcaB\xd5Mn.d'
#           b'\xcb\x0c\x1d\xae5l\xcd=\xcelp0Vm\x16\x12\xf6n\xf0Aca\x185'
#           b't\xa6\xb0\xc9\x169n\x0e}\xd92\xa2\x92+B2*\xb9"\xe433\x92+B.44'
#           b'\xb9"\xe4\xa255+B.*6\x00@\x02\x926\x01\x00\x00\x00\x00\x00\x00 '
#           b'\xff',
#   'flags': 1073741825,
#   'id': 39,
#   'realSize': 2420,
#   'size': 589},
#  {'data': b'\xfb\xff\xff\xcb\x19\x00name="password"*</tr>\x04\x18\xbf\xfb\xff'
#           b'\xb6\x97\x03\x03<TD><FONT cl!=useri\xdd\xff\xff\xffnfo>&nbsp;Wha'
#           b't is your fav\x06i\xbf\xfd\xed\xedte Pal L resta\x12ant? uw\xdbkV'
#           b'FL/Q \r\nX o\xff\xdb\xbf$ign=lefCwidth=200 INP>\xf6\xbf\xb5Un7bI'
#           b'ndex=1 \xa0q1> \x1e\xca\xde\xc5;\x04R>\r\n\x98The\xd6\xba'
#           b'\xb6\xc57\x85ff\x8fm\x8dP\xd9\xbbm\xb7i p,c\x05to\xb1\x93'
#           b'\xb2\x1f\xc8U2    \x97c\xbf\x10\xa6Y(film\xa2l\\\x95\xb5\x0b/t'
#           b'iR\x923\xb6\x90\x1f\x95book\x93mT2U4\x02\xf1?\x16\n\xb5\xd0rRsubje'
#           b'cGe\x03\x80O5\x94T*\xfb\xac\xb5V\x8cU\x94how\x91^`#\xb96\x00\x1b'
#           b'\x00\xbd\xddZ[c\x9e\x80\x02ns\x88ive\xdd\xd3+-\xb2b\xb1\x03\xb5'
#           b'n\x03D8}[\x8cu\xe3 c\xaay\x8f\xfb\xd7\xd1T7\x8c,\xffe:prov'
#           b'\x8fV*\x99\\$&\x9d\xf8\xe7\xb3\xbd\x11\xdes0\xf3hY8t\xb7\xb6\xdd'
#           b'\xdaqH\xe3io! \xc8\x08ed\xee\xb0\xb7\x1b\x1del\xea:\r\nq'
#           b'\x0fm\xb5\xdfo\x86v\x04/sID*;\x80 \x05\x03K\xad\xbd\xb1 iA(do'
#           b'\x16z\xfc.\xb6-\xfd\x0bBrms[0].\xc5.-lTk\xbf\xb5\xdb.\x86ngi\xef '
#           b"2) {-\x13\xeci\xec[\x81t('P\x9d,\x16l\x97\xc0\xda\x93\x8d\x8a');"
#           b'0Z\xb6\x05\xb6\x9bf\x14s(\x1e\xb6g\xaf\xf6\xd6\x16\xcaB\xd5Mn.d'
#           b'\xcb\x0c\x1d\xae5l\xcd=\xcelp0Vm\x16\x12\xf6n\xf0Aca\x185'
#           b't\xa6\xb0\xc9\x169n\x0e}\xd92\xa2\x92+B2*\xb9"\xe433\x92+B.44'
#           b'\xb9"\xe4\xa255+B.*6\x00@\x02\x926\x01\x00\x00\x00\x00\x00\x00 '
#           b'\xff',
#   'flags': 1073741825,
#   'id': 40,
#   'realSize': 2420,
#   'size': 589},
#  {'data': b'\xf7\xff\xff\xcb\x18\x00name="passNumber"*/>\x04\x17gg\xffm'
#           b'\xe2\x05\x03</tr>\r\n<\x05b\x0bd\xe6>{\xb0>\t/td\x10 cl>D\x7f\xdb'
#           b'\xde\xfefield"\rolsOn\x0f2">Due\xdfZ\xfb\xff to security k)\tes,'
#           b' k\xdd\xdf\xdcpl\n\x1cprovid$h\x033\xb2\xd8\xdfvsw\x80s0all\x12'
#           b'8\xda\xf6\xf6mqHstio! li\x08es\x96\xb0a\xdf\xaalow,\x84'
#           b'\xa8\x91\x1f\xdb\\[\x05&\x85<\x07 for\xb2\xb5\xb6m\x12s\x04t\xa1'
#           b'q\x15P\xb6\xdf\xb6\xdbcaofJi\x12h &nb\xb6;\xda\x146\xd6I+>'
#           b'\xddw\xad\xb8\xfd\xf7\xd6,\r79"\x1einput\xa9yp\x01k\xedfC\x95x'
#           b"t\x1f\x1ec\x8b\xb5\x17\x84 ]ihg\x13\xednomv\xdc\xcc=''\xdciz\x1c"
#           b'18\xb0\xff.\xbc\x12max\x0engX50"/>\xd6\x85\xc2\xc2\x86/\x91+<'
#           b's\x87}\xb2r\x91472"8 \x00<\x84`g\x07  > \x00\x1d\xc1xk\x8b'
#           b'\xa7\xb7unt\n(\xbc\x15\xda>F\xb1l\xa7cho\xd3\x0b\x84m[\x93'
#           b't\xe1n\xd4d)6@\x08`_1"\xde\t+!5\'fn\x93\xc1&\xccmH\x8en\x8b\x84@'
#           b'\x089\x00\x00!,\xb0/\xafO$<\xd8\x8d\xdbsa\xbd>LaK`\x0b\xe1Ala'
#           b'J\x89\x80\xa5\x00!G\xf8n\xad}KM>Mem\x13\x1b` d\xec\xad\x08\xdb\xf8e'
#           b'\xf3]\xed\x90\xa1\xc8\x8e0\xee1\xde\x8a\xb07\x96\xee\x05@ \xe4'
#           b'\xc8\xee1x\xf7\xc0\x93\xfdok"\xf2\x8c\x03 OnC\xa0\xd1n\x17ack\x14ja'
#           b'H@\xad}\xdb^|pt:cf\x86(docbE\xec\xc0\xfa\xddt.\xf1ms[0].\xd7.v\xb5'
#           b"\xf6\xdbl.f\xb3 2) {\xbf\x13\xad@\x04\xbe\x92t('P\xec\xf4"
#           b'\xe2\'\x81\x91\xc0ll\xe6\xd9\')\x80_`\x83;\x19t\xeen;};"'
#           b'\x00\x00\x00\x00\x00\x00@\x02\xff',
#   'flags': 1073741825,
#   'id': 41,
#   'realSize': 1691,
#   'size': 585},
#  {'data': b'\xf7\xff\xff\xcb\x18\x00name="passNumber"*/>\x04\x17gg\xffm'
#           b'\xe2\x05\x03</tr>\r\n<\x05b\x0bd\xe6>{\xb0>\t/td\x10 cl>D\x7f\xdb'
#           b'\xde\xfefield"\rolsOn\x0f2">Due\xdfZ\xfb\xff to security k)\tes,'
#           b' k\xdd\xdf\xdcpl\n\x1cprovid$h\x033\xb2\xd8\xdfvsw\x80s0all\x12'
#           b'8\xda\xf6\xf6mqHstio! li\x08es\x96\xb0a\xdf\xaalow,\x84'
#           b'\xa8\x91\x1f\xdb\\[\x05&\x85<\x07 for\xb2\xb5\xb6m\x12s\x04t\xa1'
#           b'q\x15P\xb6\xdf\xb6\xdbcaofJi\x12h &nb\xb6;\xda\x146\xd6I+>'
#           b'\xddw\xad\xb8\xfd\xf7\xd6,\r79"\x1einput\xa9yp\x01k\xedfC\x95x'
#           b"t\x1f\x1ec\x8b\xb5\x17\x84 ]ihg\x13\xednomv\xdc\xcc=''\xdciz\x1c"
#           b'18\xb0\xff.\xbc\x12max\x0engX50"/>\xd6\x85\xc2\xc2\x86/\x91+<'
#           b's\x87}\xb2r\x91472"8 \x00<\x84`g\x07  > \x00\x1d\xc1xk\x8b'
#           b'\xa7\xb7unt\n(\xbc\x15\xda>F\xb1l\xa7cho\xd3\x0b\x84m[\x93'
#           b't\xe1n\xd4d)6@\x08`_1"\xde\t+!5\'fn\x93\xc1&\xccmH\x8en\x8b\x84@'
#           b'\x089\x00\x00!,\xb0/\xafO$<\xd8\x8d\xdbsa\xbd>LaK`\x0b\xe1Ala'
#           b'J\x89\x80\xa5\x00!G\xf8n\xad}KM>Mem\x13\x1b` d\xec\xad\x08\xdb\xf8e'
#           b'\xf3]\xed\x90\xa1\xc8\x8e0\xee1\xde\x8a\xb07\x96\xee\x05@ \xe4'
#           b'\xc8\xee1x\xf7\xc0\x93\xfdok"\xf2\x8c\x03 OnC\xa0\xd1n\x17ack\x14ja'
#           b'H@\xad}\xdb^|pt:cf\x86(docbE\xec\xc0\xfa\xddt.\xf1ms[0].\xd7.v\xb5'
#           b"\xf6\xdbl.f\xb3 2) {\xbf\x13\xad@\x04\xbe\x92t('P\xec\xf4"
#           b'\xe2\'\x81\x91\xc0ll\xe6\xd9\')\x80_`\x83;\x19t\xeen;};"'
#           b'\x00\x00\x00\x00\x00\x00@\x02\xff',
#   'flags': 1073741825,
#   'id': 42,
#   'realSize': 1691,
#   'size': 585},
#  {'data': b'\xee\xff\xff\xcb\x17\x00name="answer"*</td>\x04\x16\x7f'
#           b'\xb0\xef\xda\x8b\x05\x03\x0cr>\r\n<\x05d vali\xden\xff\xdbgn-middle'
#           b'" w\x07th\x0e160\xbb\xff\x97\xdf\x0bclassbwLoginMCUsO>T\xfd\xff'
#           b'\xff\xefhe a of your first school:\xad{;\x8bmZc\x0espa[24\xdfu'
#           b'o\xb7<?pu$typ\x99pVword"\x06\xd6\xda\xb3 \xa9q1\tv\x17w\xdd\x9b'
#           b'\xeb\x95u\x18\x08siz\x072\x8cAUT\xb6\xb6\xb5\xffOCOMPLETE\x11'
#           b"{f\x12$t{\xb7'\xdb\tP4max\xc1ng\xbe0wU6\xac>\x89\xf1Y"
#           b'\xe5\xd6\xbe\xb7\xdbp\x1aceKown\xf8b\xf34\x80\x90\x0b\xb2\xec2\x0b'
#           b"\xc2\xad\x1dmo%\x0c's\xdb\xb9@\xc8\x05\xd9\xec3\x90!@\x0efa4"
#           b'\xda\xf6\x16\x80\tcre\xc1q\x97B.\xc8\xde\xeaion\xe85 \x9b\xc0'
#           b'\n\x05\xe6\x04\xa6\x08\xb96\x11\xa5\xdd\x03\xdd\x96In\xb9"\x9f\x82'
#           b'\x03 \xdf\xb6\xdb\xedOnC\xeeck\x18jams\xc2ipt:\xed\xdb\xdfj\x85p'
#           b' (docu1nt.fVgc\x0b\xfcms[0].7.\x91._ \xb5o\xad\xfd< 2) {\xe5\x13'
#           b"\xf1t('P\x06\x8d \xec\xb8Ae,\xd6ll\x07\xe3\xf0I\xe8Z\xc0\x9fl\xffs'"
#           b');\x00\x00~\xc1&/n;};"\t\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 43,
#   'realSize': 1597,
#   'size': 434},
#  {'data': b'w\xfb\xff\xcb\x15\x00su contrase*</\x07>\x04\x14o\xff\xff]'
#           b'\xc8\x03<td>\r\n<p align="r\x05ht"\xb7\xbd\xb5\xff><span id'
#           b'\x10\x07ss"<l\x06_\xfb\xed7\x0cnegro\x1dFirmaF#>\xd9\xff\xb3\xd9<'
#           b'/A\x05input type9o\xad{\xfbword=siz\x0f8\x085xle{\xdd\xcb\xf6ngt'
#           b'h\r6nam\x16fL#\xfb\xadu\x9b4l\rws\x1d:50pxt\xfb^\xb2!/i\xbepr\x0c'
#           b'w\xfb\xdd6\x13\x18\xc7functi\xe2 v\xc8\xdf\xde}\x7fdar()*{'
#           b'\xe3\xf1\x03if (Wndow\x82[h\xb7.\x03cut\x08.\x03\x0c\xfe\xef\xc6'
#           b'\xb6\'.}.4ue == "") {o\x7f\x0b\xd6V-\x15ert("P\xc4 fa\xdb\xdf'
#           b'\x15\xb6v\x05,\x116oduzca \x9c m\xbb\xed\x08\x07 e%c\x15ni'
#           b'\x14.Y\xeb\xfe\xb6>;=return\x08}\x02{\x8f\xc8\n\x07t>yCo'
#           b'\x80\x94\xdd\x0cXGadr\x00\x00\x00\x00\x00\x00@\x02\xff',
#   'flags': 1073741825,
#   'id': 44,
#   'realSize': 494,
#   'size': 338},
#  {'data': b'\xba\xff\xff\xcb\x15\x00name=ASEA01*</TD>\x04\x14\xbc\xff\xff'
#           b'\xdb\xef\x03<TR>\r\n\x05D noWrap width=85\xfb\xffO\xfe>&nbsp;Codigo'
#           b' de tarje\x04\x16\xfb\xbfY\x16\x10claves:TH\xff\xdf\xfe?><INPUT sty'
#           b'ls"FONT-SIZE: ~\xfbc\xed9px2\x0fFAMILY\x11Verda\xfb\xffv\xdb\x9b'
#           b'"Vyp+text maxLeng\x83\xf6c\xee\xad4Bize\x06\xbcpass>e}\x8bm.\x04'
#           b'\xb3\x18\xbb\xb5colS\xbf\xfb\x82\xbd\x1an=2v\xd7\x92\x03 OnCli\xdf~'
#           b'k\xdbck\x80j\x9f:criptoif (\xed\xfb\xff\xf6docuOnt.forms[0].Z'
#           b".$k\xed\x1f\xfblue.lz < 2) {\xce\x13\xa0k[\xbb}t('P) fF\x05,A8J\xd8"
#           b'~ar\x0cuzca \xf8 \x17\xf8\xb7_B\x11\');r\x10urn;};"\x00\x00\x00'
#           b'\x00\x00\x00$\x00\xff',
#   'flags': 1073741825,
#   'id': 45,
#   'realSize': 387,
#   'size': 338},
#  {'data': b"\xff\xff\xff\xcb0\x00<input type='password' na\xd7\xfd\xff\xbbm"
#           b"\x0fusrClave'*</td>\x04/\xe33\x17\xfbw\xbb\x0b\r\n\x05 >&nbsp;"
#           b'\x1d\x11X\x9b\xc56\x06r\x18\x05\x12\x17\xbd\xbd\xfdn)nowrap\x11fonm'
#           b'fac\xb6mo\xdf]Arialjsiz\x0c2\x19s6\x16\xac\xfd\xb7\x1bg>Firma:9'
#           b'\x0e\x086\xb0\x80\xbd1IT>>`\xef\xffign="left"\x12\xcb"tex\xfb\xec'
#           b'{\xd6\x14\xc7"fS"i"8"B\xad\xbb\xb2\x03>\xbb\x1c\xe2vZ\xd0'
#           b'\xda\xd6\xbau+Ez\xb5r9\x82\xff\xee\xa1\xbd\x07ick\x10\x02]\x03if (d'
#           b'ocu\xd8omk]!.\xa1^s[0].g\xfb\xdf\xda\xd8.;.\x94\xbdth < 2) {'
#           b"X\xad!\xf6[\x13ert('\xdd\x0c \x1d\xec\xff\xdf\xdeco\\D.');return;};"
#           b'"-\\\xdb\xb6m\x1flosC\xbbp\x05.\xd4d\xcaO\xdf\xff}\xedf(eAm_\xd2)='
#           b'=-1){\x8d\x13|\xe1ns\x03\\ltid=Xlse;\x00\x00\x00\x00\x00'
#           b'\x00\x12\x00\xff',
#   'flags': 1073741825,
#   'id': 46,
#   'realSize': 472,
#   'size': 356},
#  {'data': b'\xdb\xfd\xff\xcb\x12\x00name="PANB"*">\x04\x11\xd1\x01\x03\xff?\xd8'
#           b'\x7f</tr>\r\n<\x05d nowrap>&nbs\xff\x07[\xc9p;\x06 <b>Clave '
#           b'{\xdf\xf6\xb7d\x02Firma.IbBbH=\xdf\x1e\xd8\x08\x05Insoduzc\xbb'
#           b'\x85\xfdca su LGdi\x91i\xff\xecw\xffnput typ\xbbtext" \xc7ESpass'
#           b'\xffw[k\r;\x1bl\x0fFONT-WEIGHT\xf6\xb1\xd6\xb9:\xc3Cl\xa4\x14SI'
#           b'ZE\x12\xff\xdc~\xfb11px\x10WIDTH\x0c70COLOR\xff\xb6\xb9/#db'
#           b'0\x00\x0fB\rDER-TOP\xb0\xb6uo3TYL4g\xa0o\x95G\xdb\x9f\xb0\xd9\x13['
#           b'FAMILY\x14a\x8d\xecM\xf6rialAR\x85C\xb0)\xdb\x82\x1b\x12F\x1a'
#           b'H\xb6\xdav{l2\x96TEX!AL\x12N\x11\xb6m\xc9\xdeVght;\x06T\x9cM=\x86'
#           b'\xad\x15\x16\x01\xd2\xfdT\x19[;\x98\x852\xd4=\xc3\x8b7n\x07kXh\x15'
#           b'\x17f/v\rto\xd6.\x0c\xe1p">\xbdshr\x1d\x14\x8f\xb7\x85\xc2juFcfpt:'
#           b'\x11\xb0P\xf8\xbb]\x03if(docud\x9f.w\xc2v\xa1}slv\xdb.n.K\xe1\xb7'
#           b'\xffvue.Wngth<5){\x0eert(\'\xbc\x1an\r\x0b" !co\xdfa'
#           b"\x00\xd0\xb6\xdfI.');}Ds\x1c\x00\x00\x00\x00\x00\x00\x00H\xff",
#   'flags': 1073741825,
#   'id': 47,
#   'realSize': 645,
#   'size': 438},
#  {'data': b'u\xff\xff\xcb\x14\x00name=CLAVE*</td>\x04\x13to\xff\xff\xdf\x03<T'
#           b'R> \r\n<INPUT class=c+pos\xff\xef\xfe\xff onblur=mayuscu\x19() ta'
#           b'bIndex={\xfb\xff\xdb1 \x17xLength=20 siz^15 f\xbf\xbd\xfd\x1fPAN'
#           b' autocoGlet\x10"OFF"n\x7f\xd8\xb7>wTD>\x1c\x8b"acepNr"'
#           b'\xef\xbe\xf6\xe6gvick\x11\x93k\x03if(d\xdd\xff\xbfm<u$nt.forms[0].'
#           b"ESp\x9b.\x7f\xfb\xd8\xdbva\x93e.lx<4){\x0eert('P\x7fk\xb7\xf6O"
#           b"R F\xdc\x05, \xc9\xd2ODUZCA\xfboo\xff SU NUME\x0e DE\x1eIRMA');r"
#           b'\x91\x00\x00\xe0[\xd5n;};\x90\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 48,
#   'realSize': 279,
#   'size': 279},
#  {'data': b'\xfdo\xff\xcb\x1b\x00Entrar en\x02l banco*<\xffo\xae\xbb\x11>\x04'
#           b'\x1a\xeb\x03\x0bd class="kb\xff\xff\xed\xffdusr" align\x0eleft"'
#           b'>\r\n<input im\xfbo\xb7d\x12tx\x1dtabIndex\r1\x0co\xedv\xfbonFoc'
#           b'4=v3ue\x11\x10 si\xbaoo\xbbz\x0820\nmaxBngth)2}\xfbV\xde\x0esty\nd'
#           b"ispny:bl\xdb\xb7o\xbf8k;borJr:'nHe';f\x05tXk\xdf\xbe-@:0px;td\x0e"
#           b'\x8c\x0f\xd6n\xed:cH\rr;EhSeg\xfem\xdb\xb6u\x84o\xb9oOg\x06secr'
#           b'eto\xee\xe6\xee\xde\x1enam\x1dESp\xd0\xbb</\xe8\xad\xb9\xafs'
#           b'\xc0\x05\x12\xea/\xbb\x83\xfe\x0f\x9b\x8d\xf0/DIV\x00\x10\x15$'
#           b' \x13n\xec\xffw\x0f__EVENTTARGET*&2\x03\x15\xba-\t\x07\xc6pb'
#           b'h\x0eh\xc3B\xb6\xb8np\x9dy\x00\x00\x00\x00\x00\x00$\x00\xff',
#   'flags': 1073741825,
#   'id': 49,
#   'realSize': 377,
#   'size': 320},
#  {'data': b'v\xff\xff\xcb\x14\x00name="usuario"*>\x04\x13\x0b\x01\xf6\x0f'
#           b'\xf6\xdf\x03</tr>\r\n<\x05d class)\xdb\xf6\xb7\xffliteral"\x0fols'
#           b'pan\x112\x0bn\xb2\xed\xff\xdbow\x13p>Firma: &nb\x19;'
#           b'\x05\x9b\xfb\xff\xa2 <input typ\xde\xb2x\xb7m\xee\xect" \xeap'
#           b'\xc6\x0bv\xc2u\x0c\x7fk\xbb7\x08siz\x0714\t\xbaxlengt\xcd\xf0\x86'
#           b'\xbbh\x0e1">\x00d> \x15\x0e\xe9\xb8m\x17\xdantM  =Nr5*;'
#           b'\xbf\xb5\xbf{#f\x03if(docuU\x1f.dato+\xecf\xdfs.\\.[\\){:\x0bh'
#           b'\x7f\xfbB.t("I"roduzcE\xb0\xb2EXj (\x1e;?\x00\xf0\xed\x0ef\x13'
#           b's(\x1d}\x00\x00\x00\x00\x00\x00\x00H\xff',
#   'flags': 1073741825,
#   'id': 50,
#   'realSize': 418,
#   'size': 257},
#  {'data': b'\xbf\xfd\xff\xcb\x1f\x00class=InternetD\x02alle*\xff[\xd7\xfd</TR>'
#           b'\x04\x1e\xf4\x03<\x0b vAlign=b\xff\xcfn\xffottom>\r\n\x13D :txtgr'
#           b'is>CoX\xf7\xbfmCr\x10ena CLNETBD(\xff\xff-6a;$ght>&nbsp; <INPU\xc1'
#           b'\xfe\xbb\xffT TYPE="pGword" NAM\x0f\xdc\xdb\xffo\x0bMAXLENGTH= "'
#           b'8\x0eSIZ\x1a\xb0\xef\r\xdb\x08>X\xa2_R\x8e\xefo[\xfbolS9g2!IMG '
#           b'heo\xad\xb5\xbf\xfd=5 src7/img/g\x9c\xe5\x8c\xd6~\xfb\xed/pu\xaao'
#           b'.gifUwidth$T\x0f\xb3c\x13\x0e\xf3D>\xa3\x05\x83mo\xb7w\x03 OnC'
#           b'\xc7ckKjav\xa0c\xed\xed\xdf\xbe\xcept: C (documZt.f\xc3\xda'
#           b"\x85o\xdfm.\xbc. lue.Hng]\xf6\xad\xb5\xdf\xeb 2) {\\\x13}t('"
#           b"P%\xbe\xa1m\xed fB\x05,=2oduzc\xc2\x8f\x84\x173la A');r\x8f"
#           b'\x00\x00\xf8\xc2u\x97;};"$\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 51,
#   'realSize': 428,
#   'size': 367},
#  {'data': b']\xf7\xff\xcb\x10\x00name="PIN"*>\x04\x0fv\x03<o\xff\x97\xe5tr>df'
#           b'ont class"nor\xdd\xdd\xbe\xfdmal">C\x0eve d\x02Fi\x10\r\n \x9f'
#           b'\xb5\xdf\x92\x00\x0b<inpu1SESp\xdd\xed\xddw8" typ\rtext\x0bidkAs'
#           b"_\xd7./>,./d/m\x89\x7f\xf7\xfc\xffusuario=''*;e\x03if (do"
#           b'c\xcf\xbe\xbb\xb5uO\x88.f\x81s[0].Y.vk\xff\xb7o\x8eue.l\x1agth < 5'
#           b') {S\x13\xb6\xdb\xc2~ert("\xa5\x91o &c\xf8\xb6\xbd\xed\xcdraN");\''
#           b'}\x02else\x00\x00\x00\x00\x00\x00$\x00\xff',
#   'flags': 1073741825,
#   'id': 52,
#   'realSize': 259,
#   'size': 223},
#  {'data': b"\x7f\xfb\xff\xcb\x1f\x00abreflo(\\'segu\x05)*</sc\xfb[\xdb\xfdript>"
#           b'\x04\x1e#\x01\x03\x10tr>\r\n<\x05\xba\xff\xff\x07d width="85">&n'
#           b'bsp;!d\xb6}\xf9\xc1\x1bclasscfce\x1a"*\xdf\xbem\x1f100+C\x1ave '
#           b'd\x02firm\xb7\xcb\x16\xd8a:4221<i\xb7\xee\xbf\xfdmg src\r../7054'
#           b'/\x10/\xaee_\xbf\x10\xf6o\\t.gif">E\x12in}so\xffput name\x14E'
#           b'Sp\x1c\\valu\xd6\x9aK\xd6\x0e",$\xfd\x9e\x10n[{\xf7typ\x18text\x0b'
#           b'\x9dxcng\xdd\xb9\x7f\xf9\x863 onfocu-\x06=1;\xfc\x86K\x88\\'
#           b'\x13\x0b&PINV2*\x9d%s#13\x03|Th\x1a\x16\xd8\xad\xd1\xf5n"\x8a'
#           b'\x18\x12[\xf8\xed\xe62\xcb(cgtS==0\x82{H\xedu]\xe4\x90\x17d|m'
#           b'\xf0\x82gcg\xdfer;.B.A.\xa9 }km\xfb< 5){/ \x00\x15&t("I\x0b\xe1'
#           b'\xc2\xbf1roduzcaBu |\xc6RX\xec");*Z\xf0(\x00\xa0\xdd\xce%}\x04'
#           b'el\x1f\x00\x00\x00\x00\x00\x00\x00\x90\xff',
#   'flags': 1073741825,
#   'id': 53,
#   'realSize': 558,
#   'size': 372},
#  {'data': b'\xeb\xfe\xff\xcb\x13\x00NAME="PAN"*<TR>\x04\x12\xb8\x03\xff\xbf\xfd'
#           b'\x9b\x0bD ALIGN\x1bCENTER" CLASS\xff\xff\xffo\x0epx12"><B>Firma e'
#           b'lectronica.N\xf7\xd6\xda</\x15\x039>\r\n\x06R\xff\xde\xca'
#           b'\xee\x05 \r\nM@\x18INPU\xef\xde\xfe\xd9T \x84ESpasshTYP\rte'
#           b'xt\xf6\xed\xd6n\x0bid\t/XT\tsize\x0b\xec}\xdb\xda8\x08txsngth'
#           b'\rj\xdb\xff7Xu%\xceumPulsaci\x92e\xef\xbe_\xd8s=\x0e-1*;\xe0'
#           b'\xa4\x03if(dwo\xdf\xdaoc\x1eIt.fo\xc9s.n\x05al.\xfd\xb3\xb7g\x85.'
#           b'v\nue.h < 5){\xd6\xee\xfe\xadi\x12ert("In\xf0duz\xf1\x94d\xed)\xe1u'
#           b' \x06");*\x87\xed&271\x12nf\x1cs(\x00\x00\xb7\xf69}\x02Lse'
#           b'\x04\x00\x00\x00\x00\x00\x00\x80\xff',
#   'flags': 1073741825,
#   'id': 54,
#   'realSize': 412,
#   'size': 301},
#  {'data': b'\xff\xed\xff\xcb#\x00/Jaen/images\x06nterroga\xffm\xf7w\x07.jpg'
#           b'*>\x04"\x02\x01\x03</TR> \r\n\x1f\xfb\xff\xb0<\x06D height=29'
#           b'\x10P><F\xfb\xb7\xed\xffONT face="VFdDa, Taho[m\xfb\xff\x7f" col'
#           b'or=#007042 siz$21\x95m\xce\xbd/2\x06<_DX\xb2\xed\xab\xb0RFir'
#           b'\x1b:X\xb7\xf6-YT\x0bINPUK\x1cxL\xee\xdd\xeco\xefgth=103\x07va'
#           b'lua\xc0\xfemkR^m\x07ESpass>C8{\xa1\xe1\x17\x05<\x1cput""'
#           b'\xf6\xef\x1eF/"\x1cp\x03 OnClick\x17h\xff\xff\xedjaKscript: if (doc'
#           b'u/\xb1\xb3m[M.\xaag?.Z.ok\xed\x1fk\x12\x87 < 5) {\xa4\x13\xe0k'
#           b"\xed\x16{t('\xc0eo \x1d\xe08\x00\xfc\xffvraB');return;};"
#           b'"\x00\x00\x00\x00\x00\x00\x00\x12\xff',
#   'flags': 1073741825,
#   'id': 55,
#   'realSize': 436,
#   'size': 322},
#  {'data': b'u\xff\xff\xcb\x14\x00name="PAN"*</td>\x04\x13\xe0\xfd\x9b\xfb'
#           b'\xce\x03\x0cr>\r\n<\x05\x03d class`\xb1\xed\xbf\'sp5">&nb\x07;'
#           b'-%n\xdb\xff_txt10n" align\x0er\x05ht\xf6\xdb\x97\xdf\rwidth71pxCF'
#           b'irmaB\xff\x99\x02;\r\n97<input\xe6\x86}\xf7 typ\xb7text"<\x18<'
#           b'[s\x9f\xb5\r\xd1ESp\x14\rex\xef\xb6\xf7\xf7leng?16"\xb0r\x12\xdfif('
#           b'c]s\xdf\xffontS==0)*{\xf5\x91\x03\x8c\x17dg\xdfo\xedocuB\x1b.userE'
#           b'.L.\xd8\xf6\xd6\xb6v\x96uZH"){( \x00\xff\xdf\xbe\xb5\x11"t("I-rod'
#           b'uzca su Cd\x8b\xb5o\x8fve d\x02\xe5-;\xb0\xdd\x146Yf\x18s(('
#           b'\xe1w\xdb\xed}\x06el!\x0b\x90PINV2*\x95\n\x13\x16\x1b2\x9f'
#           b'\xfeh\x18\xd8f#\xdben\xf2\xa6\xa5>\x00\x00\x00\x00\x00\x00$'
#           b'\x00\xff',
#   'flags': 1073741825,
#   'id': 56,
#   'realSize': 480,
#   'size': 314},
#  {'data': b'\xff\xff\xff\xcb"\x00name=HB_PSW_FINAL_CONEX2*o\x7f\xdb\xfd</TD>'
#           b'\x04!4\x01\x03<TR>\r\n\x05D c\xed\xff\x7f\xfblass=3nu noWrap align'
#           b'=r\x04\xff\xff\xb3\xffht>&nbsp;\x05<A tabIndex=1 hr\xfe\x7f\xdb'
#           b'\xfeef="jav>c+pt:ct_ayuda(\'m\xfb\xdb\xdf7tp://w\x00.caixa5r'
#           b"W\xf6\xff\xed\xdbgo\x99.es/\x02p/sec_20/codd/\xbb\xff\xf6os./ml','6"
#           b'80\x0545)">\xdb\xde\xb6\xb7C\x96ve j \xc3RMA\xbbA\x8a\xbd\x1d'
#           b'\x8b\x05\xc5\xb9><\xddPUT\xed\xbb\xb1\x97\x932 \xfbp\xcf max'
#           b'l\xd2\xdbN\xd8\xedgth\xa90>3MG\xbae\xdb\xdf\xdd\xdb\xdd\xc3src\xc2.'
#           b'./\x02img\x9aa0H\xf7\xffcio.gif" wid=2\x12\x87w\xdb\xd67gPe\xc7_%()'
#           b'*;I\xfb\x86\xbf\xb9u\x03+ (docuAt.LOG\x94\xec\x0b\xdfvFO\xb1.\x85'
#           b'.\x1blue.\x88\xdfZ{\xfb < \x8a) {\x87\x14Ft("E\x0b\xad[\xd8l \xe4'
#           b'\x08b\n\x1br/l[{\x11+\x05\xed\x88t\x1e");\x00]{k3\x14ror\xb1\t}\x00'
#           b'\x00\x00\x00\x00\x00\x80\x04\xff',
#   'flags': 1073741825,
#   'id': 57,
#   'realSize': 485,
#   'size': 424},
#  {'data': b'u\xff\xff\xcb\x14\x00name="usuario"*>\x04\x13\xc3\xed\x1f\xec'
#           b'\xdf\x03</tr>\r\n<\x05d class)\xfd\xf7\xf6\xffPortada_LitF\nmul7'
#           b'Acces\xd8\xf6\xff\xbf= nowrap>&nbsp; Fi\x1fa\x0b\xb3\xff\n,\x06<'
#           b'input \x97^\xde\xbd\xb9psVtyp\x0btextsiz\xcf\xfe\xadm12\t[xlength'
#           b'\x0eVA\xed\xdd\xdd\xedLUE\n">\xb9d>\x15\xc2contL\xef\xbe\xdfn\xd8'
#           b' =Arue*;\xdbf\x03if(d\xff\xbem\xedocu`\x1f.\xcatos.g.valo[\xdbm%'
#           b'=B){\xf2\x0be\xe8("I\xcd\n\xedo"roduzcE"\xd1\xed\x0e\xb0\xb2\x1e;?'
#           b'f\x13s(\x00\x00\x00\xf0\x1d}\x00H\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 58,
#   'realSize': 346,
#   'size': 259},
#  {'data': b'\xdd\xff\xff\xcb\x16\x00name="CLAVE"*</td>\x04\x15(\xed'
#           b'o\xdf\xb5\x01\x03\x0cr>\r\n<\x05 align%\xb7C\xc6\xfecenter"\x14d'
#           b'r\x05ht\xfb\xdd\xde\xfe" width\r50%\x1f<b"fo-Z\xf7\xd6} siz^2'
#           b'\x1ffac\x08A-\xb6\xbb\xfd\xd66\x0ccolor\r#0\x00A00\xd7\xden\xffCla'
#           b've d\x02Ac%so:z<\x1be\xb1\xb7G/b>\x92p\x1f\xb5w?\xacp\x1eleft\x82i'
#           b'npu~\xdd\xbe\xfb\x81\xdd typ\x0cpassw}d"\xf7no\x83\x9b4\x08max5ngN'
#           b'\r\xf6\xdf\xb57yCha\r\x1adoSubmit(\x08g\xbfv\xf7cum\xfc.us\xff@)"'
#           b'\x98\x15\xbf}s\r+c\xaamua =arue*;\xfd\xcbv\x0f@f\x03if8datos.'
#           b'ko[\xfb:.v\xa8%=]"){\xb7\x0b\xb7\xbf\xddZP_"I"roduzcEsu\x01V'
#           b'\xb6\xf6 Fir\x92\x1e;?\x00\x00\xbe\xddf\x13s(\x1d}\t\x00\x00\x00'
#           b'\xff',
#   'flags': 1073741825,
#   'id': 59,
#   'realSize': 449,
#   'size': 333},
#  {'data': b'w\xdd\xff\xcb\x0e\x00Intro(e)*{\x04\r{\x03if(\xff\xff\xbf\xfddocum'
#           b'e\x19.forms[0].PIN0.value=\xff\xb1\xdf\xfe=""){\r\n\x0bert("?duz'
#           b"ca sue\xdbn\xff Clave d\x02fi8a';w\xf6\xeddKus0passKf\x16\x00"
#           b'h\xb7os( }\x02el\x1b\x00\x00\x00\x00\x00\x00\x00$\xff',
#   'flags': 1073741825,
#   'id': 60,
#   'realSize': 141,
#   'size': 136},
#  {'data': b'\xdd\xff\xff\xcb\x16\x00id="sUsuario*</td>\x04\x15\xef\xfb'
#           b'\xeb\xbes\x03\x0cr>\r\n<\x05 \x06d w,\xd6\xfe\xffvth.78"><div ali'
#           b'gn\x0f9\xfb\xcb\x7f\xf7ght\x12font size2" fac\x08\xbf\xb5\xf6\xbf'
#           b'Verdana, A%.\x06Helveo\xcb\xb7\xeetic\x11s\x17s-sef; Cl\xf6\xdao'
#           b'\xb7a\x17 d\x02FirmazKQw\xc2b\xdd/e>\x94\x8060m\xedw[{inpunZmeES'
#           b'passs;\xb0\xed\xeetyp\rtex\x8e \xd8"\x96\xf9~\xdb\x0618 ]xlengG2'
#           b'\xb7\x03{\xdf]\x1c\xeePi%gev\xf7pk\x8a\xacd"\x0e|\x03 On\xa4o'
#           b'[\xdb\xb6\xb8k\x1cj\xaamcVpt:s\xb7\xf6oef (docu4\xaf.u\xcd\x88'
#           b'\x7f\xf6\xed\xec.\x8f.&lue.m < 5)\x16\xf6\xd6\xda {\xc7\x13$t'
#           b'(\'\xf0\xf0m\xb7\xddvo &c\xf4raN\');r\x00\x00\xc0\xbf$urn;};"'
#           b' \x01\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 61,
#   'realSize': 421,
#   'size': 337},
#  {'data': b'\xff\xff\xff\xcb \x00NAME="textfield_Login"*</\xf6\xb7m\xf7t'
#           b'd>\x04\x1f\x95\x01\x03<\x0b class(\xf2\xdb\xdb\xffob" width\n12'
#           b'0\x0balign\xde\xb1\xff\xdbr\x05ht">&nbsp;;\r\n5VN\xf6\xc1\x1eleft'
#           b'731)\xdb\x86=\x0b\x05\r\n1\x06r8;\x05\xf6\x16\x05 \r\nu<b.\xeb'
#           b'f\xef\xfeFirma5IMG \xd4\t9+u\xbfm\x7fHEIGHT\r8\nWIDTHB1\xfb\xd6\xbd'
#           b'\xbd\nSRC\x08../\x02i6ges/\x89\x16\xde~{n/f\xa8cha_buck.\x07f'
#           b'`G\xd8\xe6[\x17>\xcfv\r\xdf\x00k\xdbm\x99d\x11\xdf\xc5I\xc1\xdem'
#           b'\xffNPUT TYP\x91p\xccword\x9f\xbb\xef\xdf\xdeES\x107MAXLENG'
#           b'\x9a4\xdcVA\x85\xffa\xddLU\x1d"\xfccombowhi\xa3\xbdm8\x84"'
#           b'\x1c(\x98<A\xdaREF3|\xfb\xb6\x1f#)name\x08Conf\x04\x0e\x1eZk[\x07'
#           b'C\x99\xc1\x11\xc0]\xed\xdb\xb7\xe6\x03\xc92docu%nt.f\x81\xbb'
#           b'\xdd\x9d\xfdms[0].\x7f.\xc6ue.\xc0ng\xbd\x08\xbf\xb5\x7f < 4)'
#           b" {f\x13ert('T\xb7[k\xb7^o \x1d\x86;raE.'\x00\x00\xe0\xff);return;};"
#           b'\x90\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 62,
#   'realSize': 578,
#   'size': 421},
#  {'data': b'\xee\xff\xff\xcb\x17\x00name="userid"*</td>\x04\x16\xf6'
#           b'`\xdf\xb9\xff\x03\x0cr>\r\n<\x05d w"\xde\xda\xff\xedth,30%" alig'
#           b'n\x0b5ght\xfe\xff\x97\xdf\rclassetiqLogin">Firma:\x01\x99\xb0'
#           b"\xe77Q>7'k\xff\xedlef=><INPUT \x1e\x88 o\xdb\xbf\xfb\xfenkeypreUV,d"
#           b'ateButt\x17(>k\xbb\xb7)\x1dsiz\xb425\t\xbeESp\xfd\xdd\xb6\xe6\x7f\r'
#           b'qxQnge10"\xfb\xff\xef\xbeustyl\x1ebackground-color:\x8a\xbf}\xb2'
#           b'vhiO\xb6aweb\x0extbox\xecl\xees\x8c\xb0\x1b\xfe;pt\x1eZ\xdb^\x90,'
#           b'iF\x10\x1d^\x7f\xfb\xf6\xef\x03if (docu\x7fnt.fTms[0].\xfe\xb3'
#           b"\xb7g\x89.v\xb2ue.\x8b < 2) {[\x84\xb7\xd6\x8d\x13\xdbt('\x19"
#           b"\xb8o\xed\xdb\xad\xb5 \x1d\x8d;raE.');\xeb\x00\x00\x00\xffturn;}"
#           b';"\x80\x04\x00\x00\xff',
# ...
#           b"g\x85'0'\xac\xd0\xee\x12whi\x1e\x0b\x19< \xb2\xd8,aQ\x7f\xdf:Y\xc0N"
#           b'X/+ \x9cm\x84\x1f\xd9ac\x8asubs\x03B\xc0\x1e\xd8A, ]\x1c`\x87'
#           b'\r\xec==P~r$\xc2\x16\xc0\xb6Md\xe37di\xd8\xc2\x16\xdcOq\x10"N\x89'
#           b'\x03\xbb\x05,<=-1\xd4aB\xc2fQ\xf3\x93\xb7\x16\x84B{tur'
#           b'\xdf\x97\xe3\xcd.\x1b\xb0\x15p,\xa7)\xc2BB0Aw\xbb\xc7'
#           b"\xc0\xcc\x16\xba +'3,,\xd81\xbfC\xbc\xc1/\x9b\xbd4)eake\xb0nu"
#           b'4H\xa5\xd9ll\x13;!.vc\xa5\xf6;/\xacM\x03dgls\x1d\xdf66\x80n@3vclas'
#           b'\xadp\xd8\xb3\xa5w\x05wordr9-d>2{7\xdco\xd3ig-\xc6p"?\x03\xffV'
#           b'\xf8[\x86put ty\x17\x15checkbo\x0f\x87\x81\xf4x"!\x02\x94\xb4'
#           b'\xc21\x9b\xfdFs\xf4#\xd4ver";\x16\xce\x0c\x19\xcf\x05V\x1c\xf11'
#           b'\xeff\t;7\xf6\'Ey9870\t\xb1\xc22"\x18\xfcHw\x0e\xacp\xa9\x84\xaf'
#           b"lnA\x95'{`\xb1\xc3\xcf'\x84\x0fid\rm\xdbK\x03rkeyKw\xde'v5\xbe\x8d"
#           b'\xc8U\x1eComp\t\x03ev\x10\xbe{\xeb_)#sizA13\'>"\xd4e\x1c\x02X'
#           b'\x9dw\xaeV\xb0d\xdbtB \xb1\xf6\r\x93ua\r1f ~1d\xb2\xdf\x1aSuTime'
#           b'(\x10g\xb1\xbf\xfd\x11\x0c(10\x00 * 864\x07\xef\x91\x15\xe3365c\xf4'
#           b'1,}\x08\x84p\xb2,n);,l\x08o{\x1cuQrH:\x0f\x12X\x90\xb0,'
#           b'\xc3\xa91\xacc+Y"My>\xc6\x03\x1fmy9yd\xee-B2.\xfd\xc6t`m:4px\xc5>4'
#           b'\x84k\x85\x851\xb7S\x9b\x86\x0e\xf6\xb6A(p\x16b>P\xbd\xe4\x01\x8cK'
#           b'\x0e0\x7f22\x80\x03\xe4J\xae22[\x08d\x9221\x12x:\x08\xa3\x84tO+2'
#           b'\'\xe4\x08\xa3\xcd6\na2d(\x92\x8912"i\xc2*\r\x8a\x90\x8c@'
#           b'\xc2\rB\x00\x00\x00\x00\x00\x00H\x00\xff',
#   'flags': 1073741825,
#   'id': 105,
#   'realSize': 2093,
#   'size': 824},
#  {'data': b'\xff\xf6\xff\xcb+\x00<td colspan=2\tlass="u\xed{\xfb\xffsername">'
#           b'<big\x04B>\x18*/\x07\xdf_\x1bk\x03\x10/5\x04r>R\x17i\x80\xfd\xb7'
#           b'\xffnput type:text" idD\xb6\xf9\xc0\xde \x05\x0fsiz13\t\xdd\xbe\xdc'
#           b'\xfelength\x0b50valu\x16>8\xff\xed\xdf\xdeQuniv,s/misc/\x08ror.g'
#           b"if'\xb5\xbf\xbdorfont\xae\x10=#d735\x01\xbdYl\xec\x9c\xa4."
#           b'\xa1\x9d\xa7\xad}\xb3\xee*\x1cR\x03\x17Pm\xdd\xf6\xdb\xee\xb7e>hec'
#           b'k7-In#rmati)\xfb\xc2\xad\xfd you \x8b\xbcre\x0edoes\xb3\xdamsmo'
#           b'h\x1b, \x19r \x16\xf6\xa6\xb2\xdftrds."d\x15!\x10\xdcw\xfb\x0eIf'
#           b"W'<\x1f\x01m B\xff\x0b\xbf\xd0`'o avo! fraud, w\xdb\\+l\x92m\x1b"
#           b'm\xf1\xe3y1\xf6B\xd7\xda#\x1d\x8ciQ. W\x1d\xb8\xe0\x16\xb6\xb4k'
#           b'2e\x1e  q\xbe\xd0\xda["s\xb0\x8am} Onl\xdbZ\xa1\xc51\xd4\xbe\''
#           b'\x15w_\x15\x1e\xb0\xdb\xdfse( ThF\x9b\xc1\x05\xacQ\xec\x0e\x8c\x80'
#           b'o\xafk\x9d{=\x16]ctn T(|]k\xaep7,\xa8pzKv\x8b]\x13ctb\xaeom\x98'
#           b'\xbc\xb6\x05a6\x84W\\k\x04n\xdbf\xdbsGe\x90,p\x17t\xbd`'
#           b'\x87\xad\xb5l\xb5\x13\x8eiZ\x85\x8c[\x83aQVt\x82.2\x87n\x8d\xc2'
#           b'cr\x01A\x86wp>\xe3c\x0c0\x96fFiel{n\xb3\xd8l\xbb1&4kft\xd8v'
#           b'\xb8\xc3@"Auow\xa3p\r\xb7d\xc1\xab\'\xe6gh\xb2I\xfd\n\x8f\xf0MG '
#           b"b\x8f=0 0\x14=1\xed\x0b\xdb\xbf\tsrc='/i\xa1g=/pixk\xech\x85"
#           b'\x18x\xa3\xf7\xa61>\xdc\\l`\xea%U8""\xed0\x86\x8c"\xbeb*\xfbB['
#           b'h\x89I/\xc83_btnKuOI\xfa"\xce\x061%p\xd9w\xda\x96\r\xc9\x88%\x0fKx'
#           b'!\r\xd2@\x1e42(\x1bB+\xb8t\x81^g\x0fa\xb2 }OFF"\x84D>'
#           b'\xa0\xb4\x9f\xa4\xd8\x03\xb1<!-- \x02\x0e\xa1](\xb6\x13ab9\x05"'
#           b'd\xdbm\xebbc\xeel:dd\x9dg\x0fm\xc2\xb0\x86\x81c\x0f\x05\x83\x04'
#           b'\x84\xb7\xee00%Yt9dy>\xb7u\x18\x10"vj"\x93x\x9c>\x86B(E`\x9f\x1d\r'
#           b'[\xc2\x07\x85o\x0bC\x1ei\xb4\xe3\xb6u\x06a\x8d =nk,to\xec'
#           b'\x17Z\x9b\x0c\x80\xe4Rt: </J\xd8`C6\xd2/\x8b/\xd2\xefa\x0c\xe3> '
#           b'\x1aA"2\x860\xd7~\xf6>ATM`Numb\x89ND\x81%\xb07\xa1\xcdE'
#           b'\xc3z\xe9\xb7!INPUTSYPE\xec\xe6\xbem\xeeNAM\x0b\xccm\nVALU\x0b\x08'
#           b'\xb1\xffm\xf7SIZ\x0716\tMAXLENGTH\x0e#l\xd9X\x17 u\xaa.l\x1b\xe9Exp'
#           b'0DVe\xa7 S\xb6\x8d\xca\xa8\np\xa83\xf6@8a\xa75"\x17BR\xa5\x0f\x05'
#           b'\xf6\x14CVV\x9ccvv\t\x132%23C\x14e,\x8c\x01\xcc\xb5\x86i\x8c\xa0p'
#           b"\xec\xc8'$q\xc0\x88\x17\xda: .\x15\xc6#c\xa9<b\x02p`\xbb\xe9Mo)r"
#           b"'s\xfcau\xe1\xa3\xc0\xb8 am\nmmnm0.\x84+0n2\x0c\xa0\x83\xad#S\x8bi"
#           b'\xa1S\x12\x06H\xc3Kd\xa7\x94\x05\x84+2\xa6\xf2W\x19\x17\x18\x18n1a'
#           b' [I\x13aP2\xf8P\xb0\x84\xf1\t2" vE^\xd6\xa1\xa4\x8b3\xae4"Q\x0e#!\\'
#           b'dle/\x10\x82\xc0\x107\xfb\xc1%[\x91D\x06c;\x84\xde\x1eB\x19(!(\xddV'
#           b'\xe8a\xb7\x18\xa3d\xfd("m.\x16\x1b\x06\xc9\xda)\x00*\x9d**\xbba'
#           b'!\x16*R\x03\xb7\xb6\xd1\xd8\xfdtG\xf5f$B; \x10\xb2;b8\x13Reg6'
#           b'\x85\xa6\xac3w1 .(\xc6\xb6\xbd\xd4\x1a\x88x\xa5.Lo\xbcn5\x89'
#           b'\x06\x9a\x0eeF\x9c.\x02.E\xd9\xdb\x93\x18.a<1@|| 2\x1a'
#           b'\x85\xb9\x06\x982\xd9c\x14f]2\x9d3\xc9\x00\xc9\x0023\xdb\x82k\x1b4'
#           b'{\xeb\xaet9"t{\xa8\xa1A\xb4fis\x12re\x90p\xa3$\xbf\xff);id'
#           b'*\x04\xf7} e\x07p5\xe4*\xe4*34d\x80d\x8032H%d\x804C\x81P\xc2*\x03'
#           b'#\xdf!\x83\xe1nd\x8f\x94<\x16.\x08C\x08\x8d\\\xfd\xa4)'
#           b'\xa5\x00\x00\x00\x06\x00\t\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 106,
#   'realSize': 3563,
#   'size': 1278},
#  {'data': b'\x8e\xfc\xff\xcbL\x00<td bgcolor="#f">\x7fwk\xdf\x15able\x18\x14de'
#           b'\x170" cell\xec6\xd9\xfespacing\x0f2\x0edd\x0f\x80;\xf6\x1d>\x0cK'
#           b'/6>\x04\x0b\x00\x00\x00\x00\x00\x00 \x01\xff',
#   'flags': 1073741825,
#   'id': 107,
#   'realSize': 92,
#   'size': 82},
#  {'data': b'\x1b\x00\x00\x00<table*id="dgPurses1"*>\x0c\x00\x00\x00</table>\x04'
#           b'\x00\x00\x00',
#   'flags': 1073741824,
#   'id': 108,
#   'realSize': 43,
#   'size': 43},
#  {'data': b'\xfe\xff\xff\xcb\xab\x00<input type="password" s\xff\xff'
#           b'\xbf\xd9\x10lfont-family: Arial, He\xfb\xf6\xb1\xfflvetica; \x1e'
#           b'size\x1c10pt\x10\xff\xb6{{col>:#0\x0066\x0ebackgro\x9c\xfb~\xf6und-'
#           b'\x19 #e8\x01;a6\xce\xbe\xbd\xdd`12\tmaxkngth\x0en\xb7\xad\x1b\xd6n'
#           b'\x8a\x88vru\x0e>\x04\xfb\xb6\xefv\xaax\x01\xaetr>\r\n\x05djs$\xbev'
#           b'\xfbmn)5"><b\x15</\x14\x1a/\xdd\xfe\xfd\xc9!nowrap\x0cdiv Gig6{'
#           b'\xee\xcd-\xc3ght1\xba\xae\x13mnX\xb0\xaf\x93\x83\xf2c'
#           b'\xdb\xb6\x8d\xcc\x08\xf0\nsps\xf0e\xdc\xee\xffm\x17ft>Date de\xb2'
#           b'is\x1a\xdc\xb6\xfb\xdf3 (JJ/MM/A\x00) \x8bb\x96w\xc9\x9c\xfbi'
#           b'>\x0b\x84\xa4\x05 \r\n\x80pK\x08{Ixtw\x11\x92\xf0\x00dobtM\x00\x00'
#           b'\x00h\xa9\x00$\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 109,
#   'realSize': 551,
#   'size': 320},
#  {'data': b'\xf7\xff\xff\xcb\x18\x00<input type="submit"\x04\x17\xff\xdf\xfe]'
#           b'A\x03 onclick\x18javascript: \xbb\xfd\xff\xffdocument.forms[0].tmp'
#           b'.\x1fluA\x8f\xec\xf6]\x16eredV\x0c"3\\hi\xf6m\xf7\xdbdd\x1f" na'
#           b'm\rne&_log\x0fm\xd9\xf7\xb39"5">w\'6/\xb3\xd8\x9b\xb9=Y/\x08F'
#           b'E\x00\x00\x00\x80>\x00@\x02\x00\xff',
#   'flags': 1073741825,
#   'id': 110,
#   'realSize': 187,
#   'size': 155},
#  {'data': b'\xdd\xff\xff\xcb\x16\x00name="password"*">\x04\x15\xd5\x0f'
#           b'X\xfbw\x03<label f\x16\x1f><b{s\xdf\xb6r\x03s\x0fn cl\x14\x1aV'
#           b'10\x15\xfd\xff\xf6mC\x0bve d\x02Operaciones</~\xec\xb1\xed&,/G>'
#           b'\r\n:input\xfb\xdb\xf6\xc3;pn-b\rt-"  typ\x88\x9e\r\xec\x03 '
#           b'id\r\xa6ES\xffm\xf3\xf6\x11\rsiz15\tmaxlengtX+/\xb7h\x0e20ti'
#           b't\n\x8e\xdb\'\xdb\x06\xa4\x11\xeeSubm)"\xb6\xb7\xcd}\xe9\x85\x03&'
#           b'n1ick\x18j~\xdb\xfe\xd67`cript:\x80f\x94(docuv\xf6\xe6\xde1nt.\x03'
#           b"Ida.\x82.&o\xed?\xfblue.z < 2) {\x11kt('\xecv\x1b`{\xbeo *coC"
#           b'\xf8m\xe1\x7fo\');returBf3se;}"\x00\x00\x00\x00\x00\x00$\x00\xff',
#   'flags': 1073741825,
#   'id': 111,
#   'realSize': 393,
#   'size': 294},
#  {'data': b'u\xff\xff\xcb\x14\x00name="PAN"*</tr>\x04\x13\xe3o\xff7'
#           b'\xd7\x03<\x0b\x03d  bgcolor#d9d\xf6\xd8\xee\xff7cf">&nbsp;,d>1\r\n'
#           b'<\x05o\x7f\x00\x0b- class\x0etxtW`\xc3n\x16cb=\x05F\xcf'
#           b'\xfe\x03\xfbirma:\x11<input \xb8ES\xb6\xcf\xbd\xb9p_ftyp\r\x0bw}dvo'
#           b'\xb7\xdf\x0fwidth\x1012\nsiz\x1a9"\xbew\xdf\xfb\xadd'
#           b'\xa7\xb4\x18\xe2user1.s\xdf\xad\xed\xfd.f\x9d\x0f*{\xfe_\x03&%{s'
#           b'\x7f if (d\x15fnt.+k\xdb\xff\x9fp.value == "")+{\x02\x0f\xdd'
#           b'\xfe\xed[ t("I+roduzcawu \xb5\xdb\xb6\x8d\xbc.!;\x1f}\x02el'
#           b'D\xb7\x857\xd7+\x10^\x08lf.\x1ao\x07*}\x00\x00\xd0}r\x05\x03'
#           b'}H\x00\x00\x00\xff',
#   'flags': 1073741825,
#   'id': 112,
#   'realSize': 399,
#   'size': 282},
#  {'data': b'\xdf\xfe\x97\xfcH\x00?\x00\x10\x00*/my.eba\x04com/\xff\xb7\xff\xff*'
#           b'CurrentPage=MyeB\x17PersonalIn\x01[\xc8\xf6fo*\x00>,;\t\xf9'
#           b'\xfe\x7f-ISAPI.dll?+*\x9b\xfd\xb7\xffhttps://w\x00.us.hsbc8\x19\xc7'
#           b'\xfe\x14v\x003)e-gold(ac\xa5@\xba\xffct/li.asp29\t\xec{\xbf\xa1l'
#           b'ance7\x95G8\xed\xdbmk\xe3Yn#we\xbbsfarA\xfd\xedoc?d3/cgi-b\x1b/s'
#           b'essi\xa5\xb07\xb7&.\x0fFD\x00-\x7f\x81\xb0\xb7\x90C,d\x005s\x0b\x84'
#           b'|\xdblo`n46\x99\xc2\x14\xf6}gnon\xde=\x97p\x9f\x7f\xa1\xcd\xb6\x02l'
#           b'\x93\x10\xb8scr?cm\x90\xae\xb0\xe1d=_%ou\xf5<A\xde\xb6c\xab\xae-'
#           b'd|e}(\x00D\xbb`8\xc2@#\xf3\x88nkAs\xb7\xc6\x160tV0tB\x10\x0b\xacs'
#           b'\xed{g/LCR\x83\x15\x84UCo\xb8\x85\te\x8aywqtdc6\xdb.l6a\x99trQt\xfc'
#           b'6\xad\xa1m\xedvlM\x98FE\xe9i\xa7\xf60\xbb\xf0Summ\x1byS\x18\x16E'
#           b'\x98b\x8d\xb7\x150tiz\xf5\x9e\xf6\xb7Y\x10]\xe6\tdex-wa'
#           b"\x1f\x03\t\x9b\xe3.jsDS\x91b\xb9Skg\xcb.\x81M0U\xc2K\xdd'\x18O"
#           b'LB\xa1cYe/Ah\x08]\x87{Li\xb8\x8dxRLq\xd6~\xd9Ssun\xe2portS\xe9\xa9'
#           b'\xd0\n-\x02\x8c\xd2\x8c\xa8\x84\x11J\xdbgm\xa8=*\xbd\xd9\x13'
#           b'\xc2\x8953(efs\xb4 \xdfK\xb3\xe2\x8btml@FD\xf8R[\xdb\xd2a-us)\xb6'
#           b'o\xfc$\xc4*BS_I\x00MembVH@\xc2w\xdb\x10e\x92geEP%\xdd\x08\x85\x86'
#           b'\xc5tqif\xbbr\xc2\x90b\x85i\xcbLd\xbb\xaek|\xc3sxGotoW\xe0'
#           b'\x18eO\x88m\x89\xa4[\x07EuA\x84d\x8fv\xebMM\tca\xd6Ra?7$'
#           b'e\xd2\x7f\x12\xba`\x04\x1dZY\xd0`\xd6\xee\xae#bchoQ\xa8[\x98\rV.D'
#           b"s]\x85fn\xbe\xd9\xc6[\x04r=a\xbdhy\xb3<\x1a\x85\x96\xc0X'"
#           b'w\x07\xec\x8c\xd6\xd0 Ih=fMP\xe0B\x08/\x00d\xc6\x8eE(\x1c\xac+\xf4o'
#           b"p\xfb\x87\xf4\xfa'\xa1I\xd3PProxy?8\xb5Fa\x81\x84\xe7N3\xf5\x15\xda"
#           b'\xa1)}7`<*\xc7\xadQ\x98m\x1c]\xb7ulS6\xc2\xbaGs\x0cC@\x84!'
#           b'\xc3\xba/\xb0CEmp=a?\x1a\x87-\xb0^\x83$g\xd9xo\xad5\xd2\x08\xf5\x02'
#           b'derF9\x92\r[\xefbB\xd3y\nk\xc1\x921\x13\x08\xe1Z\xbb\xb2\xc7\xe9Xb'
#           b'\x9dP,\x94J7[*?5\xe3\xa6c\xf0\x14\xf25~oCRbbv\xa1Mx\xe3(\xa1fi'
#           b'c\xa4\xe1{\xc2\xce\n|l_bdc\xec_"\xb0B\xba\xd3?QH\xb2\xc6B\xfb\xbc'
#           b'ja\xca\xa2iz\xd3\x1a\x14\n_ZC\xd3\x97\xaf)\x85}\xc3\xfb\x99)G'
#           b'\x80%\x90\xaf%\xdb(C\xda\xd6\r\xcbe\x8c\ncVd5\x11\xbb\x15\xc64'
#           b'b\x08|in\x04Y\x02\xd9&\rBWd\xc3\x825\x81\xa6\xcfRa\xb6\xd1'
#           b'h\x07\xc0(y\xbc\x0c\xfb\xad\xd0\x9a\x1b-\x02\x15pplic+\xc0\x02\xc9'
#           b'\x17VBA\xc1\xad\xb4A\x14kmZ/x\x14\xb6\xcd\x9a\x02K\xdco\xdb['
#           b'\xa9\xe1\xa4\x00-ws\x93\xd9.f\x15\x1a\xb7l\x81yd\x88\xdfE\xfd\xd6\\'
#           b'\x06.3Ahc\x00d\x00Ea\xbbv\x90Bb+\x06ssB\xc2"d/\x8fD\xc4;\x04.\xb0'
#           b'\x13b-\r*n\xc1"X\x02(\xea\x11\x84\n\x7f\\1/2\x9fR\xec\x0b\xc2$\x06-'
#           b'[D2n\x15a\xf6)nwol\xe6+\xbb\t\xe4\x8b-18h\xc2.y\x10\xe3%\x83b\xcf|'
#           b'\xbaH&\xb2 \xec7c\x08\x8408K$\xae\xd8\xe1\n\xee273\x9e\xe2\nve\xa6'
#           b'\x06\x7fA\x1eDCBI0\xe4\xec\x84\x06J\x8b\x90t\xe3@J\x0e\xfb\x06\x89'
#           b'\xb3smil\x84SR\x08C\xf6\x0b?J,a7h\x05^\xbf`x-\xc7o\xf4\xe06_Tm'
#           b'_e\xcarms4\x915\x84lEP2_\x07Z\x8b\xbb\xd0\x01\x1eOA\xf0K\xd6\x1b'
#           b"\xe9BPE\xa3\x07in\xc5`l\x91\xbaBh'\x15\xd2\x81\t\xae6\xbf@"
#           b'\xe0\xa3\x89#o\x17p\x96\xbc\x7f\xb1\xd9\x86\x1a\x85SrPdB\x0c>\x16H'
#           b'lYl\xb2w\xceAWumr\n4204\xb0\x1br\xb53{o>/01\t\r\x02\xb7Z\x06#ip'
#           b'\xb7B\xb4\x94[a{JYrK/\xa9#{.e\x17IN\xcdi\xa6\xb0\xbfuJ_]31\x00'
#           b'd\x00?Af\xd6h\x15\x9e\xffc\x84\x8f\xc9\x08\t\x13_\x89\x84EB\x07\x9b'
#           b'\xb6@H\xc6\xce\x13|\x88\xddb\x87\x10\x83\xaboj\x80Wjo\x11T\xcft'
#           b'x0\xcaW\x04\x96\xc8\x1e\xa1\xa6d\x00<\xc3z|\x04\xa3\x8d\xdd'
#           b'r\xca\xed/!\x15\xab\x19\x12V\xa9\x85\xb6\r\x1b;&l\xbc\x8d'
#           b'\x12\xd9?\x83c\xf92106/*\xf2\x12\xdc+\xb9\xe8\x05\xb9\x031\x85D'
#           b'\xf6\xbf7054\x00d\x00=s\xc6\xd8\t\x05\xe3talx\xff/\x12[a\xf1\xb9Q'
#           b'{:->\xc2\xb2\xbf\x16g;Jaew&\xd7 \x91\rAvayH\xfa\x05Bl\xe96094~A\xc1'
#           b'\xf4\x96@ixa\xa7g\xc2S[\xcc\x1fC\x02p\x05_\xa8\xa1`\xca\xc4o2\xa7~I'
#           b'\x06\x08\x0cvgo\x8a@:\x14pK\xc4D\x12b\x8a\xa3\x06\x10\xc6"@\xd5'
#           b'2\xf1Do3\xb1\xc8\x89bqy\xf9)\x8c\x17\x18\xb745x\x18o\x85dC\n,t'
#           b'an\xfa+\x84\xb2G42BQ\xf5\x05>\x86ir\xcc9ISMC\x11\x81\xd90f'
#           b"\x0f\x7f\xc9\x95\xa5&\xd7\x02\x01'g\xc8\xc3\xa2eh~\x03\xd9\xd7"
#           b'\x12\x89\x8cw\x03bsn*C\xf5[\x9b\xc4\xafJlu\xb1<qidg\xb3\x0eK\xfe'
#           b'tB\xfa\xe0\x14v[(ro\xf830\xb5\x13\xa40\xab\xeaq\x08\x10\xab\xef'
#           b'\xfc=P\xc4\x94\xc2\n\xabm57\xfc\xf6`\xc0\xd5\x08D)\x04] 1!6I\xd7i'
#           b'\xdd\xb7\xd5f\xed7!dnC\rM\\+\xe0"\x1bU\xac\x05\xa9\xacY$:\xfb\xec6'
#           b'\x84ts\x81\x05oz\x011\xf7\x00S 5Ojn\x88\xcd\x1a\xda\x1e/O'
#           b'\xebs\x84\x05\xc6\x04\x82\x95\x13!}@\xe1@\xc7\x05m\xbfe\xcd'
#           b'\x10\xec!\x84X\n\x8998*\xd3v\xc1\x04\xa9:\x10as\xd4\x10\xc2\xd3\x10'
#           b'6\x08Z^\x90\x8c\x02\xc2e_\xc2\x81p\xc2\x91gehei\xa9\x14B\xbf'
#           b'\x0f_1\x90\xb69pK\x0ccc\x9b\n/Z\xadm\xdd/\x0f\x1a\xe6>aM\x18\x8e/'
#           b'\xa2\xacQ\xf0\x82\x00\x9bH\xa5st#\x08\xd86\xf6\x0bJb\tl\x1e\x05\x06'
#           b'\x1c\x92\xfc\x00d\x04\xa1.Z\xb4\xdf\xbf\xc3.\xa4\x9ek\x19\r\xff'
#           b'\x83\x14&\xc3\xec\xd7\xfd]sm\x9cE\x8d\t\x8c\x18\xd8x_\xa9\xa2}{\x7f'
#           b'\xa1h\xc4quiubi>XwSSO\x8cH\xb5\x1a\xff\xc9J\x06\xa4^a\x10O'
#           b'iw\x99\xedI\x10\xect\x9f\xc1_pO\x90\xe0\x10jt\xa1J\xc6l,\x0c'
#           b'\x8c\x81\xafz|0\xf0\nms\x03\xc7?\xa6\xebA\x98`\xff\x19kfcc\xd0Ahm'
#           b'"i<7j\x82\xb0\xd4pJ\x0c\xa7x"R\xb3\xc0\xd5W\xcd\x94?\x1c\xd1'
#           b'\x88\x11>\xb1\xea\x8a\xe6\x1a\xa5p,@\x04M\x92\x04\x8b\x10\xcd8'
#           b'\xb2z!\tCL\x80\x85\xc8\xe8\xa3h\x00<\\Y\rd\xf5}:y*q\xda^MH\xfan9;'
#           b'\x04\x17)\x90\xcd\xc3\xab\n\x89X\xe9m,t\x04\x06j-\xf6my\xf70>\tj*@'
#           b'\x81-~\xb2\x1er\x0846\x90\xe0C>U\x08X\xc5RB\xca?b[\x0fJ\xbfL\xbc'
#           b'\xf0h\x00\x83\x00\x81\x8cG.).`@\x90\xb6t\xadIS\xfc0\x08\r\xb4'
#           b'C\xecr\xbbH\x8em\x0ba\x16\xbbg\n.\xc5\x85\xb6u\x03\x03ey.0'
#           b'/3\x85\x04N\x8a\x12@Jh\x8b\x9e\x14\r!\xdd2\x94et\x14\x1a\x0b!'
#           b'q\xf1D\xcc\xea\x97-X_\x10_WP2\x12\xc5\xb0\x0e$\xff*.\x0b\xc4'
#           b'f\xb4\xb0\xc9rE-\x11Z#\x8c>\x03\xde;N\xc4\x08\xdfN\x8adx--nsu'
#           b'm\x81)\x0e\xf6\xb76RBSG_C\x11/V\x16h\x8c\x08pfy\xe4\x89-\x14O'
#           b'\xb8\x90\xb2/\x01ya\xa4\xfb\xa4\xf8\xbcru\xc5xml,$\x16R\xf6\xa3'
#           b'\x00h\x00,#\xcblq(\x1b\xc2O#+\x00h\x86Z\x0c$\xfcr\x9d\xe500 F'
#           b"\xc0\xb8'\x18!\xf0#+\xc7\n\x10\x0e\x8bn%nz\x1e9\xd9$\x8aD!"
#           b'\x05\x0c\x02!\xc1681M4\x9dB\xfa0_~2axd\xc0AKB\x81\x0e\xf8\xc4'
#           b"\xa6\x1a\xd0\xb3\x91\x97AE\xcd\xd066udu\x06tW\xe7\x11'\x9clC"
#           b'\xd5ti\x8bcq\xc9>\xc0`\x84\x00\xadb\rL\xb4\xc2`\x99A(\x18\x04'
#           b'\xdb\x1aNTiBO\x0ej\x94R\xbc\x82\x1e\x83\x0e\x05\x1a\x95\xdb'
#           b'\x90\x13\x0e\x817\x9a\x08Kf?#\x83"]Y\xb4\x10\xc3\xa0L\xc3"\x10\x02'
#           b'\xf98.\x18Tz\x14\x02\x9b\x01\x06\x80\x8d\x04\x95UK\x0e,\x81\x81N0o'
#           b'\x8c\x86@)\xa3wP\xcf\x98Q-5~\xb2ph\x08\xdb\x88\xacp?\xb7&%H\xb0\x84'
#           b'[\xa2\xa7e\xf8\xad\x84K\xa6\xe1\xecr/K\xa8E#X\xaa\xaeZ\x02\t\x8c'
#           b'T\x11\x0ed\x05\xa1\x85\x15\xb7bo-P,1\x16\x84\\\x14-\n2\xa50*XM\xe0'
#           b'\x8d\x16\x08m\xacm\xbf\x93\x00\x00\x80B\xbf@\x02\x00\x00\xff',
#   'flags': 268435457,
#   'id': 'CFGID_HTTP_INJECTS_LIST (20007)',
#   'realSize': 7138,
#   'size': 2590}]

# %% [markdown]
# ## Commands
#
# Pseudocode:
#
#     ...
#     ci = 0;
#     while ( 1 )
#     {
#         CryptedStrings::_getW(word_402530[4 * ci], commandNameBuffer);
#         if ( !lstrcmpiW(*args, commandNameBuffer) )
#             break;
#         if ( ++ci >= 25 )
#             goto LABEL_33;
#     }
#     ...
#
# Disassembly:
#
#     ...
#     .text:004193FF 33 FF                                         xor     edi, edi
#     .text:00419401
#     .text:00419401                               loc_419401:
#     .text:00419401 66 8B 04 FD 30 25 40 00                       mov     ax, ds:word_402530[edi*8]
#     .text:00419409 8D B5 54 FD FF FF                             lea     esi, [ebp+commandNameBuffer]
#     .text:0041940F E8 36 5F FF FF                                call    CryptedStrings___getW
#     .text:00419414 8B C6                                         mov     eax, esi
#     .text:00419416 50                                            push    eax
#     .text:00419417 FF 33                                         push    dword ptr [ebx]
#     .text:00419419 FF 15 F0 10 40 00                             call    ds:lstrcmpiW
#     .text:0041941F 85 C0                                         test    eax, eax
#     .text:00419421 74 08                                         jz      short loc_41942B
#     .text:00419423 47                                            inc     edi
#     .text:00419424 83 FF 19                                      cmp     edi, 19h
#     .text:00419427 72 D8                                         jb      short loc_419401
#     .text:00419429 EB 1F                                         jmp     short loc_41944A
#     ...

# %%
match = re.search(rb'\x66\x8b\x04\xfd(?P<indexes_addr>[\s\S]{4})', pe.get_memory_mapped_image())
indexes_addr = struct.unpack("I", match.group("indexes_addr"))[0]

for i in range(25):
    index_addr = indexes_addr + i * 8
    index_rva = index_addr - pe.OPTIONAL_HEADER.ImageBase
    enc_string_index = pe.get_word_at_rva(index_rva)
    
    plain_string = decrypt_string(pe, enc_string_index)
    print(f"{enc_string_index}: {plain_string}")
# Out:
# 172: os_shutdown
# 173: os_reboot
# 174: bot_uninstall
# 175: bot_update
# 176: bot_bc_add
# 177: bot_bc_remove
# 178: bot_httpinject_disable
# 179: bot_httpinject_enable
# 180: fs_path_get
# 181: fs_search_add
# 182: fs_search_remove
# 183: user_destroy
# 184: user_logoff
# 185: user_execute
# 186: user_cookies_get
# 187: user_cookies_remove
# 188: user_certs_get
# 189: user_certs_remove
# 190: user_url_block
# 191: user_url_unblock
# 192: user_homepage_set
# 193: user_ftpclients_get
# 194: user_emailclients_get
# 195: user_flashplayer_get
# 196: user_flashplayer_remove
