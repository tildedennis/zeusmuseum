# %% [markdown]
# ## Initial Setup
#
# 1. Download the Zeus 1 version 1.2.7.19 reference sample from [MalwareBazaar](https://bazaar.abuse.ch/sample/0060fa563c86399ac56dfc261181beeeafc3a74ded1f88ee248d794fcb14e178/).
# 2. Unpack the sample with [PE-sieve](https://github.com/hasherezade/pe-sieve).

# %%
# Install required Python modules
import sys
# !{sys.executable} -m pip install pefile

# Import required Python modules
import pprint
import re
import struct

import pefile
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pefile in /usr/local/lib/python3.8/site-packages (2018.8.8)
# Requirement already satisfied: future in /usr/local/lib/python3.8/site-packages (from pefile) (0.16.0)

# %%
# Load the unpacked sample
fp = open("c049fe5f480e0f676533b30d4ba00053d9329369093c1c212bb74e64a7f1ec22.bin", "rb")
sample = fp.read()
fp.close()

pe = pefile.PE(data=sample)

# %% [markdown]
# ## Resolve Windows API Calls
#
# Pseudocode:
#
#     bool resolve_all_win_apis()
#     {
#       kernel32_hdl = resolve_win_apis("kernel32.dll", &kernel32_apis, 125u);
#     ...
#
# Disassembly:
#
#     .text:00409C37 6A 7D                         push    7Dh ; '}'
#     .text:00409C39 BA 08 12 40 00                mov     edx, offset kernel32_apis
#     .text:00409C3E B9 50 38 40 00                mov     ecx, offset aKernel32Dll ; "kernel32.dll"
#     .text:00409C43 E8 CA 09 00 00                call    resolve_win_apis
#     .text:00409C48 A3 38 4D 41 00                mov     kernel32_hdl, eax
#     ...
#
# Pseudocode:
#
#     HMODULE __fastcall resolve_win_apis(const CHAR *dll_name, int api_list, unsigned __int16 num_entries)
#     {
#       HMODULE dll_hdl; // ebp
#       unsigned __int16 index; // di
#       int offset; // esi
#       FARPROC api_addr; // eax
#
#       dll_hdl = LoadLibraryA(dll_name);
#       if ( !dll_hdl )
#         return dll_hdl;
#       index = 0;
#       if ( !num_entries )
#         return dll_hdl;
#       while ( 1 )
#       {
#         offset = api_list + 8 * index;
#         api_addr = GetProcAddress(dll_hdl, *offset);
#         if ( !api_addr )
#           break;
#         ++index;
#         **(offset + 4) = api_addr;
#         if ( index >= num_entries )
#           return dll_hdl;
#       }
#       return 0;
#     }

# %%
match = re.search(rb'\x6a(?P<num_entries>\x7d)\xba(?P<api_list_addr>[\s\S]{4})', pe.get_memory_mapped_image())
num_entries = struct.unpack("B", match.group("num_entries"))[0]
api_list_addr = struct.unpack("I", match.group("api_list_addr"))[0]

for i in range(num_entries):
    offset = api_list_addr + 8 * i
    offset_rva = offset - pe.OPTIONAL_HEADER.ImageBase
    api_name_addr = pe.get_dword_at_rva(offset_rva)
    api_name_addr_rva = api_name_addr - pe.OPTIONAL_HEADER.ImageBase
    api_name = pe.get_data(api_name_addr_rva, 128).split(b"\x00")[0].decode()
    print(f"{i}: {api_name}")
# Out:
# 0: FormatMessageW
# 1: LocalFree
# 2: GetEnvironmentVariableW
# 3: GetOverlappedResult
# 4: GetVolumeNameForVolumeMountPointW
# 5: WaitForMultipleObjects
# 6: GetFileInformationByHandle
# 7: FileTimeToLocalFileTime
# 8: FileTimeToDosDateTime
# 9: CreateTimerQueueTimer
# 10: GetThreadContext
# 11: SetThreadContext
# 12: LoadLibraryA
# 13: GetProcAddress
# 14: ResumeThread
# 15: OpenThread
# 16: FreeLibrary
# 17: SuspendThread
# 18: GetProcessId
# 19: GetFileAttributesW
# 20: GetProcessHeap
# 21: GetCommandLineA
# 22: GetLogicalDrives
# 23: GetDriveTypeW
# 24: GetFileSizeEx
# 25: CreateFileMappingW
# 26: MapViewOfFile
# 27: UnmapViewOfFile
# 28: ResetEvent
# 29: GetTimeZoneInformation
# 30: GetVersionExW
# 31: GetUserDefaultUILanguage
# 32: GetModuleHandleA
# 33: Sleep
# 34: CopyFileW
# 35: GetModuleFileNameW
# 36: GetModuleFileNameA
# 37: SetFilePointerEx
# 38: GetLastError
# 39: CreateMutexW
# 40: OpenMutexW
# 41: ReleaseMutex
# 42: lstrcmpiW
# 43: lstrcmpiA
# 44: lstrcpyW
# 45: lstrcpynW
# 46: lstrcpynA
# 47: lstrcpyA
# 48: lstrcatW
# 49: lstrcatA
# 50: CloseHandle
# 51: DeleteFileW
# 52: SetFileAttributesW
# 53: WaitForSingleObject
# 54: SetEvent
# 55: CreateFileW
# 56: CreateEventW
# 57: SetFilePointer
# 58: HeapCreate
# 59: HeapDestroy
# 60: HeapAlloc
# 61: HeapReAlloc
# 62: HeapFree
# 63: ConnectNamedPipe
# 64: WaitNamedPipeW
# 65: SetNamedPipeHandleState
# 66: CreateNamedPipeW
# 67: GetTickCount
# 68: WriteFile
# 69: ReadFile
# 70: SetEndOfFile
# 71: GetFileSize
# 72: FlushFileBuffers
# 73: GetLocalTime
# 74: DisconnectNamedPipe
# 75: WriteProcessMemory
# 76: CreateThread
# 77: CreateRemoteThread
# 78: CreateToolhelp32Snapshot
# 79: Process32FirstW
# 80: Process32NextW
# 81: Module32FirstW
# 82: Module32NextW
# 83: Thread32First
# 84: Thread32Next
# 85: GetExitCodeProcess
# 86: ExitThread
# 87: ExitProcess
# 88: OpenProcess
# 89: VirtualQueryEx
# 90: VirtualAllocEx
# 91: VirtualProtectEx
# 92: VirtualFreeEx
# 93: GetCurrentProcessId
# 94: SetThreadPriority
# 95: GetThreadPriority
# 96: GetCurrentThread
# 97: GetCurrentThreadId
# 98: CreateProcessW
# 99: GetProcessTimes
# 100: MultiByteToWideChar
# 101: WideCharToMultiByte
# 102: MoveFileExW
# 103: CreateDirectoryW
# 104: GetTempPathW
# 105: IsBadReadPtr
# 106: IsBadWritePtr
# 107: SetLastError
# 108: ReadProcessMemory
# 109: InitializeCriticalSection
# 110: EnterCriticalSection
# 111: LeaveCriticalSection
# 112: GetSystemTime
# 113: SystemTimeToFileTime
# 114: GetTempFileNameW
# 115: FindFirstFileW
# 116: FindNextFileW
# 117: FindClose
# 118: GetComputerNameW
# 119: SetFileTime
# 120: GetFileTime
# 121: GlobalLock
# 122: GlobalUnlock
# 123: ExpandEnvironmentStringsW
# 124: FindResourceW

# %% [markdown]
# ## Decrypt Strings
#
# Pseudocode:
#
#     ...
#     g_decrypted_strings = HeapAlloc(hHeap, 8u, 416u);
#     if ( g_decrypted_strings )
#     {
#       index = 0;
#       do
#       {
#         offset = 4 * index;
#         if ( **(&g_encrypted_strings + offset) == -1 )
#           return 0;
#         buf = Mem::alloc(**(&g_encrypted_strings + index) + 1);
#         if ( !buf )
#           return 0;
#         encrypted_string_entry = *(&g_encrypted_strings + index);
#         v7 = *encrypted_string_entry <= 0;
#         buf_index_cp = 0;
#         if ( !v7 )
#         {
#           buf_index = 0;
#           key = 0xBA;
#           do
#           {
#             plain_byte = key + encrypted_string_entry[buf_index + 1];
#             ++buf_index_cp;
#             buf[buf_index] = plain_byte;
#             buf_index = buf_index_cp;
#             key += 2;
#           }
#           while ( buf_index_cp < *encrypted_string_entry );
#         }
#         buf[buf_index_cp] = 0;
#         if ( *buf == 'W' )
#         {
#           *(offset + g_decrypted_strings) = Str::xToUnicode(buf + 1);
#           Mem::free(buf);
#           if ( !*(offset + g_decrypted_strings) )
#             return 0;
#         }
#         else
#         {
#           *(offset + g_decrypted_strings) = buf + 1;
#         }
#         ++index;
#       }
#       while ( index < 103u );
#       ...
#
# Disassembly:
#
#     ...
#     .text:0040A725 68 A0 01 00 00                                push    1A0h
#     .text:0040A72A 6A 08                                         push    8
#     .text:0040A72C FF 35 C4 5F 41 00                             push    hHeap
#     .text:0040A732 89 35 C4 4F 41 00                             mov     dword_414FC4, esi
#     .text:0040A738 C6 05 DE 47 41 00 00                          mov     byte_4147DE, 0
#     .text:0040A73F FF 15 2C 4E 41 00                             call    HeapAlloc
#     .text:0040A745 A3 F4 4A 41 00                                mov     g_decrypted_strings, eax
#     .text:0040A74A 3B C6                                         cmp     eax, esi
#     .text:0040A74C 75 07                                         jnz     short loc_40A755
#     .text:0040A74E 32 C0                                         xor     al, al
#     .text:0040A750 E9 5B 01 00 00                                jmp     loc_40A8B0
#     .text:0040A755
#     .text:0040A755                               loc_40A755:
#     .text:0040A755 89 75 F8                                      mov     [ebp+index], esi
#     .text:0040A758 57                                            push    edi
#     .text:0040A759
#     .text:0040A759                               loc_40A759:
#     .text:0040A759 0F B7 5D F8                                   movzx   ebx, word ptr [ebp+index]
#     .text:0040A75D C1 E3 02                                      shl     ebx, 2
#     .text:0040A760 8B 83 20 40 41 00                             mov     eax, g_encrypted_strings[ebx]
#     .text:0040A766 0F B6 00                                      movzx   eax, byte ptr [eax]
#     .text:0040A769 40                                            inc     eax
#     .text:0040A76A 74 72                                         jz      short loc_40A7DE
#     .text:0040A76C E8 60 44 00 00                                call    Mem__alloc
#     .text:0040A771 8B F8                                         mov     edi, eax
#     .text:0040A773 85 FF                                         test    edi, edi
#     .text:0040A775 74 67                                         jz      short loc_40A7DE
#     .text:0040A777 8B B3 20 40 41 00                             mov     esi, g_encrypted_strings[ebx]
#     .text:0040A77D 80 3E 00                                      cmp     byte ptr [esi], 0
#     .text:0040A780 C6 45 FF 00                                   mov     [ebp+buf_index_cp], 0
#     .text:0040A784 7E 1E                                         jle     short loc_40A7A4
#     .text:0040A786 33 C0                                         xor     eax, eax
#     .text:0040A788 B1 BA                                         mov     cl, 0BAh
#     .text:0040A78A
#     .text:0040A78A                               loc_40A78A:
#     .text:0040A78A 8A 54 30 01                                   mov     dl, [eax+esi+1]
#     .text:0040A78E 02 D1                                         add     dl, cl
#     .text:0040A790 FE 45 FF                                      inc     [ebp+buf_index_cp]
#     .text:0040A793 88 14 38                                      mov     [eax+edi], dl
#     .text:0040A796 0F B6 45 FF                                   movzx   eax, [ebp+buf_index_cp]
#     .text:0040A79A 0F BE 16                                      movsx   edx, byte ptr [esi]
#     .text:0040A79D 80 C1 02                                      add     cl, 2
#     .text:0040A7A0 3B C2                                         cmp     eax, edx
#     .text:0040A7A2 7C E6                                         jl      short loc_40A78A
#     .text:0040A7A4
#     .text:0040A7A4                               loc_40A7A4:
#     .text:0040A7A4 0F B6 45 FF                                   movzx   eax, [ebp+buf_index_cp]
#     .text:0040A7A8 C6 04 38 00                                   mov     byte ptr [eax+edi], 0
#     .text:0040A7AC 80 3F 57                                      cmp     byte ptr [edi], 57h
#     .text:0040A7AF 75 34                                         jnz     short loc_40A7E5
#     .text:0040A7B1 8B 83 20 40 41 00                             mov     eax, g_encrypted_strings[ebx]
#     .text:0040A7B7 0F B6 00                                      movzx   eax, byte ptr [eax]
#     .text:0040A7BA 8D 4F 01                                      lea     ecx, [edi+1]
#     .text:0040A7BD 48                                            dec     eax
#     .text:0040A7BE 51                                            push    ecx
#     .text:0040A7BF E8 59 48 00 00                                call    Str__xToUnicode
#     .text:0040A7C4 8B 0D F4 4A 41 00                             mov     ecx, g_decrypted_strings
#     .text:0040A7CA 57                                            push    edi
#     .text:0040A7CB 89 04 0B                                      mov     [ebx+ecx], eax
#     .text:0040A7CE E8 11 44 00 00                                call    Mem__free
#     .text:0040A7D3 A1 F4 4A 41 00                                mov     eax, g_decrypted_strings
#     .text:0040A7D8 83 3C 03 00                                   cmp     dword ptr [ebx+eax], 0
#     .text:0040A7DC 75 10                                         jnz     short loc_40A7EE
#     .text:0040A7DE
#     .text:0040A7DE                               loc_40A7DE:
#     .text:0040A7DE
#     .text:0040A7DE 32 C0                                         xor     al, al
#     .text:0040A7E0 E9 CA 00 00 00                                jmp     loc_40A8AF
#     .text:0040A7E5
#     .text:0040A7E5                               loc_40A7E5:
#     .text:0040A7E5 A1 F4 4A 41 00                                mov     eax, g_decrypted_strings
#     .text:0040A7EA 47                                            inc     edi
#     .text:0040A7EB 89 3C 03                                      mov     [ebx+eax], edi
#     .text:0040A7EE
#     .text:0040A7EE                               loc_40A7EE:
#     .text:0040A7EE FF 45 F8                                      inc     [ebp+index]
#     .text:0040A7F1 66 83 7D F8 67                                cmp     word ptr [ebp+index], 67h
#     .text:0040A7F6 0F 82 5D FF FF FF                             jb      loc_40A759
#     ...

# %%
def decrypt_string(key, enc_string_addr):
    enc_string_addr_rva = enc_string_addr - pe.OPTIONAL_HEADER.ImageBase
    # first byte is a length
    str_len = struct.unpack("B", pe.get_data(enc_string_addr_rva, 1))[0]
    enc_string = pe.get_data(enc_string_addr_rva + 1, str_len)
    
    plain_string = b""
    for eb in enc_string:
        pb = (key + eb) & 0xff
        plain_string += struct.pack("B", pb)
        key += 2
        
    plain_string = plain_string.decode()
    
    # first byte is W or A for wide or ascii
    plain_string = plain_string[1:]
    
    return plain_string


match = re.search(rb'\xc1\xe3\x02\x8b\x83(?P<enc_strings_addr>[\s\S]{4}).*?\x33\xc0\xb1(?P<key>[\s\S]).*?\x66\x83\x7d\xf8(?P<num_entries>[\s\S])', pe.get_memory_mapped_image())
enc_strings_addr = struct.unpack("I", match.group("enc_strings_addr"))[0]
key = struct.unpack("B", match.group("key"))[0]
num_entries = struct.unpack("B", match.group("num_entries"))[0]

plain_strings = {}
for i in range(num_entries):
    offset = enc_strings_addr + 4 * i
    offset_rva = offset - pe.OPTIONAL_HEADER.ImageBase
    enc_string_addr = pe.get_dword_at_rva(offset_rva)
    plain_string = decrypt_string(key, enc_string_addr)
    print(f"{i}: {plain_string}")
    plain_strings[i] = plain_string
# Out:
# 0: lowsec
# 1: user.ds
# 2: local.ds
# 3: sdra64.exe
# 4: winlogon.exe
# 5: svchost.exe
# 6: explorer.exe
# 7: SYSTEM
# 8: _AVIRA_2110
# 9: _AVIRA_2101
# 10: _AVIRA_2108
# 11: _AVIRA_2109
# 12: _AVIRA_21099
# 13: software\microsoft\windows nt\currentversion\network
# 14: UID
# 15: software\microsoft\windows nt\currentversion\winlogon
# 16: software\microsoft\windows\currentversion\run
# 17: userinit
# 18: software
# 19: system
# 20: csrss.exe
# 21: %08X%08X%08X%X
# 22: %s_%08X
# 23: ntdll.dll
# 24: outpost.exe
# 25: zlclient.exe
# 26: SetErrorMode
# 27: *%u.%u.%u.%u*
# 28: image/jpeg
# 29: screens\%s\%04X_%08X.jpg
# 30: winsta0
# 31: default
# 32: gdiplus.dll
# 33: ole32.dll
# 34: gdi32.dll
# 35: DISPLAY
# 36: GdiplusStartup
# 37: GdiplusShutdown
# 38: GdipCreateBitmapFromHBITMAP
# 39: GdipDisposeImage
# 40: GdipGetImageEncodersSize
# 41: GdipGetImageEncoders
# 42: GdipSaveImageToStream
# 43: CreateStreamOnHGlobal
# 44: CreateDCA
# 45: CreateCompatibleDC
# 46: GetDeviceCaps
# 47: CreateCompatibleBitmap
# 48: SelectObject
# 49: BitBlt
# 50: DeleteObject
# 51: DeleteDC
# 52: reboot
# 53: shutdown
# 54: resetgrab
# 55: upcfg
# 56: kbot
# 57: rename_bot
# 58: getcerts
# 59: getmff
# 60: delmff
# 61: sethomepage
# 62: bc_add
# 63: bc_del
# 64: block_url
# 65: unblock_url
# 66: block_fake
# 67: unblock_fake
# 68: kos
# 69: rexeci
# 70: rexec
# 71: lexeci
# 72: lexec
# 73: resetkwm
# 74: application/x-www-form-urlencoded
# 75: Content-Type: %s
# ZCID: %s
# 76: Keys:
# 77: TYPE
# 78: FEAT
# 79: PASV
# 80: STAT
# 81: LIST
# 82: anonymous
# 83: https://onlineeast#.bankofamerica.com/cgi-bin/ias/*/GotoWelcome
# 84: CustomerServiceMenuEntryPoint?custAction=75
# 85: Q%u: %s
# A%u: %s
#
# 86: drivers\etc\hosts
# 87: Accept-Encoding:
#
# 88: %08X.uf
# 89: *.uf
# 90: getfile
# 91: addsf
# 92: delsf
# 93: software\microsoft\windows\currentversion\explorer\comdlg32
# 94: filesearch\%06X_%s
# 95: pass
# 96: certs\%s_%02u_%02u_%04u.pfx
# 97: GRABBED TAN:
# 98: SKIPPED TAN:
# 99: wmclient.dll
# 100: WebMoney Keeper Classic
# 101: WebMoney Keeper
# 102: webmoney\*.init

# %% [markdown]
# ## Extract Version
#
# Pseudocode:
#
#     ...
#     version[0] = 0x1020713;
#     r = BinStorage::_addItem(binStorage, 10003, 4, version);
#     ...
#
# Disassembly:
#
#     ...
#     .text:00412819 BB 13 27 00 00                                mov     ebx, 2713h
#     .text:0041281E 8B C6                                         mov     eax, esi
#     .text:00412820 C7 45 F8 13 07 02 01                          mov     [ebp+version], 1020713h
#     ...

# %%
match = re.search(rb'\xbb\x13\x27\x00\x00[\s\S]{2}?\xc7\x45[\s\S](?P<version>[\s\S]{4})', 
                  pe.get_memory_mapped_image())
version_bytes = match.group("version")
version = ".".join([str(b) for b in version_bytes[::-1]])
print(version)
# Out:
# 1.2.7.19

# %% [markdown]
# ## Get BaseConfig
#
# Pseudocode:
#
#     ...
#     pe = (g_self_image + *(g_self_image + 0x3C));
#     data1_section_addr = 0;
#     if ( pe->FileHeader.NumberOfSections >= 4u )
#     {
#         data1_section_header = (&pe->OptionalHeader.DataDirectory[3] + pe->FileHeader.SizeOfOptionalHeader);
#         data1_section_addr = (g_self_image + data1_section_header->VirtualAddress);
#         if ( IsBadReadPtr(data1_section_addr, data1_section_header->Misc.PhysicalAddress) )
#             data1_section_addr = 0;
#     }
#     g_base_config = data1_section_addr;
#     ...

# %%
data1_section = pe.sections[3]
base_config = pe.get_data(data1_section.VirtualAddress, data1_section.Misc_VirtualSize)
print(base_config)
# Out:
# b'j\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80\xee6\x00`\xea\x00\x00`\xea\x00\x00`\xea\x00\x00\x80O\x12\x00`\xea\x00\x00!\x00\x1d\x00\x00\x04w\xdb\xb5\xbc(\x9f\x10G\xfel\xf8F\xf9\x11\xd1RZ\x15\xc5H\xd3^\xfbT\xacs\xf6xpSU\x9e7\xbb\xef\x166\x90\x93*\x18\xedCP\xf3\x92\x19\x14u\xc0\xabA\x8a\x0ci\x91\x06\x1a2\th\xa9\xae8\xa1O\\\'\x9bJ\xb1\r\xf2&\xf4\xcc\x82}30.\x7f"j\x0b\xb9<\xd9X)q\xa2\x84N|\xaf\xd5\xa3Q\x96\xc1\x88\x9a\xc4\xdc\x98D\xb6;\x80\xcb\x9d5\xc3\xee@\nm\xc2\x02\xcd={\x17\xdd-\x8d\x81y\xb7\xb0\x8c\x8fb\x08\xa7\x1f\xf0\xf7\x94\xd2\xe8\xb2\xfc\x95I\xcfknro\xa8~\xda\xd8\xe9+W\xd6\x1c\x05!>\xb3\xe1\xa6\x13\x12/\x03_,\xc9\xbd`L\x839\xca\xbf\xea?\xe5\xb4B\xf5%\xaa\xc6\xa5\xe2tv\xbeV4\xeb:\xe6\x99\x1d\xd0Y\x04M\xc7\xd7[\xd4\xb8\x8e\x97\xad\xba\x1b\xde\x9c\xa4\xecd\x89\xf1z\x87\xdf\xc8\x01cf\x85$\x8b] \xe0a\xce1#E\xa0K\xe7\xfag\xe3\xe4\xff\x86\x0f\x00\xfd\x0ee\x1e\x07\x00\x00^}f}(@\x19wX\x87U\x8cS\x8f>\x98\x04\x8c5\\3\xa9\xf9\x985\xa7(\xa6%o\x1c\xae$^}f}(@\x19wX\x87U\x8cS\x8f>\x98\x04\x8c5\\3\xa9\xf9\x9e6g2\xa5. ...

# %% [markdown]
# ## Parse BaseConfig
#
# Pseudocode:
#
#     void *__userpurge decrypt_url@<eax>(int plainbuf@<eax>, unsigned int len@<ebx>, int encbuf)
#     {
#       int *p_buf; // edi
#       void *buf_len; // eax
#       unsigned int i; // eax
#       int buf; // ecx
#
#       p_buf = plainbuf;
#       if ( !plainbuf )
#       {
#         p_buf = &encbuf;
#     LABEL_7:
#         for ( i = 0; i < len; ++i )
#         {
#           buf = *p_buf;
#           if ( (i & 1) != 0 )
#             *(buf + i) += -7 - 2 * i;
#           else
#             *(i + buf) += 2 * (i + 5);
#         }
#         return len;
#       }
#       buf_len = (len + 16);
#       if ( len != -16 )
#         buf_len = Mem::alloc(buf_len);
#       *p_buf = buf_len;
#       if ( buf_len )
#       {
#         Mem::_copy(buf_len, encbuf, len);
#         goto LABEL_7;
#       }
#       return buf_len;
#     }

# %%
def decrypt_url(encrypted_url):
    url = b""
    for i, eb in enumerate(encrypted_url):
        if i & 1 == 1:
            pb = (eb - 7 - 2 * i) & 0xff
        else:
            pb = (eb + 2 * (i + 5)) & 0xff
            
        url += struct.pack("B", pb)
        
    return url


defaultBotnet = base_config[0x8:8+4].decode()
print(f"defaultBotnet: {defaultBotnet}\n")

delayConfig = struct.unpack("I", base_config[0xc:0xc+4])[0]
print(f"delayConfig: {delayConfig}\n")
delayConfig2 = struct.unpack("I", base_config[0x10:0x10+4])[0]
print(f"delayConfig2: {delayConfig2}\n")

delayReport = struct.unpack("I", base_config[0x14:0x14+4])[0]
print(f"delayReport: {delayReport}\n")
delayReport2 = struct.unpack("I", base_config[0x18:0x18+4])[0]
print(f"delayReport2: {delayReport2}\n")

delayStats = struct.unpack("I", base_config[0x1c:0x1c+4])[0]
print(f"delayStats: {delayStats}\n")
delayStats2 = struct.unpack("I", base_config[0x20:0x20+4])[0]
print(f"delayStats2: {delayStats2}\n")

baseKey = base_config[0x2a:0x2a+258]
print(f"baseKey: {baseKey}\n")

defaultConfig_len = base_config[0x24]
print(f"defaultConfig_len: {defaultConfig_len}\n")

encrypted_defaultConfig = base_config[0x12c:0x12c+defaultConfig_len]
defaultConfig = decrypt_url(encrypted_defaultConfig).decode().replace("http", "hxxp")
print(f"defaultConfig: {defaultConfig}\n")

testDownloadDelay_url_len = base_config[0x26]
print(f"testDownloadDelay_url_len: {testDownloadDelay_url_len}\n")

offset = 0x12c + defaultConfig_len
encrypted_testDownloadDelay_url = base_config[offset:offset+testDownloadDelay_url_len]
testDownloadDelay_url = decrypt_url(encrypted_testDownloadDelay_url).decode().replace("http", "hxxp")
print(f"testDownloadDelay_url: {testDownloadDelay_url}\n")

testDownloadDelay_buffer_len = struct.unpack("H", base_config[0x28:0x28+2])[0]
print(f"testDownloadDelay_buffer_len: {testDownloadDelay_buffer_len}\n")

num_langids = base_config[0x25]
print(f"num_langids: {num_langids}\n")

offset = 0x12c + defaultConfig_len + testDownloadDelay_url_len
langids = base_config[offset:offset+num_langids*2]
print(f"langids: {langids}\n")
# Out:
# defaultBotnet:
#
# delayConfig: 3600000
#
# delayConfig2: 60000
#
# delayReport: 60000
#
# delayReport2: 60000
#
# delayStats: 1200000
#
# delayStats2: 60000
#
# baseKey: b'w\xdb\xb5\xbc(\x9f\x10G\xfel\xf8F\xf9\x11\xd1RZ\x15\xc5H\xd3^\xfbT\xacs\xf6xpSU\x9e7\xbb\xef\x166\x90\x93*\x18\xedCP\xf3\x92\x19\x14u\xc0\xabA\x8a\x0ci\x91\x06\x1a2\th\xa9\xae8\xa1O\\\'\x9bJ\xb1\r\xf2&\xf4\xcc\x82}30.\x7f"j\x0b\xb9<\xd9X)q\xa2\x84N|\xaf\xd5\xa3Q\x96\xc1\x88\x9a\xc4\xdc\x98D\xb6;\x80\xcb\x9d5\xc3\xee@\nm\xc2\x02\xcd={\x17\xdd-\x8d\x81y\xb7\xb0\x8c\x8fb\x08\xa7\x1f\xf0\xf7\x94\xd2\xe8\xb2\xfc\x95I\xcfknro\xa8~\xda\xd8\xe9+W\xd6\x1c\x05!>\xb3\xe1\xa6\x13\x12/\x03_,\xc9\xbd`L\x839\xca\xbf\xea?\xe5\xb4B\xf5%\xaa\xc6\xa5\xe2tv\xbeV4\xeb:\xe6\x99\x1d\xd0Y\x04M\xc7\xd7[\xd4\xb8\x8e\x97\xad\xba\x1b\xde\x9c\xa4\xecd\x89\xf1z\x87\xdf\xc8\x01cf\x85$\x8b] \xe0a\xce1#E\xa0K\xe7\xfag\xe3\xe4\xff\x86\x0f\x00\xfd\x0ee\x1e\x07\x00\x00'
#
# defaultConfig_len: 33
#
# defaultConfig: hxxp://brnsounds.cc/ex/config.bin
#
# testDownloadDelay_url_len: 29
#
# testDownloadDelay_url: hxxp://brnsounds.cc/ex/ip.php
#
# testDownloadDelay_buffer_len: 1024
#
# num_langids: 0
#
# langids: b''

# %% [markdown]
# ## Download and Decrypt DynamicConfig
#
# ![](zeus1_1.2.7.19_pcap.png)
#
# An encrypted DynamicConfig is archived on the [Internet Archive](https://web.archive.org/web/20120730050214/https://zeustracker.abuse.ch/monitor.php?show=config&hash=a12d962f53c2f0e80a6d620c3fa9408b&downloadfile=1).
#
# Pseudocode:
#
#     ...
#     if ( rc4Key )
#         Mem::_copy(rc4Key_cp, rc4Key, 0x102u);
#     if ( a2 == v5 )
#     {
#         if ( rc4Key != v5 )
#             Crypt::_rc4(rc4Key_cp, binStorage, dataSize);
#     ...

# %%
def rc4_keystate(S, in_buf):
    out_buf = b""

    i = S[256]
    j = S[257]
    
    for in_byte in in_buf:
        (i, j, S, K) = rc4_prga(i, j, S)
        out_byte = in_byte ^ K
        out_buf += struct.pack("B", out_byte)

    return out_buf


def rc4_prga(i, j, S):
    i = (i + 1) % 256
    j = (j + S[i]) % 256

    S = bytearray(S)
    S[i], S[j] = S[j], S[i]
    S = bytes(S)

    K = S[(S[i] + S[j]) % 256]

    return (i, j, S, K)


# Load encrypted DynamicConfig
fp = open("ZeuS_config_a12d962f53c2f0e80a6d620c3fa9408b.bin", "rb")
config_bin = fp.read()
fp.close()

binstorage = rc4_keystate(baseKey, config_bin)
print(binstorage)
# Out:
# b'\x10\x89\x00\x00\x00\x00\x00\x00v\x00\x00\x00\x03\xf0\x92\xb4\xce\xfc\xea\xd1|\x00\xabu\x8f\x1d\xa6|!N\x00\x00\x00\x00\x00 \x04\x00\x00\x00\x04\x00\x00\x00\x13\x07\x02\x01"N\x00\x00\x00\x00\x00 \x1c\x00\x00\x00\x1c\x00\x00\x00http://brnsounds.cc/ex/1.exe#N\x00\x00\x00\x00\x00  \x00\x00\x00 \x00\x00\x00http://brnsounds.cc/.zs/gate.php&N\x00\x00\x01\x00\x00 \x85\x00\x00\x00\xa1\x00\x00\x00\xdb\xff\xff\xff!*.microsoft.com/*\x00!http:/\tm\xd6}\xed\xfdyspace\x16\x15\x14s\x15w\x00\xb0\xbf\xbd\xfd.grup1ant\x02der.es5\xc0\xda\xff?odnoklassniki.)\x1b\xfb?\xbb{vko3kte\x16@*/login.K0`Ovmp\x12atl\x10\x00\x00\x00\x00\x00\x00\x00H\x00\xff*N\x00\x00\x01\x00\x00 \xc0\x00\x00\x00\xe8\x00\x00\x00\xff\xbf\xfc\xffO\x00\x01\x00\x03\x01\x06\x00\x10\x00<\x00D\x00https://banki\xcf\xfd\xff\xffng.*.de/cgi/ueberweisu\x15\x10\xd7}{\xff*\x00*&tid=\x07\x1atrag\nIB\xb6%\xf9o\x03\x00N9\x00;\x00=Jt=`\xef\xc3\xdan%VgadX\x0e\xef\xb7\xdf\xbdK\x01KktNrT\x12Enz\x00PH[\x1b\xb0\x9f\x02A\x00N\x97w\x00}i\xff\xdb\xdfkw9A*/j\n/mp#/Subm\xef\xff\xcbo\x18Recapo\x00SYNC_TOKEN\xa1\x00\x00\x00\x80\x00\x00@\x02\x00\xff\x01\x00\x00\x00\x00\x00\x00\x80D\x00\x00\x00D\x00\x00\x00+\x00\x00\x00\x06\x00 Registered email address</td>*<img*>\x0b\x00\x00\x00\x06\x00</td>\x0e\x00\x00\x00\x06\x00e-mail: \x02\x00\x00\x00\x01\x00\x00\x80d\x00\x00\x00d\x00\x00\x00\xff\xff\xff\xcbJ\x00\x06\x00(<a href="http://feedba\xff\xf6\xff\xf6ck.e\x05y.com/ws/eB\x0bISAPI.d\x8f\xfd`\xffll?ViewF&&*">\nI</a\x00\xf0\xb0\xd8>\x10\t\x1b: \x00\x00\x00\x00\x00\x00\x00H\xff\x03\x00\x00\x00\x00\x00\x00\x80G\x00\x00\x00G\x00\x00\x003\x00\x00\x00\x06\x00<table cellspacing="0" summary="page layout">\x0e\x00\x00\x00\x06\x00</table>\x06\x00\x00\x00\x00\x
\xeesiz\x1920\tmaxleng\x8b14\x0e\x1b\xf6[ytit\nEnterl\x15}\xeb\xde\x9al5dex#1\racce\xfe\x17\xbb\xbdPkey\x0eA"~\x85&nbsp;\xbb\x80\xcd\xc6\xeb-\xe5\xd52ou\xd8\xec\x00kS\xd4\x0e,\xd0\xdc\xfe66\x13\r4\xe8Sign o\x02to\x00\x00\x00\x00\x00\x00\x12\x00\xff\n\x00\x00\x00\x01\x00\x00\x80D\x00\x00\x00P\x00\x00\x00\xff\xff\xff\xcb ...

# %% [markdown]
# ## Parse DynamicConfig

# %%
def parse_binstorage_header(binstorage):
    header = {
        "size": struct.unpack("I", binstorage[0:4])[0],
        "flags": struct.unpack("I", binstorage[4:8])[0],
        "count": struct.unpack("I", binstorage[8:12])[0],
        "md5Hash": binstorage[12:28],
    }
        
    return header


def parse_binstorage_sections(section_data, num_sections):
    CFGIDS = {
        20001: "CFGID_LAST_VERSION",
        20002: "CFGID_LAST_VERSION_URL",
        20003: "CFGID_URL_SERVER_0",
        20004: "CFGID_URL_ADV_SERVERS",
        20005: "CFGID_HTTP_FILTER",
        20006: "CFGID_HTTP_BOTLOG_FILTER",
        20007: "CFGID_HTTP_POSTDATA_FILTER",
        20008: "CFGID_HTTP_FAKES_LIST",
        20009: "CFGID_HTTP_INJECTS_LIST",
        20010: "CFGID_HTTP_TANGRABBER_LIST",
        20011: "CFGID_DNS_LIST"
    }
    
    sections = []
    offset = 0
    for i in range(num_sections):
        section = {}
        
        id_ = struct.unpack("I", section_data[offset:offset+4])[0]
        if int(id_) in CFGIDS:
            section["id"] = f'{CFGIDS[int(id_)]} ({id_})'
        else:
            section["id"] = id_
            
        section["flags"] = struct.unpack("I", section_data[offset+4:offset+8])[0]
        section["size"] = struct.unpack("I", section_data[offset+8:offset+12])[0]
        section["realSize"] = struct.unpack("I", section_data[offset+12:offset+16])[0]
        # additional parsing of data is left as an exercise
        section["data"] = section_data[offset+16:offset+16+section["size"]]
        
        offset += 4 + 4 + 4 + 4 + section["size"]
        
        sections.append(section)
        
    return sections


binstorage_header = parse_binstorage_header(binstorage)
print("binstorage_header:\n")
pprint.pprint(binstorage_header)

binstorage_sections = parse_binstorage_sections(binstorage[28:], binstorage_header["count"])
print()
print("binstorage_sections:\n")
pprint.pprint(binstorage_sections)
# Out:
# binstorage_header:
#
# {'count': 118,
#  'flags': 0,
#  'md5Hash': b'\x03\xf0\x92\xb4\xce\xfc\xea\xd1|\x00\xabu\x8f\x1d\xa6|',
#  'size': 35088}
#
# binstorage_sections:
#
# [{'data': b'\x13\x07\x02\x01',
#   'flags': 536870912,
#   'id': 'CFGID_LAST_VERSION (20001)',
#   'realSize': 4,
#   'size': 4},
#  {'data': b'http://brnsounds.cc/ex/1.exe',
#   'flags': 536870912,
#   'id': 'CFGID_LAST_VERSION_URL (20002)',
#   'realSize': 28,
#   'size': 28},
#  {'data': b'http://brnsounds.cc/.zs/gate.php',
#   'flags': 536870912,
#   'id': 'CFGID_URL_SERVER_0 (20003)',
#   'realSize': 32,
#   'size': 32},
#  {'data': b'\xdb\xff\xff\xff!*.microsoft.com/*\x00!http:/\tm\xd6}\xed\xfdyspa'
#           b'ce\x16\x15\x14s\x15w\x00\xb0\xbf\xbd\xfd.grup1ant\x02der.e'
#           b's5\xc0\xda\xff?odnoklassniki.)\x1b\xfb?\xbb{vko3kte\x16@*/login.K'
#           b'0`Ovmp\x12atl\x10\x00\x00\x00\x00\x00\x00\x00H\x00\xff',
#   'flags': 536870913,
#   'id': 'CFGID_HTTP_BOTLOG_FILTER (20006)',
#   'realSize': 161,
#   'size': 133},
#  {'data': b'\xff\xbf\xfc\xffO\x00\x01\x00\x03\x01\x06\x00\x10\x00<\x00D\x00ht'
#           b'tps://banki\xcf\xfd\xff\xffng.*.de/cgi/ueberweisu\x15\x10\xd7'
#           b'}{\xff*\x00*&tid=\x07\x1atrag\nIB\xb6%\xf9o\x03\x00N9\x00;\x00=Jt=`'
#           b'\xef\xc3\xdan%VgadX\x0e\xef\xb7\xdf\xbdK\x01KktNrT\x12Enz\x00'
#           b'PH[\x1b\xb0\x9f\x02A\x00N\x97w\x00}i\xff\xdb\xdfkw9A*/j\n/mp#/S'
#           b'ubm\xef\xff\xcbo\x18Recapo\x00SYNC_TOKEN\xa1\x00\x00'
#           b'\x00\x80\x00\x00@\x02\x00\xff',
#   'flags': 536870913,
#   'id': 'CFGID_HTTP_TANGRABBER_LIST (20010)',
#   'realSize': 232,
#   'size': 192},
#  {'data': b'+\x00\x00\x00\x06\x00 Registered email address</td>*<img*>\x0b'
#           b'\x00\x00\x00\x06\x00</td>\x0e\x00\x00\x00\x06\x00e-mail: ',
#   'flags': 2147483648,
#   'id': 1,
#   'realSize': 68,
#   'size': 68},
#  {'data': b'\xff\xff\xff\xcbJ\x00\x06\x00(<a href="http://feedba\xff'
#           b'\xf6\xff\xf6ck.e\x05y.com/ws/eB\x0bISAPI.d\x8f\xfd`\xffll?ViewF&'
#           b'&*">\nI</a\x00\xf0\xb0\xd8>\x10\t\x1b: \x00\x00\x00\x00\x00'
#           b'\x00\x00H\xff',
#   'flags': 2147483649,
#   'id': 2,
#   'realSize': 100,
#   'size': 100},
#  {'data': b'3\x00\x00\x00\x06\x00<table cellspacing="0" summary="page layou'
#           b't">\x0e\x00\x00\x00\x06\x00</table>\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 3,
#   'realSize': 71,
#   'size': 71},
#  {'data': b'\x14\x00\x00\x00\x06\x00e-mail:</font>\r\x00\x00\x00\x06\x00</font'
#           b'>\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 4,
#   'realSize': 39,
#   'size': 39},
#  {'data': b'\x1d\x00\x00\x00\x06\x00<form name=fiat*</form>.\x00\x00'
#           b'\x00\x06\x00<th colspan=4 align=left valign="bottom"\x06'
#           b'\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 5,
#   'realSize': 81,
#   'size': 81},
#  {'data': b'\xff\xff\xff\xcb*\x00\x06\x00<div id="pageIntro" cla{\xf6\xf2\xdbs'
#           b's\x11nopri">A)td(o\xbf}\x1bs\x04ebar&align\x0flef\x95\xb5\xc1n# '
#           b'v\rt4@\x00\x00\xd0\xcc\x06\x00H\x00\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 6,
#   'realSize': 113,
#   'size': 92},
#  {'data': b'\xb7\xff\xff\xcb;\x00\x06\x00<span class="moz\toa\x7f\xb7\xfd\xffk'
#           b'"><input type\x16p\x1cword"*<o\xcf\xbe\xbf/.>\x06\x00\x00\xe6@br-st'
#           b'r\xdf\xdao\xedong\x07Fbel f+4atmp\x8f\xb5\x7fkDIATM PIN9\x1b>:<\xfb'
#           b'n{\xb0/,&nbL;> />\r\n\x87\xb6\xb7\x9f\x08 acce\x0bkey\x14A'
#           b'\xde\xee\x93\xdd\ridn nam)US+n\xbfm\xde\rsiz13\tmaxleuth\xad'
#           b'u\x9b\xeb\x0e4\x18Ql\x19w:\x11\xf6\xd6\xb6\xb7:\x107px\x13t\xa0Adex'
#           b'\x16\x00\x80`\xee2"\x93\xeb\x02\x00\x00\x00\x00\x00\x00@\xff',
#   'flags': 2147483649,
#   'id': 7,
#   'realSize': 295,
#   'size': 226},
#  {'data': b'\xff\xff\xff\xcb2\x00\x06\x00<input type="password" \xf6'
#           b'\xfd\x0f\xecnam\x0f*</td>\x06\x00\x00\xe67\xff\xbf\xfdm\x0f widt'
#           b'h%225"><label f\xd7\xdc\x03k-Fcl\n\x10\x15k\xff\xb7Xm\x1f\'3. ATM '
#           b'PINR\x12\x9d\xc8\xfe\x169br/>\r\n\x88US\xad}k\xed\x11\rp\x0batmp+'
#           b'\x0b\xfb\xfd\xdb\xeesiz\x1920\tmaxleng\x8b14\x0e\x1b\xf6[ytit\nE'
#           b'nterl\x15}\xeb\xde\x9al5dex#1\racce\xfe\x17\xbb\xbdPkey\x0eA"~\x85&'
#           b'nbsp;\xbb\x80\xcd\xc6\xeb-\xe5\xd52ou\xd8\xec\x00kS\xd4\x0e,'
#           b'\xd0\xdc\xfe66\x13\r4\xe8Sign o\x02to\x00\x00\x00\x00\x00\x00'
#           b'\x12\x00\xff',
#   'flags': 2147483649,
#   'id': 8,
#   'realSize': 364,
#   'size': 251},
#  {'data': b'\xff\xff\xff\xcb2\x00\x06\x00<input type="password" \xf6'
#           b'\xfd\x0f\xecnam\x0f*</td>\x06\x00\x00\xe67\xff\xbf\xfdm\x0f widt'
#           b'h%225"><label f\xd7\xdc\x03k-Fcl\n\x10\x15k\xff\xb7Xm\x1f\'3. ATM '
#           b'PINR\x12\x9d\xc8\xfe\x169br/>\r\n\x88US\xad}k\xed\x11\rp\x0batmp+'
#           b'\x0b\xfb\xfd\xdb\xeesiz\x1920\tmaxleng\x8b14\x0e\x1b\xf6[ytit\nE'
#           b'nterl\x15}\xeb\xde\x9al5dex#1\racce\xfe\x17\xbb\xbdPkey\x0eA"~\x85&'
#           b'nbsp;\xbb\x80\xcd\xc6\xeb-\xe5\xd52ou\xd8\xec\x00kS\xd4\x0e,'
#           b'\xd0\xdc\xfe66\x13\r4\xe8Sign o\x02to\x00\x00\x00\x00\x00\x00'
#           b'\x12\x00\xff',
#   'flags': 2147483649,
#   'id': 9,
#   'realSize': 364,
#   'size': 251},
#  {'data': b'\xff\xff\xff\xcb \x00\x06\x00<div id="accountOvervie|\xdd\x7f\xf6w'
#           b'">*\x1f/table>\x07d\x04r\x00x\x87\xec\x11\x06\x00\x00\x00'
#           b'\x00\x00\x00\x00\x00\x00$\xff',
#   'flags': 2147483649,
#   'id': 10,
#   'realSize': 80,
#   'size': 68},
#  {'data': b'\xff\xff\xff\xcb \x00\x06\x00<div id="accountOvervie|\xdd\x7f\xf6w'
#           b'">*\x1f/table>\x07d\x04r\x00x\x87\xec\x11\x06\x00\x00\x00'
#           b'\x00\x00\x00\x00\x00\x00$\xff',
#   'flags': 2147483649,
#   'id': 11,
#   'realSize': 80,
#   'size': 68},
#  {'data': b'p\x00\x00\x00\x06\x00<a href="#" onClick="javascript:handlePageLink'
#           b"('/internetBanking/RequestRouter?requestCmdId=AccountDetails"
#           b'\x0e\x00\x00\x00\x06\x00</table>\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 12,
#   'realSize': 132,
#   'size': 132},
#  {'data': b'\x17\x00\x00\x00\x06\x00Account Name</td>\x0e\x00\x00\x00\x06'
#           b'\x00</table>\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 13,
#   'realSize': 43,
#   'size': 43},
#  {'data': b'.\x00\x00\x00\x06\x00account-history-wait.jsp" method="post'
#           b'">\x0e\x00\x00\x00\x06\x00</table>\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 14,
#   'realSize': 66,
#   'size': 66},
#  {'data': b'"\x00\x00\x00\x06\x00id="dgDepositAcctsheader0"*>\x0e\x00'
#           b'\x00\x00\x06\x00</table>\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 15,
#   'realSize': 54,
#   'size': 54},
#  {'data': b'-\x00\x00\x00\x06\x00<td class="ice_headerleft">Deposit</td'
#           b'>\x0e\x00\x00\x00\x06\x00</table>\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 16,
#   'realSize': 65,
#   'size': 65},
#  {'data': b' \x00\x00\x00\x06\x00<td class="acctName_Text">\x0e\x00\x00\x00'
#           b'\x06\x00</table>\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 17,
#   'realSize': 52,
#   'size': 52},
#  {'data': b'\x1c\x00\x00\x00\x06\x00account summary</font>"\x00\x00\x00'
#           b'\x06\x00<td height="10" colspan="4">\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 18,
#   'realSize': 68,
#   'size': 68},
#  {'data': b'\x17\x00\x00\x00\x06\x00</SPAN></CAPTION>\x0e\x00\x00\x00\x06'
#           b'\x00</TABLE>\x13\x00\x00\x00\x06\x00BOFA balance:',
#   'flags': 2147483648,
#   'id': 19,
#   'realSize': 56,
#   'size': 56},
#  {'data': b'%\x00\x00\x00\x06\x00_accountSummaryContainer"*</tr>\x0e\x00\x00'
#           b'\x00\x06\x00</table>\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 20,
#   'realSize': 57,
#   'size': 57},
#  {'data': b'\x17\x00\x00\x00\x06\x00<tr class="rowa">\x0e\x00\x00\x00\x06'
#           b'\x00</table>\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 21,
#   'realSize': 43,
#   'size': 43},
#  {'data': b'\xff\xff\xff\xcb\x1e\x00\x06\x00<span class="bodyText5"\xd6'
#           b"\xde\xed\xd9>3\x1dtd\x1bol#\x1d\x15{\xfb\xdd\xb0'\x0fcerH20'&"
#           b'nb\r\x00\xc0{{;</(>\x06\x00\x00\x01\x00\x00\x00\x00\x00\x00 \xff',
#   'flags': 2147483649,
#   'id': 22,
#   'realSize': 87,
#   'size': 84},
#  {'data': b'\xff\xff\xff\xcb"\x00\x06\x00name =p  rethepassword*\x7f\x1b{\xfe<'
#           b"/TD>\x06\x00\x90'<\x0f bgCol\xff\xff\xbfo\x1d=#E7\x01 vAlign=top><I"
#           b'NPUT\x7f\x7fo\xff maxLengI=8 Y=ESR si\xff\xff\xed\xddze\x12styl\x07'
#           b'"FONT-FAMILY: Vem\x1f\xbbmna+; \x15SIZE\x138\x19lv\xdb\x8ft"\x02'
#           b'yp\x9b\x95>\xdfn\x7f\x16\xb7:oculy_f\x17m_on~\xb3\xb7\xffsubmit();'
#           b'\xb9TR\x0b\xb1,&\x01\xbf\xfd\x1d\xf6\nxc\xbe :#Q706E6\x97\r\x1b'
#           b'\xd8F;\x89\x88\x877\xcav\xfb\xedpt;_nt-we\xe7ht8b\xee\xb1\x87'
#           b'\xdfAd">\r\n\x0eh\x15=20\xfd{\xd8\x10\xdaMG\xa4\x0c\x1811w\xed\xdf'
#           b'\xfevrcu/grafi{sDJ/tip\xb3\xde~+\xb8d\xbb\x1bWo.gif\xe6wid;\xb2\xcf'
#           b'\x1e00\xde<TDOb\xfb\x1dd\x17\x9a\x9c\t0 Zn\xbf\xe4\x10\xd6Sr\\77Cla'
#           b'vG\xb8p\xb2e\rFi?a%0fu<@\xd8\xdanc\x9f\xef Z*{\xd8\xdfbg\rz*Y(self'
#           b'.l\xed\t\x03v.2.\xf3.v\xc0\xa1\xb5\x8f\xf1ue.l\x0e<4){\x0e\x9e'
#           b"\xa1\xb7val'~ \xd8rsZ\x12 (\xbb\xf1\xddf\x0f\xdf f\x89)6o "
#           b"2\n\xb7\xd6Z\xd1S\xd9].'\xd1\x00\x00\xe0;\x98urn;}\x90\x00"
#           b'\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 23,
#   'realSize': 688,
#   'size': 471},
#  {'data': b'o\xff\xff\xcb"\x00\x06\x00id="clave" name\x0copp\xf7c\xdf\xffasswd'
#           b'"*>\x06\x00\x00\x9b\'<div (\xef\xfe\xff5\x1a/ear sep4"></\x18>\r\n'
#           b'<\xbd}\xf7o\x1abel for\x1fodusu"io2\xd6\xfe\xed\xb7 C\\ d\x02fir'
#           b'ma: 0)la\xff/2input id1\x87\x1f\x1b\xf6\x1cES"s+01 a\xd9\xec\xbfm{f'
#           b'3w180"/>-\x9aG\x0f\xdbZ\xf7typ6hNknDSX\x8d\xb2\xc9\xfePASWI_#\xcd32'
#           b'\xb1\xcem\x87wviu\x0ee)2\xb7[\xfb`\x0fEntr\xa7Non\x98ic'
#           b'\xec\xdb\xd6\xb6k\x10j\xde/c\xb9pt:2(\xbfu\xb7m"\xd9\xad\x02- \x00F'
#           b'\x16day, \xff\xdb\x85\xf6Octo\xf3219\x0b2007 3:02\xfb\xd6\x1e\xfb'
#           b' AM \x101CheIw();\x0f\x9d\x1d;l6O\xb2\xc5\x14fu\xd6&\xbb\xb0qt'
#           b'\x1fn -{xR[lk\xffvv=docu\xb9\x97.\x9bp.\x85\xedcg\xc2.\xb1;if(#'
#           b".5&\xbc\xa1\xfdngth<44@rt('\x96\x17\xc2\xad\xdd\xfersR\x12 (\xa6)"
#           b"\x1e+\xb4\x0b\x0co 2\x96Qo.'\xd6]\xf6\xdf\x9areturn;}mx"
#           b'\x1bn\x15\xb6\xb5\xd6\xdaP\x85\x97\x13?!sz\xd0\xb5o\x13=w;Va'
#           b'c\xb3\xd8}\x00\x00\x00\x00\x00\x00H\x00\xff',
#   'flags': 2147483649,
#   'id': 24,
#   'realSize': 622,
#   'size': 441},
#  {'data': b'\xfd\xff\xff\xcb \x00\x06\x00name="oppasswd"*</tr>\xb1c\xb1'
#           b'\xae\x05\x04\x0b\x1f\x0f\x19\x01\n\xdb\xf6\xb7\xfftd height024" a'
#           b'l\x0bn\nro7w{\x11\rclA\rfi\x071">\xd6\xbe\x9d\xfd&nbsp;\x05C\x11ve'
#           b' d\x02\x1b+\xec\xbd\xfbrma:Qd>\r\nM3\xb7c\xee\xff <input t'
#           b'yp\x9e\x9cor\x9e s\xb1\x7fk\xddiz\x0f8\x08Hxlength\r\xf6'
#           b'\x93\xbdg\xc5ES(\x8acmbco\x03\xf7\xee\xca\xdaoYrbMetabx'
#           b'\xbb\xdd\xdc\xfb widG\x82umgcrc\x0c\x16\xb0o]\x08/\x87.gif'
#           b'\x1f\xfe\xb0\t\x83M1S2#\xab\x84a[;h,Yn\x92V\xde\xcd-\x1c v,'
#           b'u\x0e6\x06\x00\x00&\x1b\x96\xca7\xca7\x1ea{\xdb\xcd1s<a\x86ref\x14j'
#           b'V[\xec\x0b[#c~pt:\x08\x1d%\x10f\xdfnc\x07C\xa6ckA();\x0f5\x0b\xb1'
#           b'\xc1\xce%*|\xbf\x14\x0efo\xdbd\xffunction /{Prrv=d\x9d\xfd\xf6'
#           b'\xedocu\x85nt.E\x03rada.\x8e.\x9e\xb0-\x8c\x8d;\x12(#.}<4\xdd&'
#           b"\xfc\xd64\x14ert('\xe6\xcarsn\x17\xc2\xadR\x12 (\xf6)\xd8o [{"
#           b"\xac\xd02\x90Qo.'\x9c\xc4tao#\xfburn;}m\x01tosr\x00]\xfb6=o;Vac"
#           b'\xab\xd2}\x00\x00\x00\x00\x00\x00\x80\x04\xff',
#   'flags': 2147483649,
#   'id': 25,
#   'realSize': 696,
#   'size': 440},
#  {'data': b'\xff\xff\xff\xcb\x1b\x00\x06\x00name="password"*</tr>\x06\x00\xfe'
#           b'\xcd\x8d=\xe1 <\x0f\x03d width;\xd6\xfc\xdf)50">&nbsp;d\x19cl=\xd9'
#           b'\xad\xfd\x9b\x19textoHoN 4."\xbf};\xb0\x05C%ve d\x02Firm'
#           b'a\xed\xe5\xbfc<\r\n>aligncenAv`\xff\xb7r;<INPUT typ\x97 '
#           b'\xa7\xcdm\xdb{ES\x11\rv4u\x0e\x08a\xe5\xdbnIxl8g\x996\x8a~\xdb'
#           b'\xba\xcfTCoPn\xb5o\x16tabin\xd97{\xdbzx\x194">\xb7\xe64\xe0om\xb0'
#           b'\xb7\x1aputph/\'n"  \x0c\x1b\t\x16p\x1a\xe1\xc8F\xd929\xa8>m'
#           b'\xfbo\xdb?functi\x98 )viar()*{\x01\xed\xf6\xd8YR\xa5 if(\xb0cuB'
#           b"\x9dm\xaem\xbb.\xbd\xce\r.K./\xb4\x9f\x8dJ.\xed<4){\x0e.t('"
#           b"\x97\xad\xb5\x08NO\x0cXric\xff\xaf\xebn\x0bno^c\xfdr=');retur\x93"
#           b'\x15\xbemsf1se;}ual\x89l\xc2\xdaog\xc2_=}\x00\x00\x00\x80;'
#           b'\x00@\x02\x00\xff',
#   'flags': 2147483649,
#   'id': 26,
#   'realSize': 564,
#   'size': 353},
#  {'data': b'\xfd\xff\xff\xcb!\x00\x06\x00name="password"*</TD>\xfe\xf6\xfd'
#           b'\x9e\x05\x06\x00\x00G\x01&<\x0f align\xb6\xae\xfd\xdf+left" cols5'
#           b'\x0e7\x0bv\xe9b\xff\xc1\x19bottom">=\x04Rys\xbf]\x03\r\n<clb"'
#           b'tex\xdbO\xd8mH$e"N>3. C!v\xd6\xfe\xdb\xede d\x02TrWsferenci4L'
#           b"\xdf\xdd\xfe,Cwidth120bIMG s\xb9\xff\xb7\xffrc='/img4yg/px.gif' b"
#           b'\xc7n\x0f\xd8\xad<\x180\'0 hemhtKX\xc0\xde\x0b1">Q\x83S\t'
#           b'\x07\xc2\x7fNPUT typ\x11 !\xf9no\xefES\x11\rmax-ngV6\x1cv\xdb\xbeta'
#           b'binnx\r3"\xe3T0\xd8\xb6\xfdCon\xebn\x7foo+\xbc\xb5\t\x8bmbh\x1d9'
#           b'n" \xca\x06!$\x82w)0\x0e\t\x0f6\x91>.\x00\xa0cem\x0b\xad\xebzr'
#           b'wA\xf5Df\x10#\xce\xda\x0b\xad2\x8d^ick\x0b\\\x9e\xd6\xbd-\xc4'
#           b'3-(\x9fcum/.1\xddp\xb6\xb9\xbd\r.U.\xd2ue.\x85\xbf\xb5\x9f\xe9<4){'
#           b"\x0eQt('Fir\x00\xed\xd6\xda\xdb e\x0cctrRP\x0bno\x0e\x7f\xfb\xeb"
#           b"\n\xa7\xecr=');qturn;}\x13\xb6p\xb2;Zda\x0esX=\x00\x00Ldv"
#           b';\x12\x00\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 27,
#   'realSize': 666,
#   'size': 426},
#  {'data': b'\xfe\xff\xff\xcb\x1a\x00\x06\x00name="password"*<tr>'
#           b'\x06\x00\xdb\xdb\x1d{\xf4\x1f</\x10\r\n\x16\x03d\xdd\xdc\xdf\xfe'
#           b' height020" cl5\nc"\xef~\xd8\xb6\x19s@n\x0ftxtb\x13Firm'
#           b'\x01\xb6\xfb\xdaa:>\x1a>Ed>Jg\x07\xf6\x7finput typ\x96 \xa6E[\xdb'
#           b'\xbc\xbdS\x11\rsiz16\tbxo\xff\xb6\xfdlength\x0e9\ronkeyUp\x0bja'
#           b"v\xf6\x7f\xfbo(cript:cu\x1fta('pwd');#)\xeb\xde\xb6\x0bbbdex"
#           b'x"\x97\xe1\xdb\x07\x84\x16\x13btnE9rar"\x0f\x13\xf6\x1f;\x80\x1b On'
#           b'Clickc \xfe\xb6\xdb\xfeif  (dokml.f\xb2ms[0].\xffl\xdb\xce\xaf.'
#           b"'l\x84.\xa7 < 3) \xd7\xbe\xbd\xb5{n\x13ert\x96Debe>gEXXxoduc2 \x08 "
#           b'9\xc0o\x0b\xdf\xabreturVf)se;}"\x00\x00\x00\x00\x00\x00 \x01\xff',
#   'flags': 2147483649,
#   'id': 28,
#   'realSize': 432,
#   'size': 320},
#  {'data': b'\xff\xff\xff\xcb\x1c\x00\x06\x00name="sl_clave"*</div>\x06\xb6'
#           b'\xeb\xc6\x9e\x00\xbf!<\x10 \x1dss\'\xff\x07\xf6\xedfi\x07">\r\n'
#           b'\x13textoform\x0b\x9b\xddn\x18Fi\x05a:B$u\x1f;\xf9input<\x0b ty'
#           b'pxp\xdb{\xf6\xd6\x1dw\x16d" \x88ES\x11\rT\xbb{\xdb\xfeABINDEX\x113'
#           b'\x0csiz\x1a10"M\xfe\xad\xbd\x01Tu\x10nxlengthfc\xc9\xde\x148">'
#           b'y\x079\xbe=\xac\xfd\xc0nhidd.lan\xed\xee[\xbb\xbbri}\x0fvalu\x10L'
#           b'OGu@vl\xb0"\xfd4>\r\n@\xb1-\xd8\xb0\xad>9\x1a3\xdb\n\xdb\xdbo'
#           b'n\xa7ick\x10jR\x1fcb[\x17;{pt:S\x87\x1f/r\x03v\xf6\x0f[\xfb=do'
#           b"cuF\x84.\x18s[0].P?\xdb>v.O;if($.\xde<4){-\xc2[k\x8a\x16\xaft('f"
#           b"\x82\xffoo\xdbo \x1acktraH.');return;\xc2\xda-\xd9} W\x03vij"
#           b'Um\x1b\xecm=R;"r\xdas1_2\x16\xde\xda\xffl https://L\xb7neb\x17k'
#           b"\xdb\xbe\xad\xdd\x06g.`\xb9s\x0c.\xf2/\x0c\xad\xdd\xda'/log\x1d"
#           b'\x12o?b\x97\xdd\xbf}\xecod=\x0f* GPOdata_be\xcee\xa1\xd1Nh\x0c'
#           b'"p\x1bTR;\t\x13\x0e\xce\x91\xa5td\x06\x860\xd89r\x05d\xe4{'
#           b'K\xc6\xd6\x05Ill\xbbign\x14#\xdbh\x9b\\t\x13\x1dND\x89\x8c'
#           b'\x13\xd8td)\r\nn\x861al\xaenC6ln\xdb\xda\xe6\x08\x1bb:\xf9x\x0c'
#           b'2\x15\xfd\xad\xd0m?l\x16w\xfe&:50px;\x84\xb3\x01\xc9[@"\xe0\x80\xdf'
#           b'xa\xca\xf8OnC\x00 \xce  (\x08\x13\xdcJ\xf2\x82\x99\xe9,\xbc\x84? < '
#           b'3) \xecBi\x9ce\x9aZ\xa1-\xa1i\x0c\xd7\x04\x18N\x84V0\x14\xf6'
#           b'\x9d\xa5-\xf3\xc0B\xa1\x9d f,\xcb\xf9"\x00\x00\x00\x00\x00\x00'
#           b' \x01\xff',
#   'flags': 2147483649,
#   'id': 29,
#   'realSize': 980,
#   'size': 595},
#  {'data': b'\xfe\xff\xff\xcb\x1a\x00\x06\x00name="password"*<tr>'
#           b'\x06\x00\x83\xdd\x1d{\xb2\x1f</\x10\r\n<\x05d\xf6\xe6\xbe=s.n cl39'
#           b'app\x08\xf7\xba\xbb\xffbelFalt"\x1cTAN!/"*\xb7\x97\xb9\xd9/1\x05\n'
#           b' v+ig`\xff\xbf\xb7n;top2<input typ\x89\x9b\xb7vv \x99tG\nsiz10'
#           b'\xb0\xb2\xfdo\tmaxlength\x0e5a;\xb0\xd8\x17\xa6\x18\xb1Mi/n\x1f;{g'
#           b'e"\xcf\x82\x1d OnC}ck\xf6\xff\xbf\xdd\x1bja\x87script: if  (docur]w'
#           b"\xbb\xfbnt.S\x9donF\x85m.~.\xaeu\x7fk\xff\xd9e.v < 3) {p\x13ert('Bm"
#           b"\xb7\xdd\xfeitte hi\x0c d\x04 \xfd e\x80[\xf8_hs\x11n');retur*f"
#           b',\x00\x00\x00~se;}"\x00\t\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 30,
#   'realSize': 370,
#   'size': 291},
#  {'data': b'\x9e\xff\xff\xcb\x14\x00\x06\x00name="uPSW"*/>\x06\x00'
#           b"\x9a\xed\xff\xdb\xc7\x19<br \x11\r\n<div class'\xc1~\xf7n"
#           b'\x05b"\x12\x07el for:\x7f\xee\x8b\xfd>tan</\x15\x1e/2\x07inp]\xf7'
#           b'\xdd\xecut b!" typ\npKw\xdd\xb6\xc3n;d"Ve/t\x0cid\xff\xdb\xee\x83M '
#           b'siz&16\tmaxlength\xf7\x01\xdbn\x0e8"\x8d\x13\xb3Subm6o\xff\xb13\xb2'
#           b'o\x18 OnClick\x1cjavo\xff\xedoYcript:Wf  (docu5nt.\xd9\xb7'
#           b"\xeew\xb4ms[0].\x90.$lue.a\xfd\x7fk\xff < 3) {\xb6\x13ert('\xe3"
#           b'\xf0\xe5\xf8\xed\xe0 \xe0\xb7\xf6\xdf&\');return\xf1\x1bse;}"\x00'
#           b'\x00\x00\x00\x00\x00\x90\x00\xff',
#   'flags': 2147483649,
#   'id': 31,
#   'realSize': 316,
#   'size': 268},
#  {'data': b'\xbf\xff\xff\xcb%\x00\x06\x00name="simple_sur\x0f_t\xdf'
#           b'\xde\xef\xffext"*<tr>\x06\x00\x00\x19\x01*\x0fd cl\xed\xed\xff\xeda'
#           b'ss/bold" width\x0c22%\x0b\xd6\xb6\xbf\xfdnowrap\x0c">Memo\nbN\x1f'
#           b'\xdfb\xdb\xb7\x07d:</6>:3span\xd9\xcd}s/-alig\t#ftF?\xec[935(fonte'
#           b'inpu\xb7\x8c\xb9\xf6tsty&\x18\x0c p\xae\xf6\x9e\xfd\\p\x1e\\" \xbe'
#           b'UK\x11\r\xddv\x81\xb5H\xca \x14z&2\xebb\xb7\xb74\tmax\x1dng\xb7'
#           b'\x0ev\x89\xee\xdb\xb0nu\x19"r\x08titl\x11\xb3o{a\xc5"/\x80/\x9a>'
#           b'\xce\x06\x84\xcdm\x04r\xd3\x03\x18Cb\xec\x84w\xdb\x9et!_Np6\x88'
#           b'\x1d\xffv\xbb} OnC\xeeck!janscript:o[\xfbo\xaaf  (docu:U.Zrms\x7f'
#           b"6v\xf6[0].\xc9.\x96.\xa8 < 2)\xb5\xd6\xfe\xf6 {\r\n\x13ert('P"
#           b'\x06"\x96\tk\xed\xcd6\x0e yo\xe7\xd3\xab\xc0[\xdb\xfd\');ret\xfe f'
#           b'1(;}"\x00\x00\x00\x00\x00\x00 \x01\xff',
#   'flags': 2147483649,
#   'id': 32,
#   'realSize': 490,
#   'size': 366},
#  {'data': b'\xff\xdf\xfe\xcb\x1e\x00\x06\x00name="\x03mbershipNo"*\xed'
#           b'-\xf6\xfd<tr>\x06\x00\x00\xae#\x0fd>M!\xefvo\xfforable w\x07d<'
#           b'/\x12\r\n\x18 hei\xdf\xb6\xfd\xedghtB30" al\x0bn\nr\x11'
#           b'"\xf6\xed\xee\xff><input typatex\x12 siz\x0bg\xb7o\xff25  maxJng'
#           b'th\r4 \x83U\xdf6w\xfbKpass#cl\x06\x0effmFon;`\xb3w4titl\xa3\x81">'
#           b'\x83\xc0\xb6\xe7\x0e/\xad\x8a\x05\x11\xd1\xedcgoNo\xc4\x88\x16 OnC'
#           b'\x9e\xedo\xdb\xdbck\x1ajavac\xa4pt: if\x8b\xd9\x7f[\xfb(docu3j.ss['
#           b"0].\x8b\xb5\xff\xec\xdb.'lue.\xa8 < 2) {ik\xad}\xa1\x13)t('"
#           b'P\x06"\x8b6\x7fa\xed\x9b\x0e you\x04\xa0\');re\x00\xbc\xb5'
#           b'\xb7t\x16n f1(;}"\x00\x00\x00\x00\x00\x00\x00\x12\xff',
#   'flags': 2147483649,
#   'id': 33,
#   'realSize': 369,
#   'size': 304},
#  {'data': b'\xff\xff\xff\xcb\x1b\x00\x06\x00name="Password"*</tr>\x06\x00\xbf'
#           b'=\xf6>\xe4\x01 \x10\r\n<\x05 alig\xb5\x7f\xec\xb7n,left"\x12d bg'
#           b'col8\xec\x84\xbd\xbd\x14#ce\x16e7"$ v\r\xdc\x1fk\x1fmidd\x114div cl'
#           b"o\xed\xc7\xbe\xdd\x15enTies3\x17b>MemI\xdc\xb7}\xdbab' \x8a:xb"
#           b'\x17/0\xff#\xac\xc5\x07ms><img srm\xdf\xde\xb5c\x12\x08/spa\x18.g'
#           b'if\x7fw\xba\xdb[\xbbwth\x15a he\x88ht\n0\x89\xec\xae\xdb\x0bb^e?0"'
#           b">V\xf8\x1fK`\xad\x16input typk\xad\ri;p\x0f\xbc\x18Y\xbd'\xb4mx"
#           b'\x132\x0cXUK\x1ew{\xdb\xbc\rsiz15\tmax\xe1ng\x96\x0fa\x81'
#           b'\xb9\x0e\xe16to\\\x81}\xd8p"\x97 = \xf01{X \x974\xd5 \x00$\x1b'
#           b'\x16c\x19\x04\xcf\xbf\xdb\xc7\xce(0\x02\x88\x1e OnC\x90c'
#           b'\xda\x17n\xb7k\x17ja\x9asc\x06pt: n\xdf.\xb4\xdf>(docu\xe7\x19.fb'
#           b'ms[0?k\xdd\xd9].\xf1.\xc2u\x93\xe9 < 2\xad}k\xed) {u\x13\x85t('
#           b'\'P\x06"a\xfb\xe6\n\xe56\x0e you\x04m\xfa\xad\xbd\xfd\t\');ret'
#           b'\x16n f1(\x00\x00\x00\xe0;}"\x00\x90\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 34,
#   'realSize': 684,
#   'size': 414},
#  {'data': b'\xff\xff\xff\xcb\x1b\x00\x06\x00name="Password"*</tr>\x06\x00\xbf'
#           b'=\xf6>\xe4\x01 \x10\r\n<\x05 alig\xb5\x7f\xec\xb7n,left"\x12d bg'
#           b'col8\xec\x84\xbd\xbd\x14#ce\x16e7"$ v\r\xdc\x1fk\x1fmidd\x114div cl'
#           b"o\xed\xc7\xbe\xdd\x15enTies3\x17b>MemI\xdc\xb7}\xdbab' \x8a:xb"
#           b'\x17/0\xff#\xac\xc5\x07ms><img srm\xdf\xde\xb5c\x12\x08/spa\x18.g'
#           b'if\x7fw\xba\xdb[\xbbwth\x15a he\x88ht\n0\x89\xec\xae\xdb\x0bb^e?0"'
#           b">V\xf8\x1fK`\xad\x16input typk\xad\ri;p\x0f\xbc\x18Y\xbd'\xb4mx"
#           b'\x132\x0cXUK\x1ew{\xdb\xbc\rsiz15\tmax\xe1ng\x96\x0fa\x81'
#           b'\xb9\x0e\xe16to\\\x81}\xd8p"\x97 = \xf01{X \x974\xd5 \x00$\x1b'
#           b'\x16c\x19\x04\xcf\xbf\xdb\xc7\xce(0\x02\x88\x1e OnC\x90c'
#           b'\xda\x17n\xb7k\x17ja\x9asc\x06pt: n\xdf.\xb4\xdf>(docu\xe7\x19.fb'
#           b'ms[0?k\xdd\xd9].\xf1.\xc2u\x93\xe9 < 2\xad}k\xed) {u\x13\x85t('
#           b'\'P\x06"a\xfb\xe6\n\xe56\x0e you\x04m\xfa\xad\xbd\xfd\t\');ret'
#           b'\x16n f1(\x00\x00\x00\xe0;}"\x00\x90\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 35,
#   'realSize': 684,
#   'size': 414},
#  {'data': b'\x7f\xfb\xff\xcb\x1a\x00\x06\x00name="pinLog\x04"*<tr>\xbb'
#           b'\xbf\xbd\xdf\x06\x00\x00B\x01\x1f\x0fd styl$ma\xff\xed\xff\xbbr"-to'
#           b'p:2px;" id\x14label_Id\xffo\xff\xffentifier"><b>Tra\x10r Passwo'
#           b'rd:\x03\xf6\xd6\xda</\x13\x03I>\r\nOp\xf6\xed\xbdm$dOg:5L\x1fimg'
#           b' \x8d\xed6\xb0mefQ/rc\x14m\xe7\xda\xb7/\x1fagesE[5/dxm\xfb\xb6'
#           b'm"_\x1er`pfei\x83b\x8am\xcdm\xeenk.;0bt\x1930\xef\x02\xb6\xbd\n'
#           b'alt\x07"}hnput"[s\xdb v\x19uk!\x8cpn\x9b\xbb\xcd\xab\x0fcl\n\x10eet'
#           b'"\xd8\xf6\xb7\xc3\xaaw\xeath:150\xaa"\xa47\xb0\t/0\x02\xfc'
#           b'b\x16a\x8b9\xa1i\x05\'a\xb4\ro\xbb\xedtECm#By*("Pf)\xf7\x84\xff\xc2'
#           b'.s5ect();*}n\x03\x03,\x1b\xd9\xf7\xb7F (docu..9r\xb5\xff'
#           b"\xb1\x16:\xb9 == '') {jB\xdbn\xad\x0eyI'B\xaft\x16z\xdb\x85\x86C "
#           b'e+e\xa2n!+;-\xd9(k*Z\x95*\xadk\xed\xb7r!urn f]\x14\x0e}\x02'
#           b'\x98\xc2\x12a\x9b(akoOX{h/ca\x05onn&\x9e\n\x0b6cr}?\xd5(,I\x01@\xc2'
#           b'DY2\xaei\xc6\xc9\x00\x00\x00`\x00\x90\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 36,
#   'realSize': 1170,
#   'size': 440},
#  {'data': b"\xed\xff\xff\xcb!\x00\x06\x00name='internetBank\x0b\xff"
#           b"\x7f\xbf\xffgID'*/>\x06\x00\x00\x14\x01&<div class=\xff"
#           b'\xf6\xdd\xff"extNoPadd)">\r\n<\x16bel for\xff\xbf\xd6n\x1busG='
#           b'\x15Security K\xbe\xb0\x17\xfbey.</#,HTop\xdb\xf6\xbb\xc9I \x1dINP'
#           b'UT 5p\x94"a\xddg\xbbt\x1f" \xa0UKp2\'9Z\xfb\xbf\xfdjsDisQleAutoCo'
#           b'mp\t-H\xb7\xed\xde+siz710\ta\x17c\xb7\xf6\xf6-\x11off"\\max\x0ehth'
#           b'o_\xact"2dUw\xb8d  \xbf\xdb\\\xfbVALUE\x19D\x18l3float:\xc2\xff\xf6'
#           b'o\tft; wid5: 133px;"\x19\xb6k?\xc2\x1a:<a hr\x1f\x8davF\xc7Nh\xdb'
#           b'c\xecp/3\x11\x1f C\x9d\xcd\xfe\x85h\x03kES();;0$ `\x07\xf6'
#           b'\xad\xc3\x85uage9"\xf4l\x10\x026/\x16\x85\x88@\xb7\xcb\xfe[\xc3func'
#           b'tion[{*r \xff\x85\xc2\xf6vv=d\xefu)\xc7.PC_7_1_\xe1\xb6P\xf85I5'
#           b'_c;\x0cF\xdem.?\x13\xb6\x7f;.+lue;if(0.\x0b\xd6\xbe\xd0\xda<2A'
#           b"\x14\xb4t('P\x06#\x14\no\xeee C\x0e yo\xbd\n\x00\x00\x7f \xc3')"
#           b'}};\x04\x00\x00\x00\x00\x00\x00\x80\xff',
#   'flags': 2147483649,
#   'id': 37,
#   'realSize': 565,
#   'size': 444},
#  {'data': b'\xfc\xff\xff\xcb\x19\x00\x06\x00LI6-DDALD_spot*<tr>\x06'
#           b'\x00\xff\xff-\xf6\xfb\x1e\x0fd class="wizardL]\xfb\xf7\xffabelWide'
#           b'"><l\x0b for\x1cFP\xb1X\xfb\xdbPEDedit" \x1e\x11W\xd6\xfd\xdfb0,Co'
#           b'mplete PLw2\xc2\xb6-\xf6d</>E/b>f\xde\xb0[\xf7Cr0<\x8fanI'
#           b'[\xcd\xbd\xfd\xef\x12input name\x15ESp/k\xdb[\xb0\xeetyp\rpU\x0fmax'
#           b'gn\x9bm\xdb\xedgth\x1412\x0esNe\tJ\xb3\xe7\xce.A\xa6/{d\x82'
#           b'\x17Bs\xdd\r\n\x06r\x89\x03\x19A2@r$\xfaAB8%WAIN\x14B\x9b@\x8eAp'
#           b'\x12\x176\x85pP \x18\x1c\xf9\xbd\xed\xee>valu;Nex+on\xa2ic'
#           b'k\xf6\x1f;\xa1\x0e\x1b\xf3!if (docu\x92l\xb2\xdf\xf0nt.\x05ms[0].'
#           b"\x9c.A\xbf\xb5\xffl.\x8e < 2) {e\x13ert('\xdf\\\xa1\xb5P\x06%\x0c9"
#           b"\x0e you\xdb> l\x04c  ');*r\r\xba\xd6\x16Z\x17\x07f2)\x0e}l\x90"
#           b'5\xd7-\x08\x07vs\xc2RF(\xaew\x00\x00\x00\xb0\x00H\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 38,
#   'realSize': 840,
#   'size': 378},
#  {'data': b'\xff\xff\xff\xcb\x1b\x00\x06\x00name="password"*</tr>\x06\x00w'
#           b'\xff\xff>\x99\x03 <TD><FONT cl%=us\xfb\xff\xff\xfferinfo>&nbsp;W'
#           b'hat is your fav\x06\xb7\xbf\xbd\xbdite Tal P resta\x12an\xeen'
#           b'{\xedt? ZFL/Q \r\nX\xed\x7f\xfb\xb7 $ign=lefCwidth=200 \xc7\xfe'
#           b'\xb7\xf6INPUn7bIndex=1 \xa4q1C\xd9\xbb\xd8> ;\x04R>\r\n\x98TZ\xd7'
#           b'\xb6\xd8he7\x85ff\x8fm\x8d{\xb7\xed\xd6Pi p,c\x05to\xb1\x93\xf6\x03'
#           b'\xb9*2    \x97\xec\x17\xc2TY(film\xa2\xab\xb2val/tiR'
#           b'\x92\x16\xf2\xa3\x923book\x8dJ\xa6\xca\x934\xfe\xc7B\xa1'
#           b'\x02\xb5\xd0rRsubjec\xa8l\x000O5\x94e\x9f\xb5\xf6TV\x8cU\x94h'
#           b'ow\x91\x0bl$W6\x00vkm\xa4\x1d\xb9c\xa0\x82\x02ns\x8aC\xba\xb4\xf4iv'
#           b'e\xb8b\xb7<b\xbb\xbe-\xc6\xb1p"Du\xe9$c\xb0ykj*\x9c\x95=\x92,'
#           b'\x05e>\x95L\xae\xfdprov\x95$,\xa3\xde\x08ok\x02\xeds0\xf9h]\xdbn'
#           b'\xed\xd98tqH\xe9io! \xce\xd8\xdb\x8d[\x08ed#el\xf0:\r\nu\xfb'
#           b'\xcd0v\x11ov\x0c1sID*;\x86\xed\x8d\xed="\x05\x16&iM(do\x1a'
#           b'\xe9_\xd8j\x80\x08.Nrms[0].\xd1\xad\xdd\xb6m.1lZ.\x8cngo\xfbc\xdf'
#           b'Z\xfb 2) {-\x13\x87t(\'P\xa3,\x9eldO"l\x9d\x90\');\xb0\xdd\x04\xd60'
#           b'Zf\x14s(\x1e\xb7\xb6\xb0-\xbcg\xd6B\xdbMn.\xada{\xb5d\xd1'
#           b'\x18\xd3=\xdalp\xb0w\xebp0bm\xf6Aca\x18M\xb6\xb0\x90;t?n\x0e}'
#           b'\\\x112\x85\xd922\x15!\x17\x953\x11rQ\xc934!\x17\x95\\45rQ\xc9\x15'
#           b'56\x12\x90\\\x116\x00\x00\x00\x00\x00\x00\t\x00\xff',
#   'flags': 2147483649,
#   'id': 39,
#   'realSize': 2438,
#   'size': 592},
#  {'data': b'\xff\xff\xff\xcb\x1b\x00\x06\x00name="password"*</tr>\x06\x00w'
#           b'\xff\xff>\x99\x03 <TD><FONT cl%=us\xfb\xff\xff\xfferinfo>&nbsp;W'
#           b'hat is your fav\x06\xb7\xbf\xbd\xbdite Tal P resta\x12an\xeen'
#           b'{\xedt? ZFL/Q \r\nX\xed\x7f\xfb\xb7 $ign=lefCwidth=200 \xc7\xfe'
#           b'\xb7\xf6INPUn7bIndex=1 \xa4q1C\xd9\xbb\xd8> ;\x04R>\r\n\x98TZ\xd7'
#           b'\x81\x1c\xd9\xee1\x0fv\x02\x0f\x18\x03ok"\xf8\x8e\x14\xb4\xdb\x05'
#           b'> OnCgck\x18jaN\xdf\xb6\x17hF\x82pt:if\x8c(doc\xb0~wkhKt.\xf7ms['
#           b"0].\xdd\xfd6\x1b;.|.l\xb9 2) {\x10\x81o\xad\xc5\x13\x98t('P\xf2`$"
#           b"p+\xfa\xe8ll\xec\x17\xd8\xe0I\xdf');\x1ft\xf4n;\x00\x00\x00\xe0"
#           b'};"\x00\x90\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 42,
#   'realSize': 1703,
#   'size': 588},
#  {'data': b'\xfc\xff\xff\xcb\x19\x00\x06\x00name="answer"*</td>\x06'
#           b'\x00\x0f\xf6\xdd\xfb\x8d\x05\x1e\x10r>\r\n<\x05d v\xdb\xed'
#           b'\x7f\xfbalign1middle" w\x07th\x0e1\xf7\xff\xf2\xdb60\x0bclassbwLogi'
#           b'nMCUsS\xff\xff\xff}>The e of your first schooluog\xb1:qZc\x0esp'
#           b'a[2\xbb\xee\xed\xb64<?pu$typ\x9dpVwo\xc0Z{\xf6rd" \xadq1\tv\x17\xae'
#           b'{s\xdd\x95u\x18\x08siz\x072\x8c\xd6\xb6\xf6\xffAUTOCOMPLETE\x11{f'
#           b'\x12$\xef\xf6d\xdbt\tP4max\xc1ng\xbe\xae\xca\x86u0>\x89'
#           b'\xf1Y\xda\xf7v\xfb\xe5p\x1aceKown\xf8b\xf3\x10rA\xd64\xec2A\xb8\xb5'
#           b"\x03mo%\x0c's\xdb\x08\xb9 {\xb9\xec32\x04\xc8\x01fa4\xdb\xde"
#           b'\x02\x10\tcre\xc1q\x97\xc8\x05\xd9[\xeaion\xe85d\x13XA\t'
#           b'\xe6\xc0\x14!\x176\x13\x13\xe8\xb6\x80\xabKn\xbb"\xa5\xdb\xed\xf6'
#           b'\xb1\x84\x18 OnC\xf4ck\x1cjass\xedo\xb5o\xc8ipt:\x8bv (docu'
#           b'5\xb1\x05\xfe\xf6nt.f\\ms[0].=.\x97\xb7\xd6\xfe\xb3.e < 2) {'
#           b"\xeb\x13\xf7t(\x10v\xdc\xda'P\x06Ae,\xdcll\rdt\xadF\xe9"
#           b'\xc6\xa5l\x05\x00\xbf`\xf8s\');,5n;};"\x00\x00\x00\x00\x00'
#           b'\x00\x80\x04\xff',
#   'flags': 2147483649,
#   'id': 43,
#   'realSize': 1609,
#   'size': 440},
#  {'data': b'\xde\xfe\xff\xcb\x17\x00\x06\x00su contrase*</\x07>\x06\x00\xfb\xff'
#           b'\x1f\xfb\x00\xca\x1c<td>\r\n<p align="r\x05\xed\xad\xfd\x7fht"><'
#           b'span id\x10\x07ss"@\xdao\xbf\xb9l\x06\x0cnegro\x1dFirmaJ'
#           b'\xfe\x9f\xcd\xfe#></A\x05input typek\xdd\xdb\xcf9word=siz\x0f8\x08'
#           b'5\xeb^\xb6\x7fxlength\r6nam\x16fLo\xad\xdb\xdc#4l\rws\x1d:'
#           b'50\xf7\x92\r\xd9pxt/i\xc2p\xf6\xc7\xb6\xd9r\x0c\x13\x1a\xc9functi'
#           b'\xe8\xc7\xce\xfe\xee v\xcadar()*{\xe9\xf3\x1fif\x0b\xed\xf6\xdb (]n'
#           b'dow.\x03cuz\x12.\xdd\xd8Vp\x03\x16+.\x83.8uo\xc1\xda\xffe == "") {'
#           b'\\-\x15ert\xbb\xc2\xf6\xed("P\xca fav\x05,\x176od\xb7\x1da\xfbuzca'
#           b' \xa2 \r e%c\x15\xdd\xdf\xb6mni\x14.>;=return\x08}Y\xe1 k\x02{tD'
#           b'y\xb2\x9b\xe1\x11Co^Gadr\x00\x00\x00\x90\x00H\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 44,
#   'realSize': 506,
#   'size': 341},
#  {'data': b'\xf3\xff\xff\xcb\x17\x00\x06\x00name=ASEA01*</TD>\x06\x00\xff'
#           b'\xdf\xfe\xd8\xbe\x1c<TR>\r\n\x05D noWrap wid\xff\x7f\xf2\xffth=8'
#           b'5>&nbsp;Codigo de tar\xd8\xff\xcd\xdaje\x04\x16\x10claves:X\xff\xf6'
#           b'\xff\xb1H><INPUT stylw"FONT-S\xdb\x1fk\xffIZE: 9px2\x0fFAMILY\x11'
#           b'V\xff\xb7\xdb\xf6erda\x9f"Vyp+text maxLe\x1fso\xddng\x834Biz'
#           b'e\x06\xc0pass\x16ls\xb1>e\x04\xb3\x1a\xbd\xb7\x9d\x05{\xfbcolS\x1cn'
#           b'=2x\xdd\x94om\xfb\x8f\x1f OnClick\x86j\xa5@cri\xff\xdf\xfe\xdbptu'
#           b'if (docuUnt.forms[0].\xfdc\xbf}`.$lue.l\x80 < 2) {k\xb7o'
#           b"\xad\xd4\x13\xa6t('P) fF\x05\xdb/lm,A8r\x12uzca \xfe \xf6KH"
#           b'\t\x1d\x17\');r\x10\x00\x00\x00\xffurn;};"\x80\x04\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 45,
#   'realSize': 399,
#   'size': 340},
#  {'data': b"\xff\xff\xff\xcb2\x00\x06\x00<input type='password' \xbe"
#           b"\xff\xff\xeenam\x0fusrClave'*</td>\x06\x00\x00\xe5\xd8\xbf"
#           b'\xdb\xcd7\x0f\r\n\x05 >&nbsp;!\xda,\xb6\xb9\x11\x06r\x18'
#           b'\x05\x12\xed\xedw\xc3\x17)nowrap\x11fonqm{\xfb\xeefacaArialnsiz'
#           b'\x0c2\x19`\xed\xbf\xb5s6\x1bg>Firma:9\x0e\x81\x05\xec\xb5\x081IT'
#           b'\x01{\xff\xb7>ign="left"\x12\xcfg\xdf\xb3\xf6"tex\x14\xcb"fS"i'
#           b'"\xd8\x95\x1d\xd88"B>\xbb\x1e\xe4\xb5\xadu\xdbv\\u-E|\xb7r;vB{'
#           b'\xa1\x84\rick\x10\x08_#\xadm\xed?if (docuc%.\xa7d[\x1b\x1b\xfbs[0].'
#           b"m.?.\x9a\xc3t\xc4~k\xffh < 2) {^\x13ert('\xe3\xff\xdb\xbb5\x12"
#           b' \x1dco`D.\');retur\xb6\xed\x93\xfdn;};"/^losC\xc3p\x05.\xbf\xaf'
#           b'}\xdb\xdcd\xd2Of(eCo_\xda)=\xdd\x16;\xfb=-1){\x93\x154blzi\x00'
#           b'\x00\xf8\xc2d=dlse;$\x00\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 46,
#   'realSize': 490,
#   'size': 359},
#  {'data': b'\x9f\xff\xff\xcb\x14\x00\x06\x00name="PANB"*">\x06\x00'
#           b'\xd3\x01\xff\x07\xfb\x7f\x19</tr>\r\n<\x05d nowrap>&\xff`+\xf9nb'
#           b'sp;\x06 <b>Cla\xef\xdb\xfe\xf6ve d\x02Firma.IbBbH\xdb\x03\x1ba='
#           b'\x05Insol\xb7\xb0\xffduzca su LGdi\x91\x9f\xfd\xee\x7finput typ'
#           b'\xbftext" \xcbESp\xffnk\xedass\r;\x1bl\x0fFONT-WEI>\xd6:\xf7G'
#           b'HT:\xc3Cl\xa4\x14SIZE\x9f\xdbo\xdf\x1211px\x10WIDTH\x0c70CO'
#           b'\xdf6\xf7\xe5LOR#db0\x00\x0fB\rDER-\xd6\xb6\xee\xedTOP3TYL4g'
#           b'\xa0o\x95G\xfb\x136\x1b\x13[FAMILY\x14\x91\xbd\xc9~arialAR\x85C6e'
#           b'[\xb0\x1b\x12F\x1aH\xb6\xdbn\x8f\r2\x96TEX!AL\x12N\x11\xb6-\xd9[V'
#           b'ght;\x06T\x9cM\xb0\xb5\xc2\xc2=\x01\xd2\xfdTv\x88\xb0\xd0\x192\xd8'
#           b'?\xec\xc5\x8d\xd6\xb0\xd0\xb69n\x17\x19f1v\r]\x18\xc2\x0ftop"'
#           b'>\xbfuhro\x0b\x85\xad\x1d\x14jwHchpt:\n\xff\xd8\x19\x17_Dif(doc'
#           b'uj\xd8.\x14\x16\xa5.\x83ylv\xe1.\xf6\xdf\xeeNt.Oue.[ngth<5)'
#           b"{\x0e\xada!\xfcert('\xc2( !\xda\xf6[\xc3co\xe5aI.');}Ds\x1c"
#           b'\x00\x00\x00\x00\x00\x00\t\x00\xff',
#   'flags': 2147483649,
#   'id': 47,
#   'realSize': 657,
#   'size': 441},
#  {'data': b'\xe7\xff\xff\xcb\x16\x00\x06\x00name=CLAVE*</td>\x06\x00\xfb\xff'
#           b'\xff\xb1v\x1b<TR> \r\n<INPUT class=c/\x7f\xf7\xff\x7fpos onblur=may'
#           b'uscu\x19() tabI\xdb\xff\xdf\xfendex=1 \x17xLength=20 sizb1'
#           b'\xed\xed\xff\xd85 jPAN autocoGlet\x10\xfb\xcb\xbe\xfd"OFF">{TD>'
#           b'\x1e\x91"acepP\x9d\xb57wr"ixick\x11\x99m\xff\xdf\xb6\x8f#if(dBu(nt'
#           b".forms[0].}\xec\xed\xeeESp\xa1.va\x99e.l~<4){\xb5[\xfb\xbf\x0eert('"
#           b'POR F\xe6\x05, \xcf\xb7\xb7\xff\xbf\xd8ODUZCA SU NUME\x0e DE\x1eIR'
#           b"\x00\xf0\xad\xfdMA');r\x97\xdbn;};\x00\x00\x00\x00\x00\x00\x00H"
#           b'\xff',
#   'flags': 2147483649,
#   'id': 48,
#   'realSize': 291,
#   'size': 285},
#  {'data': b'\xff\xdb\xff\xcb\x1d\x00\x06\x00Entrar en\x02l banco*<\x7f'
#           b'\x8b}o\x11>\x06\x00\x00\xed"\x0fd clas\xffo\xff\xffs="kbdusr" alig'
#           b'n\x0eleft">\r\n<in\xdb\x7f\xbb\xfdput id\x12tx\x1dtabIndex\r'
#           b'1k\xb7\xdbo\x0conFoc4=v3ue\x11\x10}{\xdb} siz\x0820\nmaxBngth\xdb'
#           b"\xb7\xf2\xd6)2\x0esty\ndispny\xbe}\xfb\xed:bl8k;borJr:'nHe';fZ"
#           b'\xfb\xf6\xdd\x05t-@:0px;td\x0e\xb0vk\xc7\x8c:cH\rr;Eho\xdb\xb6}Segu'
#           b'\x84o\xb9oOg\x06sec7w\xf7\xf6reto\x1enam\x1dESp\xd0\xbb</sg'
#           b'\x9ds\xec\xc0\x05\x14\xec/\xbd\x85\xb0A\xf8B\x04/DIV\x06'
#           b'\x12\x19\xff\x1f{\xd8* \x15\x11__EVENTTARGE%!6\xd8T*,4\x1a\x13'
#           b'\xc8\xb6B\xb7\xd2pnh\x1a\xc4n|\x00\x00mX\xa9\x85\x04\x00'
#           b'\x00\x00\x00\x00\x00\x80\xff',
#   'flags': 2147483649,
#   'id': 49,
#   'realSize': 395,
#   'size': 327},
#  {'data': b'\xe7\xff\xff\xcb\x16\x00\x06\x00name="usuario"*>\x06\x00\xfe\xc1'
#           b'\xfe\xdf\r\x01\x1b</tr>\r\n<\x05d class\xdb\xfe\xf6\xdf-litera'
#           b'l"\x0folspan\x112\x0b\xb6\xfd\x7f{now\x13p>Firma: &nb\x19;\x05s'
#           b'\xff_T <input typ\xe2\xb2\xb6\xcd\x9d}xt" \xeep\xc6\x0bv\xc2uo'
#           b'm\xf7\xe6\x0c\x08siz\x0714\t\xbaxle\x11\xdep\xf7ngth\x0e1">\x00d> '
#           b'\x17(m\xbb\xd0n\xebntO& =Pr7\xda?v\xc2*;)h\x1cif(docu[v\xb3\xef'
#           b'\xdf#.datos.b.ab){\xbf}\xa1\x15@\x0b4t("I"roduz\xd9",\xb4cIt '
#           b'.\x1e;\xf8v\x07X?f\x13s(\x1d}\x00\x00\x00\x00\x00\x00$\x00\xff',
#   'flags': 2147483649,
#   'id': 50,
#   'realSize': 430,
#   'size': 259},
#  {'data': b'o\xff\xff\xcb!\x00\x06\x00class=InternetD\x02all\xdf\xc6\xbe\xffe'
#           b'*</TR>\x06\x00\x00\xf6&<\x0f vAl\x7fv\xfb\xffign=bottom>\r\n\x13D'
#           b' >txtgr\xba\xffm\xfbis>CoGr\x10ena CLNETFD\xffo\xb1\xc1(a;$ght>&n'
#           b'bsp; \xf6\xdf\xfd\xff<INPUT TYPE="pGword" NAM\x0f\xde\xfe'
#           b'\x7f\x0b\x0bMAXLENGTH= "8\x0eSIZ}o\xd8\xe6\x1a\x08>X\xa6_R\x7f'
#           b'\xdb\xda\x87\x8eolS9g2!IMG he\xad\xfd\xed\x7fo=5 src7/img/g\x9c'
#           b'\xe9\xf6\xdboo\x8c/pu\xaao.gifUwidth$f\x07\x9b\xb0T\x10\xf5D>\xa5'
#           b'\xed\xf6\xb1\x13\x0b\x85\x15 OnC\xcdckQ\xfd\xdb\xb7\xedjav\xa6c'
#           b'\xd4pt: I (docum\xf0\xed\xbb\xbd`t.f\xc9m.\xc2. lue.\xb5\xf6[\xbbR'
#           b"ngc\xf1 2) {b\x13\xb4\xad\xdd\xbe\x83t('P% fB\x05,=\x91\xf0\xc278"
#           b'oduzc9la G\x00_X\xf8\');r\x99u\xa1;};"\x00\x00\x00\x00\x00\x00\x80'
#           b'\x04\xff',
#   'flags': 2147483649,
#   'id': 51,
#   'realSize': 440,
#   'size': 374},
#  {'data': b'{\xfe\xff\xcb\x12\x00\x06\x00name="PIN"*>\x06\x00x\x17\xfb\xbfl\x1f'
#           b'<tr>\x03dfont class&\xee\xf6\xed\x7fnormal">C\x0eve d\x02Fi\x10\xac'
#           b'\xfd\x96\xec\r\n \x00\x0b<inpu1Wn\xef\xbe\xfbESp8" typ\rtext\x0bid'
#           b"\xfb\xbav\xe9oA/>,./d/m;\xf9\xff\x99\x8fusuario=''*;g\x17w\xb7\xf6"
#           b'\x1fif (docuU\x8e.f\x87s[0\xff\xf6\xed\xd9]._.v\x94ue.l\x1agth < 5['
#           b'\xd8o\xed) {Y\x13ert("\xab\x97\xb6\xb7\xddvo &c\xd3raN");\'}'
#           b'\x00\x00\x00\xdf\x02else\x80\x04\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 52,
#   'realSize': 271,
#   'size': 226},
#  {'data': b"\xdf\xfe\xff\xcb!\x00\x06\x00abreflo(\\'segu\x05)*</\x7f{\xbf\xffs"
#           b'cript>\x06\x00\x00%\x01&\x14tr>\r\n<\xf7\xff\xff`\x05d width="85"'
#           b'>&nbsp;!\xb6/?Xd\x1bclasscfce\x1a"\xdb\xb7\xed\xc3*100+C\x1ave d'
#           b'\x02fv\xd9\x02\xfbirma:4221\xd6\xfd\xb7\xff<img src\r../7054/'
#           b'\x10/\xb2\x17\xc2\xfe\xede_\\t.gif">E\x12o\xee\xed\xffinput nam'
#           b'e\x14ESp\x1c\\valVp\xc9\xbau\x0e",$\x01\x9e\xdb\xda\xbb\xb7\x10ty'
#           b'p\x18text\x0b\x9dxc\xce\xfd\xcbwng\x863 onfocu-\x06\x11\x02B\xec='
#           b'1;\\\x13K\xb2\xd8 \xfcPINV2*75\x12\x82\x81\xdd\xdaYZh\xd7\xfbn'
#           b'"\x90\xb7[\xaca\x1e\x144\xd3(cotS\x17\xe4l\xe1==0\x8e{N\x92\x1b\xd9'
#           b'w{]d\x88m\xfc\x8eerA.H\xdb\xfe\xd9\xd8.G.\xb5 < 5){/ \x00\xf0o'
#           b'\xdfZ\x15&t("I1roduzca\x16\xfbB\xb8Nu \x88");*Z\xb7\xb3\xb1'
#           b'\x14\xfc(%}\x04el\x00\x00\x00h\x1f\x00$\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 53,
#   'realSize': 576,
#   'size': 374},
#  {'data': b'\xcf\xff\xff\xcb\x15\x00\x06\x00NAME="PAN"*<TR>\x06\x00\xba\xff\xed'
#           b'\xdfb\x1a\x0fD ALIGN\x1fCENTER" \xff\xff\x7f\xfbCLASS\x0epx12"><B>F'
#           b'irma electro\xba\xb7\xd6\xfenica.</\x15\x039>\r\n\x06R\xf7Vvw\x05'
#           b' \r\nM@\x18\xf7\xf6\xcf\xfeINPUT \x88ESpasshTYP\ro\xb7v{text'
#           b'\x0bid\t/XT\tsiz\xef\xdb\xd6\xb6e\x0b8\x08txsngth\r\xff\xb3\xc1bj'
#           b"u'\xd4umPulsacg\xbf\xb0\xb7i\x94es=\x0e-1*;\xe6\xa6\xed[\xfbc,if(d"
#           b'oc"Ot.fo\xcf\xf6\xf6\xec\xees.n\x05al.\x8b.v\nue.n\xdd\xbf\xb5\x7f'
#           b' < 5){o\x12ert("In\xf6d=%\xdc\xdauz\xf7\x9au \x0c");D\xe6\x86\xac*'
#           b'\x8b1\x12n\xe0\xd6\xbe\xddf\x1cs(9}\x02Lse\x00\x00\x00\x00\x00\x00'
#           b'\x90\x00\xff',
#   'flags': 2147483649,
#   'id': 54,
#   'realSize': 424,
#   'size': 303},
#  {'data': b'\x7f\xfb\xff\xcb%\x00\x06\x00/Jaen/images\x06nterro\xff'
#           b'\xfd\xfe\xddga\x07.jpg*>\x06\x00\x00\x04\x01*</TR>c\xff\x1f\xf6 '
#           b'\r\n<\x06D height=29\x10P\xff\xb6\xfd\xff><FONT face="VJdHa, Tah'
#           b'om\xff\xffo_" color=#007042 siz$2\xb2\xcd\xb9\xb71/2\x06<_DX\xb6'
#           b'}\x15\xb6RFir\x1b:X\xd6\xbe%KT\x0bINPUK\x1c\xbd\x9b\xfd\xedxL'
#           b'\xf3gth=103\x07valu\xd8\xbfm\xcdaR^m\x07ESpass>C\xd9\x0b#\x1c\x19.'
#           b'<"put$\x8f\x9d0\xc2"5""r\x1e On\xff\xffv\xfbClick\x1bjaQscript: '
#           b'if (doc\xd9\xb6-\xb4u3W.\xb0gC.`\xf6\x8f\xb5\xd8.u\x12\x8d < 5'
#           b") {\xaav\x8b\xbd\xb5\x13\xe6t('\xc6io \x1d\xfe\x7f\xbb\xb5\xe68raB'"
#           b');return;};"\x00\x00\x00\x00\x00\x00\t\x00\xff',
#   'flags': 2147483649,
#   'id': 55,
#   'realSize': 448,
#   'size': 325},
#  {'data': b'\xe7\xff\xff\xcb\x16\x00\x06\x00name="PAN"*</td>\x06\x00\xdf\xdc'
#           b'w\xb1\xe2\x1b\x10r>\r\n<\x05\x03d cl\x8bm\xff\xedass+sp5">&nb'
#           b'\x07;1%\xdb\xfe\xff\x02txt10n" align\x0er\x05\xdf\xbe\xfcvht\rwidth'
#           b'71pxCFirm\xcf\x14\xd8\xb1aB\r\n97<7\xec\xbb\xffinput typ\xbbtext"<'
#           b'\x18\x9a\xfb\xac5<\r\xd5ESp\x14\r\xb6\xbd\xbf\xdfexleng?16"\xb0'
#           b'r\x14\xe1\xb1\xb3\xff?if(contS==0)*{\xfb\x93\x19\xfb\xad\xbdk'
#           b'\x92\x1bdocuH\x1f.userK\xde\xda\xf6\xec.R.v\x9cu`N"){\xdb\xb7\x16'
#           b'\xdb( \x00\x11"t("I-r\xb1\xf6\xed\xffoduzca su C\x95ve d'
#           b'\x02\xeb\x9b\xc2\x86l-;Yf\x18l\xbb\x1d\xb6s((}\x06el!\r'
#           b'\x92\x086\x08\x7fPINV2*\xa14\xa5d[aB\nh$kn\xfe\x00\x00\xdbl'
#           b'\xac\xab>\x04\x00\x00\x00\x00\x00\x00\x80\xff',
#   'flags': 2147483649,
#   'id': 56,
#   'realSize': 498,
#   'size': 320},
#  {'data': b'\xff\xff\xff\xcb$\x00\x06\x00name=HB_PSW_FINAL_CONEX\xed'
#           b'\x7f\x9f\xff2*</TD>\x06\x006\x01)<TR>\r\n\x05\xfd\xffo\xffD clas'
#           b's=7nu noWrap align=r\xff\x7f\xf6\xbf\x04ht>&nbsp;\x05<A tabIndex=1'
#           b'\xffo\xdb\xff href="jav>c+pt:ct_ayudam\x7f\xfb\xdb(\'7tp://w\x00.c'
#           b'aixa5r\xfe\xbf}\xbbWgo\x9d.es/\x02p/sec_20/code\xf7\xdf\xdedos./'
#           b'ml\',\'680\x0545\xdb\xdb\xf6\xf6)">C\x96ve j \xc7RMA\xbfA\xb7'
#           b'c\xb1`\x8a\xc9\xb9><\xe1PU}7\xf6\xb2T\x932 \xffp\xcf maxl\xdb'
#           b'\t\xbb\xbd\xd2gth\xa90>3MG\xbae\xbb{\xbb{\xdb\xc3src\xc2../\x02img'
#           b'\x9a\x06\xe9\xfe\xffacio.gif" wid=2\x14\xbc\xdb\xb6\x11_gRe\xc9_\''
#           b"()*;\xc3\xdfb'Ow\x191 (docuG\x85o\xbb}t.LOG\x9aFO\xb7.\x8b.!"
#           b'\xad\xbd}\xf6lue.\x8e < \x90) {\x8d\x14\xd6-\xecoJt("El \xea\x08b'
#           b'\n\xb6\xad\xbd\x85!r\x11+\x05\xed\x8et\xae\xbd\xb5\x17$");3\x14r'
#           b'or\xb7\t\x00\x00\x00\x80}\x00@\x02\x00\xff',
#   'flags': 2147483649,
#   'id': 57,
#   'realSize': 497,
#   'size': 426},
#  {'data': b'\xe7\xff\xff\xcb\x16\x00\x06\x00name="usuario"*>\x06\x00\xff`'
#           b'\xff\xb1\xc5\x1b</tr>\r\n<\x05d class\xbf\xb7\xffo-Portada_LitF\nmu'
#           b'l;Ac\xb6\xff\xff\xedcesA nowrap>&nbsp; Fi\x1fa\xfdW`\xc1\x0b\x06<in'
#           b'put \xf2\xee\xcd\x9d\x9bpsVtyp\x0btext\xf6om\xf3siz12\t[xleng'
#           b'th\x0e\xc7\xeen\x7fVALUE\n">\xb9d>\x17\xc4cog\xbf\xdd\xdantN\xde ='
#           b'Crue*;\xe1h\xb7\xad\xfdc\x1cif(docuf#.\xd0tok\xbb\xed\xdfs.m.val)=H'
#           b'){\xf8\x0b\xa1\xfd\xedme\xee("I"roduzcI,\x01V\xb6Y\xd7\x1e'
#           b';?\x00\x00\xbe\xddf\x13s(\x1d}\t\x00\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 58,
#   'realSize': 358,
#   'size': 261},
#  {'data': b'\xf9\xff\xff\xcb\x18\x00\x06\x00name="CLAVE"*</td>\x06\x00'
#           b'\xfd\xed\xbb\xf7*\x01\x1d\x10r>\r\n<\x05 alignv\xc8\xd8\xbf)center"'
#           b'\x14dr\x05\xbf\xdb\xdb\xffht" width\r50%\x1f<b"fo\xeb\xde\xbao- siz'
#           b'b2\x1ffac\x08A-v\xb7\xdfZ6\x0ccolor\r#0\x00A0\xda\xdb\xed\xdf0Clave'
#           b' d\x02Ac%so:z\xa3,\xf6\xf6<G/b>\x96p\xf6\xee\x87u\x1fp\x1eleft'
#           b'\x82inpu~\xdbw?\xb0\xe1 typ\x0cpassw}d\xde\xedm\xb0"\x9b4\x08max5n'
#           b'gN\xfe\xbb\xf6\xe6\ryCha\r\x1adoSubmit(\xec\xd7\xee\xde\x08cum\xfc.'
#           b'us\xff@)"\x98\xed\x9b\x1b\xe1\x17Gc\xacoua =ce\xc7N\xf8rue*;Fh'
#           b'\x1cif>\xb7\xad\xfd\xfedatos.@.v\xae)=c")\xdfn\xad\xb5{\xbd\x0bVe'
#           b'"I"rodu+[\xfb\xdbzcIsu Fir\x98\x1e;?\x00\xdf\xee\x00f\x13s('
#           b'\x1d}\x00\x00\x00\x00\x00\x00\x80\x04\xff',
#   'flags': 2147483649,
#   'id': 59,
#   'realSize': 461,
#   'size': 339},
#  {'data': b'\xec\xf9\xff\xcb\x10\x00\x06\x00Intro(e)*{\x06\x00}\x15\xff\xff'
#           b'\xed\x7fif(docume\x1d.forms[0].PIN0.v\x8f\xfd\xf6\xffalue==""){\r\n'
#           b'\x0bert("Cduz\xdbv\xfb\xffca su Clave d\x02fi8a\';\xb3o\'+Kus0pa'
#           b'ssK@\xbb}\xbbf\x16s( }\x02el\x1b\x00\x00\x00\x00\x00\x00 \x01\xff',
#   'flags': 2147483649,
#   'id': 60,
#   'realSize': 147,
#   'size': 138},
#  {'data': b'\xf9\xff\xff\xcb\x18\x00\x06\x00id="sUsuario*</td>\x06\x00'
#           b'_\xf7]\xec\xf1\x1d\x10r>\r\n<\x05 \x06d\xf6\xff\xb7\xdb w0th278"><d'
#           b'iv align\x0f_\xfe\xbb\xb7=ght\x12font size2" f\xad\xb5\xff\xdda'
#           b'c\x08Verdana, A%.\x06[\xbeu\xffHelvetic\x11s\x17s-sef;\xd7~\xbb}'
#           b' Cla\x17 d\x02FirmazK\x13\x16\xeb\xb6Q/e>\x98\x806\xbf\xdb'
#           b'\xda\xbb0minpunZmeESpass\x81mwostyp\rtex\x8e \xdc\xf7\xdb6'
#           b'\xd8"\x9618 ]xlengG\x076\xfb\xce2]\x1e\xf0Ri;\xe1\xd6n\'ge\x8c\xae'
#           b'd"\x14~#k\xdb\xd6\x1e On\xaa\xbek j\xb0s\xd6\xfe\xedmc\\pt:kf (docu'
#           b'8\xb5\xbe\x9d}\xee.u\xd3\x8e.\x95.&lue.\xdeZ\xfb\xcfs < 5)'
#           b" {\xcd\x13$t('\xed\xb6\xdb\xc2\xf6zo &c\xfara\x00\xf8\x17\xbeN')"
#           b';r*urn;};"\x00\x00\x00\x00\x00\x00\x00$\xff',
#   'flags': 2147483649,
#   'id': 61,
#   'realSize': 433,
x00\x00\x00\x00\x00\x00\x00\x00\t\x00\xff',
#   'flags': 2147483649,
#   'id': 107,
#   'realSize': 98,
#   'size': 85},
#  {'data': b'\x1d\x00\x00\x00\x06\x00<table*id="dgPurses1"*>\x0e\x00\x00'
#           b'\x00\x06\x00</table>\x06\x00\x00\x00\x00\x00',
#   'flags': 2147483648,
#   'id': 108,
#   'realSize': 49,
#   'size': 49},
#  {'data': b'\xff\xff\xff\xcb\xad\x00\x06\x00<input type="password" \xff'
#           b'\xffo\xb6s\x10lfont-family: Arial, \xbe}\xec\xffHelvetica; \x1esi'
#           b'ze\x1c10pt\xbf\xed\xde\xde\x10col>:#0\x0066\x0ebackg'
#           b'\xe7\xbe\x9f\xfdround-\x19 #e8\x01;a6\xb3oo7`12\tmaxkngth\x0e'
#           b'm\xeb\x86\xb5nn\x8a\x88vru\x0e\xb7\xfd\xd8\xef>\x06\x00\x00'
#           b'z\x01\xb2tr>\r\n\x05dn\xb5\xdbo\xdbs(n-5"><b\x15</\x14\xf6\xefO\xf6'
#           b'\x1a/!nowrap\x0cdiv K\xd9so\xeeig-\xc7ght1\xbe\xb2s\xc3\x82'
#           b'\xb5\x13\xb3\x97\x87\xf6\xb6mdnc\x08\xf4\nspsv\xffo\xdb\xf4e\x17'
#           b'ft>Date de\xb6is\xb6\xdd\xff\xe6\x1a3 (JJ/MM/A\x00) \x8bbK\xe6\xdc'
#           b'\xe7\x96i>\x0b\x84\xa4\x05\x84[B\xb8 \r\n\x7fIxt{\x90\x84\x07\x00'
#           b'dobx\x00\x00@\x8bM\xa9 \x01\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 109,
#   'realSize': 557,
#   'size': 323},
#  {'data': b'\xfe\xff\xff\xcb\x1a\x00\x06\x00<input type="submit"'
#           b'\x06\x00\xff\xf6\x1f{C\x1f onclick\x1cjavascr\xed\xff\xff\xffipt:'
#           b' document.forms[0].tmp.\x1fe\xb7\xef\xdaluE\x16eredV\x0c"5'
#           b'bo\xbb\xdf~hidd!" nam\rne(_lovv\x9b\xb5g\x0f;1">}):\xbd'
#           b'\x99\xdb\x063=_3\x08\x00\x008\x8bJI>$\x00\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 110,
#   'realSize': 199,
#   'size': 156},
#  {'data': b'\xf9\xff\xff\xcb\x18\x00\x06\x00name="password"*">\x06\x00'
#           b'\xc0\xda\x7f\xec\xd7\x1d<label f\x1a#\x9b\xfb\xb6}><br\x03s\x0fn'
#           b' cl\x14\x1aV\xff\xb7o\xdb10\x15C\x0bve d\x02Operacionec\x8fm\xefs<'
#           b'/&,/G>\r\n:i\xdf\xb6\x1f\xf6nput;pn-b\rt-"  tl`\x1f\xd8yp\x8c id'
#           b'\r\xaao\x9b\xb7\xf7ES\x11\rsiz15\tmaxZy\xb9\xfdlength\x0e20tit\n'
#           b'\x0f\xd86\xc0\x8e\xa4\x13\xf4Sub\xb6\xc5\xce\xb6m+"\xef\x87\x18,n7'
#           b'\xdb\xdf\xda\xf6ick\x1cj=fcript:\x86f\xde\xdc\xdbo\x9a(docu5nt'
#           b'.\x03Oda.\xfdg\xdf\xce\x88.&lue.\x80 < 2) {n\x03\xec\xad\x11qt'
#           b"('\x81\xc4o -\xfc\x8f\xdd*coCo');returHf\x00\x00\x00\xbf3se"
#           b';}"\x80\x04\x00\x00\xff',
#   'flags': 2147483649,
#   'id': 111,
#   'realSize': 405,
#   'size': 296},
#  {'data': b'\xe7\xff\xff\xcb\x16\x00\x06\x00name="PAN"*</tr>\x06\x00\xfb\xbf'
#           b'\xb9\xb1\xe5\x1b<\x0f\x03d  bgcolor\'\xc7v\xff\x7fd9d7cf">&nbsp;'
#           b'0d>5\r\n\xfb\x03X\xb0<\x05- class\x0e\x02\x1bv{txt\x16cb=\x05'
#           b'\xf6\x1f\xd8\xbfFirma:\x11<input \xbc}\xee\xcd}ESp_ftyp\r\x0bw{\xbb'
#           b'\xfd\xb6}d\x0fwidth\x1012\nsiz\x1a\x1f\xfb\xde\xb79"\xadd\xa7\xb4'
#           b'\x1a\xe4user\xe1\xd66|3.\x03.f\x9f\x0f*{\x04\xe6\xfe\x16;a\x1f, '
#           b'if (d\x19l\xff?K\xf6nt./v.value == ""\xdb\xb7\xd6\xb6)+{\x02\x0f t('
#           b'"I+rm\x1b\xbb\xfdoduzca}u \xc2.!;\x1f[\xack\xb7}\x02elD+\x12`\nl'
#           b'\xb1\xb3\xdb\xc2f."o\x07*}x\x07\x17\x00\x00\x00\x80}\x00'
#           b'@\x02\x00\xff',
#   'flags': 2147483649,
#   'id': 112,
#   'realSize': 417,
#   'size': 288},
#  {'data': b'\xdf\xfe\x97\xfc?\x00\x12\x00\x10\x00*/my.eba\x04com/\xff'
#           b'\xb7\xff\xff*CurrentPage=MyeB\x17PersonalIn/`#\xfbfo*\x00,>;-?'
#           b'$\xdb\xffISAPI.dll?+*https\xf6\xb3\xff\xf6://w\x00.us.hsbc8\x003'
#           b'\x00\x13)\xff\xc7\xfe\x14e-gold(acct/li.as\xf7[ \xecp\x0092\xa1lan'
#           b'ce7\xb6\x16\xc2\xb6kG\x95\xe3Yn6\xd6\xbe\xdd#we\xbbsfarA?d'
#           b'3s\xdb\xdf\xfe/cgi-b\x1b/sessi&.\x0fF\x0bY\n{-\x00\x02\x7fC,'
#           b'\xb6\x1d\x08{5\x00\x03slo`n4\xba\xb7D\xc86\x99gno5=\xb6\x15\x06\x12'
#           b'tp\x9f\x02l\x93\r\xff\x0bm\x10\xb8scr?cmd=_%o\xb1\x01\xd9\x85u'
#           b'\xf5\x00A<\xae\x1cao\xdb-d|e}D\x00\x11@#c\x8b]0\xf3\x88nkA0tV\xf6'
#           b'\xbd\xb9[0tB\x10\x0bg/LCR\x83-\x0ca\xbb\x15\x00U\x84e\x8ayva{'
#           b'\xc3wqtdc6a\x99trQmk\xb7\xd9t\xfc6vlM\x98FE\xd9\x85o\r\xe9i\xa7Summ'
#           b'\x1byS\x18\xb7\xb6\xc2\xb6\x98E\xd9\x980tiY\x10b\x8dz\xf5\x9e]\xe6'
#           b'\xa3\xe3\xf6\xb7\tdex-wa\x1f.jsS:j\xedl"b\xcb.\x81M\xa9\xfb$w0U'
#           b'\x18OLB\xa1cY\xeepOxe/AhLi\xb8\x8dx\x00L\xfd\xb2\x07\x12qsun\xe2p'
#           b"ort\xa1\x15Z\xacS\xe9\x02\x8c\xd2\x8c#\x94\xb6S\xa8gm\xa8=*'"
#           b'\x84\x13\t\xbd53(ef\xb6\x97f\xb3s\xb4\xe2\x8btml@F\xf0\xa5'
#           b'\xdb\x90\x13\x08Cv\x02oKf?#\x83"8*\x08\xf4\x91E\xa0L\x00\x03'
#           b'\xf9\xe9\r\x8b@8\x14\x02\xf6\xb9`P\x9b\x01\xe4UK\x04\x06Z'
#           b'\x00N\xa5\x8c:\xb00o\x8cwF\xb5\x18\x02P5~#\xb2>c\xb2php?X\xc2'
#           b'\x8d\x84&%\xa2\xa7e\xc2%S$\xf8\xe1\xecr/K\xa2\x11\xacV\xaa\xae\xa4'
#           b'F*\xd4Z\x11\x0eG\x0bha\xc5\x89o-P\x8c\x05!W,\x14-\n2\x1e$4VM9\xc8c'
#           b'm\xa1F\x0b\x84\xbf\x93\xbf\x00\x00\x00@\x00 \x01\x00\xff',
#   'flags': 536870913,
#   'id': 'CFGID_HTTP_INJECTS_LIST (20009)',
#   'realSize': 7138,
#   'size': 2569}]

# %% [markdown]
# ## Commands
#
# Pseudocode:
#
#     ...
#     ci = 0;
#     while ( Str::_CompareA(-1, v8, *(&g_s416->lowsec + g_command_offset[4 * ci]), v23) )
#     {
#         if ( ++ci >= 25u )
#             goto LABEL_30;
#     }
#     ...
#
# Disassembly:
#
#     .text:00407E52 C6 45 FD 00                                   mov     [ebp+ci], 0
#     .text:00407E56
#     .text:00407E56                               loc_407E56:
#     .text:00407E56 0F B6 45 FD                                   movzx   eax, [ebp+ci]
#     .text:00407E5A 0F B7 0C C5 F8 41 41 00                       movzx   ecx, g_command_offset[eax*8]
#     .text:00407E62 8B 3D F4 4A 41 00                             mov     edi, g_s416
#     .text:00407E68 FF 75 E4                                      push    [ebp+var_1C]
#     .text:00407E6B 8B 0C 8F                                      mov     ecx, [edi+ecx*4]
#     .text:00407E6E 83 C8 FF                                      or      eax, 0FFFFFFFFh
#     .text:00407E71 8B D6                                         mov     edx, esi
#     .text:00407E73 E8 18 72 00 00                                call    Str___CompareA
#     .text:00407E78 85 C0                                         test    eax, eax
#     .text:00407E7A 74 0E                                         jz      short loc_407E8A
#     .text:00407E7C FE 45 FD                                      inc     [ebp+ci]
#     .text:00407E7F 80 7D FD 19                                   cmp     [ebp+ci], 19h
#     .text:00407E83 72 D1                                         jb      short loc_407E56
#     .text:00407E85 E9 AD 00 00 00                                jmp     loc_407F37

# %%
match = re.search(rb'\x0f\xb7\x0c\xc5(?P<indexes_addr>[\s\S]{4})', pe.get_memory_mapped_image())
indexes_addr = struct.unpack("I", match.group("indexes_addr"))[0]

for i in range(25):
    index_addr = indexes_addr + i * 8
    index_rva = index_addr - pe.OPTIONAL_HEADER.ImageBase
    string_index = pe.get_word_at_rva(index_rva)
    
    print(f"{i}: {plain_strings[string_index]}")
# Out:
# 0: block_fake
# 1: unblock_fake
# 2: bc_add
# 3: bc_del
# 4: block_url
# 5: unblock_url
# 6: addsf
# 7: delsf
# 8: getfile
# 9: getcerts
# 10: resetgrab
# 11: upcfg
# 12: kbot
# 13: rename_bot
# 14: getmff
# 15: delmff
# 16: sethomepage
# 17: kos
# 18: reboot
# 19: shutdown
# 20: rexeci
# 21: rexec
# 22: lexeci
# 23: lexec
# 24: resetkwm
